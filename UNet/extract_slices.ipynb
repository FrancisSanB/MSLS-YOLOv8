# %%
# !pip install SimpleITK

import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import re
import shutil
import random
# Out:
# Requirement already satisfied: SimpleITK in c:\users\f_alf\anaconda3\lib\site-packages (2.3.1)

# %%
def load_all_images(file):
    print(f'loading the {file} file...')
    
    ### LOAD SEGMENTATION FILES
    seg1_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_1.nii.gz')  
    seg2_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_2.nii.gz')  
    seg3_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_3.nii.gz')  
    seg4_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_4.nii.gz')  
    seg5_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_5.nii.gz') 
    seg6_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_6.nii.gz') 
    seg7_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_7.nii.gz')

    ### LOAD 3D SCAN FILE
    flair_image = sitk.ReadImage(f'data/{file}/3DFLAIR.nii.gz')

    size = seg1_image.GetSize()

    caster = sitk.CastImageFilter()
    caster.SetOutputPixelType(sitk.sitkUInt8)

    ### FIND THE SLICES IN Z AXIS
    for z_slice in range(size[0]):
        # iterated slice of 3d image
        sliced_images = [
            seg1_image[z_slice, :, :],
            seg2_image[z_slice, :, :],
            seg3_image[z_slice, :, :],
            seg4_image[z_slice, :, :],
            seg5_image[z_slice, :, :],
            seg6_image[z_slice, :, :],
            seg7_image[z_slice, :, :]
        ]

        # get array from image slice
        sliced_arrays = [
            sitk.GetArrayFromImage(sliced_images[0]),
            sitk.GetArrayFromImage(sliced_images[1]),
            sitk.GetArrayFromImage(sliced_images[2]),
            sitk.GetArrayFromImage(sliced_images[3]),
            sitk.GetArrayFromImage(sliced_images[4]),
            sitk.GetArrayFromImage(sliced_images[5]),
            sitk.GetArrayFromImage(sliced_images[6])
        ]

        # same for the 3d image
        flair_slice_image = flair_image[z_slice, :, :]
        #flair_slice_array = sitk.GetArrayFromImage(flair_slice_image)

        for count, slice_array in enumerate(sliced_arrays):
            # if there are only zero values, skip
            non_zero_values = slice_array[slice_array != 0]
            if non_zero_values.size == 0:
                continue

            binary_mask = (slice_array > 0).astype(np.uint8)
            output_image = sitk.GetImageFromArray(binary_mask)

            # add origin, spacing, direction from original image
            output_image.SetOrigin(sliced_images[count].GetOrigin())
            output_image.SetSpacing(sliced_images[count].GetSpacing())
            output_image.SetDirection(sliced_images[count].GetDirection())

            # output image
            png_output_path = f'data/train/labels/{file}_seg{count+1}_{z_slice:03}.png'
            sitk.WriteImage(output_image, png_output_path)

            #output for the 3d image
            flair_slice_image = sitk.RescaleIntensity(flair_slice_image, 0, 255)
            flair_slice_image = caster.Execute(flair_slice_image)
            #output_image = sitk.GetImageFromArray(flair_slice_array.astype(np.uint8))
            #output_image.SetOrigin(flair_slice_image.GetOrigin())
            #output_image.SetSpacing(flair_slice_image.GetSpacing())
            #output_image.SetDirection(flair_slice_image.GetDirection())
            #png_output_path = f'data/train/images/{file}_{z_slice:03}.png'
            #sitk.WriteImage(flair_slice_image, png_output_path)
            #png_output_path = f'data/train/images_all/{file}_seg{count+1}_{z_slice:03}.png'
            #sitk.WriteImage(flair_slice_image, png_output_path)
            png_output_path = f'data/train/images/{file}_seg{count+1}_{z_slice:03}.png'
            sitk.WriteImage(flair_slice_image, png_output_path)

    print(f'...finished reading outputing the {file} file')

# %%
# loading images onto drive
load_all_images('01016SACH')
load_all_images('01040VANE')
load_all_images('07010NABO')
load_all_images('07040DORE')
load_all_images('07043SEME')
load_all_images('08002CHJE')
# Out:
# loading the 01016SACH file...
# ...finished reading outputing the 01016SACH file
# loading the 01040VANE file...
# ...finished reading outputing the 01040VANE file
# loading the 07010NABO file...
# ...finished reading outputing the 07010NABO file
# loading the 07040DORE file...
# ...finished reading outputing the 07040DORE file
# loading the 07043SEME file...
# ...finished reading outputing the 07043SEME file
# loading the 08002CHJE file...
# ...finished reading outputing the 08002CHJE file

# %%
def move_related_files(source_dir1, source_dir2, dest_dir1, dest_dir2, percentage):
    files1 = os.listdir(source_dir1)
    files2 = os.listdir(source_dir2)

    os.makedirs(dest_dir1, exist_ok=True)
    os.makedirs(dest_dir2, exist_ok=True)

    num_files_to_move = int(min(len(files1), len(files2)) * (percentage / 100.0))

    files_to_move = random.sample(list(zip(files1, files2)), num_files_to_move)
    #print(files_to_move)

    for file_pair in files_to_move:
        file1, file2 = file_pair
        #print(f"Moving: {file1} and {file2}")
        source_path1 = os.path.join(source_dir1, file1)
        source_path2 = os.path.join(source_dir2, file2)
        dest_path1 = os.path.join(dest_dir1, file1)
        dest_path2 = os.path.join(dest_dir2, file2)

        try:
            shutil.move(source_path1, dest_path1)
            shutil.move(source_path2, dest_path2)
        except Exception as e:
            print(e)

        print(f"Moved: {file1} and {file2}")

# %%
# move some images and labels to test set
source_directory1 = "data/train/images"
source_directory2 = "data/train/labels"
destination_directory1 = "data/test/images"
destination_directory2 = "data/test/labels"
percentage_to_move = 20  # Adjust this percentage as needed
move_related_files(source_directory1, source_directory2, destination_directory1, destination_directory2, percentage_to_move)
# Out:
# Moved: 07043SEME_seg4_095.png and 07043SEME_seg4_095.png
# Moved: 01016SACH_seg5_124.png and 01016SACH_seg5_124.png
# Moved: 08002CHJE_seg5_065.png and 08002CHJE_seg5_065.png
# Moved: 07040DORE_seg2_163.png and 07040DORE_seg2_163.png
# Moved: 01016SACH_seg7_074.png and 01016SACH_seg7_074.png
# Moved: 08002CHJE_seg7_064.png and 08002CHJE_seg7_064.png
# Moved: 07040DORE_seg2_112.png and 07040DORE_seg2_112.png
# Moved: 07043SEME_seg2_075.png and 07043SEME_seg2_075.png
# Moved: 07010NABO_seg2_169.png and 07010NABO_seg2_169.png
# Moved: 08002CHJE_seg4_104.png and 08002CHJE_seg4_104.png
# Moved: 08002CHJE_seg4_216.png and 08002CHJE_seg4_216.png
# Moved: 08002CHJE_seg2_138.png and 08002CHJE_seg2_138.png
# Moved: 07010NABO_seg6_124.png and 07010NABO_seg6_124.png
# Moved: 07040DORE_seg7_110.png and 07040DORE_seg7_110.png
# Moved: 07043SEME_seg5_085.png and 07043SEME_seg5_085.png
# Moved: 08002CHJE_seg6_206.png and 08002CHJE_seg6_206.png
# Moved: 08002CHJE_seg6_146.png and 08002CHJE_seg6_146.png
# Moved: 01040VANE_seg4_108.png and 01040VANE_seg4_108.png
# Moved: 07010NABO_seg4_172.png and 07010NABO_seg4_172.png
# Moved: 01040VANE_seg5_174.png and 01040VANE_seg5_174.png
# Moved: 08002CHJE_seg4_176.png and 08002CHJE_seg4_176.png
# Moved: 01016SACH_seg7_084.png and 01016SACH_seg7_084.png
# Moved: 07043SEME_seg4_132.png and 07043SEME_seg4_132.png
# Moved: 07040DORE_seg2_164.png and 07040DORE_seg2_164.png
# Moved: 07040DORE_seg7_148.png and 07040DORE_seg7_148.png
# Moved: 08002CHJE_seg3_041.png and 08002CHJE_seg3_041.png
# Moved: 01016SACH_seg7_184.png and 01016SACH_seg7_184.png
# Moved: 01016SACH_seg6_152.png and 01016SACH_seg6_152.png
# Moved: 08002CHJE_seg7_145.png and 08002CHJE_seg7_145.png
# Moved: 07040DORE_seg7_101.png and 07040DORE_seg7_101.png
# Moved: 07040DORE_seg4_156.png and 07040DORE_seg4_156.png
# Moved: 01016SACH_seg5_114.png and 01016SACH_seg5_114.png
# Moved: 08002CHJE_seg2_192.png and 08002CHJE_seg2_192.png
# Moved: 07010NABO_seg3_107.png and 07010NABO_seg3_107.png
# Moved: 01016SACH_seg2_115.png and 01016SACH_seg2_115.png
# Moved: 01016SACH_seg2_102.png and 01016SACH_seg2_102.png
# Moved: 07043SEME_seg3_102.png and 07043SEME_seg3_102.png
# Moved: 07040DORE_seg7_087.png and 07040DORE_seg7_087.png
# Moved: 01016SACH_seg6_134.png and 01016SACH_seg6_134.png
# Moved: 08002CHJE_seg3_142.png and 08002CHJE_seg3_142.png
# Moved: 08002CHJE_seg1_039.png and 08002CHJE_seg1_039.png
# Moved: 01016SACH_seg4_164.png and 01016SACH_seg4_164.png
# Moved: 08002CHJE_seg5_084.png and 08002CHJE_seg5_084.png
# Moved: 07040DORE_seg2_179.png and 07040DORE_seg2_179.png
# Moved: 08002CHJE_seg2_104.png and 08002CHJE_seg2_104.png
# Moved: 07040DORE_seg6_168.png and 07040DORE_seg6_168.png
# Moved: 01016SACH_seg5_178.png and 01016SACH_seg5_178.png
# Moved: 07010NABO_seg3_135.png and 07010NABO_seg3_135.png
# Moved: 01016SACH_seg6_181.png and 01016SACH_seg6_181.png
# Moved: 01040VANE_seg4_145.png and 01040VANE_seg4_145.png
# Moved: 08002CHJE_seg5_162.png and 08002CHJE_seg5_162.png
# Moved: 07043SEME_seg6_094.png and 07043SEME_seg6_094.png
# Moved: 01016SACH_seg2_089.png and 01016SACH_seg2_089.png
# Moved: 07040DORE_seg2_147.png and 07040DORE_seg2_147.png
# Moved: 01016SACH_seg4_142.png and 01016SACH_seg4_142.png
# Moved: 08002CHJE_seg4_144.png and 08002CHJE_seg4_144.png
# Moved: 01016SACH_seg6_179.png and 01016SACH_seg6_179.png
# Moved: 07040DORE_seg6_110.png and 07040DORE_seg6_110.png
# Moved: 01016SACH_seg5_187.png and 01016SACH_seg5_187.png
# Moved: 01040VANE_seg5_085.png and 01040VANE_seg5_085.png
# Moved: 07043SEME_seg5_141.png and 07043SEME_seg5_141.png
# Moved: 07043SEME_seg4_080.png and 07043SEME_seg4_080.png
# Moved: 08002CHJE_seg6_195.png and 08002CHJE_seg6_195.png
# Moved: 07040DORE_seg1_180.png and 07040DORE_seg1_180.png
# Moved: 07040DORE_seg6_177.png and 07040DORE_seg6_177.png
# Moved: 08002CHJE_seg5_176.png and 08002CHJE_seg5_176.png
# Moved: 07040DORE_seg2_170.png and 07040DORE_seg2_170.png
# Moved: 08002CHJE_seg2_134.png and 08002CHJE_seg2_134.png
# Moved: 01016SACH_seg7_183.png and 01016SACH_seg7_183.png
# Moved: 07010NABO_seg3_092.png and 07010NABO_seg3_092.png
# Moved: 01016SACH_seg2_140.png and 01016SACH_seg2_140.png
# Moved: 01016SACH_seg5_151.png and 01016SACH_seg5_151.png
# Moved: 08002CHJE_seg6_113.png and 08002CHJE_seg6_113.png
# Moved: 07040DORE_seg4_121.png and 07040DORE_seg4_121.png
# Moved: 07040DORE_seg2_157.png and 07040DORE_seg2_157.png
# Moved: 07043SEME_seg1_107.png and 07043SEME_seg1_107.png
# Moved: 07043SEME_seg5_121.png and 07043SEME_seg5_121.png
# Moved: 01016SACH_seg5_093.png and 01016SACH_seg5_093.png
# Moved: 01040VANE_seg5_080.png and 01040VANE_seg5_080.png
# Moved: 07043SEME_seg4_138.png and 07043SEME_seg4_138.png
# Moved: 01016SACH_seg1_150.png and 01016SACH_seg1_150.png
# Moved: 08002CHJE_seg6_200.png and 08002CHJE_seg6_200.png
# Moved: 08002CHJE_seg4_048.png and 08002CHJE_seg4_048.png
# Moved: 01016SACH_seg3_153.png and 01016SACH_seg3_153.png
# Moved: 07040DORE_seg3_135.png and 07040DORE_seg3_135.png
# Moved: 01016SACH_seg5_141.png and 01016SACH_seg5_141.png
# Moved: 07043SEME_seg3_173.png and 07043SEME_seg3_173.png
# Moved: 07043SEME_seg2_134.png and 07043SEME_seg2_134.png
# Moved: 07043SEME_seg6_154.png and 07043SEME_seg6_154.png
# Moved: 08002CHJE_seg5_104.png and 08002CHJE_seg5_104.png
# Moved: 07043SEME_seg1_179.png and 07043SEME_seg1_179.png
# Moved: 01040VANE_seg2_144.png and 01040VANE_seg2_144.png
# Moved: 07043SEME_seg4_114.png and 07043SEME_seg4_114.png
# Moved: 01016SACH_seg3_156.png and 01016SACH_seg3_156.png
# Moved: 01016SACH_seg4_063.png and 01016SACH_seg4_063.png
# Moved: 08002CHJE_seg2_213.png and 08002CHJE_seg2_213.png
# Moved: 07040DORE_seg4_116.png and 07040DORE_seg4_116.png
# Moved: 01016SACH_seg2_184.png and 01016SACH_seg2_184.png
# Moved: 01016SACH_seg2_134.png and 01016SACH_seg2_134.png
# Moved: 07043SEME_seg2_083.png and 07043SEME_seg2_083.png
# Moved: 01040VANE_seg1_082.png and 01040VANE_seg1_082.png
# Moved: 07043SEME_seg2_138.png and 07043SEME_seg2_138.png
# Moved: 01040VANE_seg2_116.png and 01040VANE_seg2_116.png
# Moved: 08002CHJE_seg3_068.png and 08002CHJE_seg3_068.png
# Moved: 07043SEME_seg4_180.png and 07043SEME_seg4_180.png
# Moved: 07040DORE_seg1_105.png and 07040DORE_seg1_105.png
# Moved: 07043SEME_seg6_144.png and 07043SEME_seg6_144.png
# Moved: 08002CHJE_seg1_138.png and 08002CHJE_seg1_138.png
# Moved: 08002CHJE_seg1_074.png and 08002CHJE_seg1_074.png
# Moved: 08002CHJE_seg3_154.png and 08002CHJE_seg3_154.png
# Moved: 08002CHJE_seg4_184.png and 08002CHJE_seg4_184.png
# Moved: 07040DORE_seg5_152.png and 07040DORE_seg5_152.png
# Moved: 07040DORE_seg2_092.png and 07040DORE_seg2_092.png
# Moved: 01016SACH_seg1_166.png and 01016SACH_seg1_166.png
# Moved: 01016SACH_seg1_178.png and 01016SACH_seg1_178.png
# Moved: 08002CHJE_seg3_138.png and 08002CHJE_seg3_138.png
# Moved: 07040DORE_seg2_061.png and 07040DORE_seg2_061.png
# Moved: 07040DORE_seg5_092.png and 07040DORE_seg5_092.png
# Moved: 07040DORE_seg7_071.png and 07040DORE_seg7_071.png
# Moved: 08002CHJE_seg3_210.png and 08002CHJE_seg3_210.png
# Moved: 01016SACH_seg6_138.png and 01016SACH_seg6_138.png
# Moved: 08002CHJE_seg3_069.png and 08002CHJE_seg3_069.png
# Moved: 07040DORE_seg6_164.png and 07040DORE_seg6_164.png
# Moved: 07040DORE_seg1_095.png and 07040DORE_seg1_095.png
# Moved: 08002CHJE_seg4_098.png and 08002CHJE_seg4_098.png
# Moved: 07010NABO_seg1_194.png and 07010NABO_seg1_194.png
# Moved: 01016SACH_seg1_076.png and 01016SACH_seg1_076.png
# Moved: 07040DORE_seg2_074.png and 07040DORE_seg2_074.png
# Moved: 07043SEME_seg6_152.png and 07043SEME_seg6_152.png
# Moved: 07043SEME_seg4_140.png and 07043SEME_seg4_140.png
# Moved: 08002CHJE_seg6_105.png and 08002CHJE_seg6_105.png
# Moved: 07040DORE_seg3_110.png and 07040DORE_seg3_110.png
# Moved: 07040DORE_seg1_153.png and 07040DORE_seg1_153.png
# Moved: 07040DORE_seg2_148.png and 07040DORE_seg2_148.png
# Moved: 07043SEME_seg3_095.png and 07043SEME_seg3_095.png
# Moved: 07043SEME_seg5_095.png and 07043SEME_seg5_095.png
# Moved: 07010NABO_seg5_186.png and 07010NABO_seg5_186.png
# Moved: 08002CHJE_seg5_053.png and 08002CHJE_seg5_053.png
# Moved: 08002CHJE_seg7_038.png and 08002CHJE_seg7_038.png
# Moved: 08002CHJE_seg3_083.png and 08002CHJE_seg3_083.png
# Moved: 07043SEME_seg2_180.png and 07043SEME_seg2_180.png
# Moved: 08002CHJE_seg1_140.png and 08002CHJE_seg1_140.png
# Moved: 01040VANE_seg2_155.png and 01040VANE_seg2_155.png
# Moved: 07043SEME_seg5_119.png and 07043SEME_seg5_119.png
# Moved: 08002CHJE_seg1_181.png and 08002CHJE_seg1_181.png
# Moved: 08002CHJE_seg4_065.png and 08002CHJE_seg4_065.png
# Moved: 01040VANE_seg1_090.png and 01040VANE_seg1_090.png
# Moved: 01016SACH_seg5_055.png and 01016SACH_seg5_055.png
# Moved: 08002CHJE_seg3_172.png and 08002CHJE_seg3_172.png
# Moved: 01040VANE_seg2_084.png and 01040VANE_seg2_084.png
# Moved: 08002CHJE_seg7_070.png and 08002CHJE_seg7_070.png
# Moved: 01016SACH_seg2_051.png and 01016SACH_seg2_051.png
# Moved: 01016SACH_seg6_149.png and 01016SACH_seg6_149.png
# Moved: 07010NABO_seg1_186.png and 07010NABO_seg1_186.png
# Moved: 01016SACH_seg1_180.png and 01016SACH_seg1_180.png
# Moved: 08002CHJE_seg5_152.png and 08002CHJE_seg5_152.png
# Moved: 07043SEME_seg4_149.png and 07043SEME_seg4_149.png
# Moved: 01016SACH_seg6_063.png and 01016SACH_seg6_063.png
# Moved: 01016SACH_seg6_062.png and 01016SACH_seg6_062.png
# Moved: 07043SEME_seg4_131.png and 07043SEME_seg4_131.png
# Moved: 01016SACH_seg3_207.png and 01016SACH_seg3_207.png
# Moved: 01016SACH_seg2_064.png and 01016SACH_seg2_064.png
# Moved: 07010NABO_seg2_181.png and 07010NABO_seg2_181.png
# Moved: 07010NABO_seg6_194.png and 07010NABO_seg6_194.png
# Moved: 01040VANE_seg3_173.png and 01040VANE_seg3_173.png
# Moved: 07040DORE_seg6_169.png and 07040DORE_seg6_169.png
# Moved: 07043SEME_seg6_077.png and 07043SEME_seg6_077.png
# Moved: 01040VANE_seg6_093.png and 01040VANE_seg6_093.png
# Moved: 07040DORE_seg5_159.png and 07040DORE_seg5_159.png
# Moved: 08002CHJE_seg2_116.png and 08002CHJE_seg2_116.png
# Moved: 01016SACH_seg3_075.png and 01016SACH_seg3_075.png
# Moved: 01016SACH_seg5_067.png and 01016SACH_seg5_067.png
# Moved: 01016SACH_seg7_168.png and 01016SACH_seg7_168.png
# Moved: 01016SACH_seg6_078.png and 01016SACH_seg6_078.png
# Moved: 08002CHJE_seg2_178.png and 08002CHJE_seg2_178.png
# Moved: 08002CHJE_seg4_182.png and 08002CHJE_seg4_182.png
# Moved: 07010NABO_seg7_169.png and 07010NABO_seg7_169.png
# Moved: 08002CHJE_seg5_153.png and 08002CHJE_seg5_153.png
# Moved: 08002CHJE_seg7_050.png and 08002CHJE_seg7_050.png
# Moved: 08002CHJE_seg3_179.png and 08002CHJE_seg3_179.png
# Moved: 01016SACH_seg2_197.png and 01016SACH_seg2_197.png
# Moved: 08002CHJE_seg1_086.png and 08002CHJE_seg1_086.png
# Moved: 01040VANE_seg1_088.png and 01040VANE_seg1_088.png
# Moved: 07043SEME_seg4_078.png and 07043SEME_seg4_078.png
# Moved: 01016SACH_seg5_085.png and 01016SACH_seg5_085.png
# Moved: 08002CHJE_seg7_095.png and 08002CHJE_seg7_095.png
# Moved: 07040DORE_seg5_115.png and 07040DORE_seg5_115.png
# Moved: 01016SACH_seg3_053.png and 01016SACH_seg3_053.png
# Moved: 08002CHJE_seg6_154.png and 08002CHJE_seg6_154.png
# Moved: 07043SEME_seg4_192.png and 07043SEME_seg4_192.png
# Moved: 07010NABO_seg5_074.png and 07010NABO_seg5_074.png
# Moved: 07043SEME_seg7_162.png and 07043SEME_seg7_162.png
# Moved: 08002CHJE_seg1_172.png and 08002CHJE_seg1_172.png
# Moved: 08002CHJE_seg3_141.png and 08002CHJE_seg3_141.png
# Moved: 08002CHJE_seg3_117.png and 08002CHJE_seg3_117.png
# Moved: 07043SEME_seg3_117.png and 07043SEME_seg3_117.png
# Moved: 07043SEME_seg6_169.png and 07043SEME_seg6_169.png
# Moved: 07040DORE_seg5_098.png and 07040DORE_seg5_098.png
# Moved: 01016SACH_seg2_211.png and 01016SACH_seg2_211.png
# Moved: 07043SEME_seg6_151.png and 07043SEME_seg6_151.png
# Moved: 07040DORE_seg2_087.png and 07040DORE_seg2_087.png
# Moved: 01016SACH_seg6_185.png and 01016SACH_seg6_185.png
# Moved: 01016SACH_seg1_106.png and 01016SACH_seg1_106.png
# Moved: 07043SEME_seg6_162.png and 07043SEME_seg6_162.png
# Moved: 01016SACH_seg3_210.png and 01016SACH_seg3_210.png
# Moved: 01016SACH_seg3_158.png and 01016SACH_seg3_158.png
# Moved: 07043SEME_seg1_143.png and 07043SEME_seg1_143.png
# Moved: 07010NABO_seg1_078.png and 07010NABO_seg1_078.png
# Moved: 01016SACH_seg7_118.png and 01016SACH_seg7_118.png
# Moved: 08002CHJE_seg4_110.png and 08002CHJE_seg4_110.png
# Moved: 01016SACH_seg5_198.png and 01016SACH_seg5_198.png
# Moved: 08002CHJE_seg4_177.png and 08002CHJE_seg4_177.png
# Moved: 01016SACH_seg1_098.png and 01016SACH_seg1_098.png
# Moved: 01040VANE_seg1_080.png and 01040VANE_seg1_080.png
# Moved: 01016SACH_seg4_052.png and 01016SACH_seg4_052.png
# Moved: 07040DORE_seg7_092.png and 07040DORE_seg7_092.png
# Moved: 07043SEME_seg2_178.png and 07043SEME_seg2_178.png
# Moved: 07040DORE_seg6_136.png and 07040DORE_seg6_136.png
# Moved: 07043SEME_seg2_102.png and 07043SEME_seg2_102.png
# Moved: 08002CHJE_seg3_191.png and 08002CHJE_seg3_191.png
# Moved: 07010NABO_seg2_093.png and 07010NABO_seg2_093.png
# Moved: 07043SEME_seg5_153.png and 07043SEME_seg5_153.png
# Moved: 07040DORE_seg3_108.png and 07040DORE_seg3_108.png
# Moved: 01040VANE_seg2_112.png and 01040VANE_seg2_112.png
# Moved: 01016SACH_seg3_192.png and 01016SACH_seg3_192.png
# Moved: 01016SACH_seg1_064.png and 01016SACH_seg1_064.png
# Moved: 07040DORE_seg4_083.png and 07040DORE_seg4_083.png
# Moved: 07040DORE_seg4_141.png and 07040DORE_seg4_141.png
# Moved: 07010NABO_seg4_189.png and 07010NABO_seg4_189.png
# Moved: 08002CHJE_seg2_164.png and 08002CHJE_seg2_164.png
# Moved: 01016SACH_seg6_114.png and 01016SACH_seg6_114.png
# Moved: 08002CHJE_seg7_139.png and 08002CHJE_seg7_139.png
# Moved: 08002CHJE_seg5_177.png and 08002CHJE_seg5_177.png
# Moved: 07010NABO_seg7_106.png and 07010NABO_seg7_106.png
# Moved: 01040VANE_seg4_100.png and 01040VANE_seg4_100.png
# Moved: 08002CHJE_seg3_150.png and 08002CHJE_seg3_150.png
# Moved: 08002CHJE_seg3_081.png and 08002CHJE_seg3_081.png
# Moved: 07010NABO_seg5_176.png and 07010NABO_seg5_176.png
# Moved: 08002CHJE_seg1_179.png and 08002CHJE_seg1_179.png
# Moved: 07040DORE_seg7_107.png and 07040DORE_seg7_107.png
# Moved: 07040DORE_seg7_076.png and 07040DORE_seg7_076.png
# Moved: 01040VANE_seg3_162.png and 01040VANE_seg3_162.png
# Moved: 01016SACH_seg3_064.png and 01016SACH_seg3_064.png
# Moved: 07010NABO_seg6_193.png and 07010NABO_seg6_193.png
# Moved: 08002CHJE_seg3_114.png and 08002CHJE_seg3_114.png
# Moved: 08002CHJE_seg7_082.png and 08002CHJE_seg7_082.png
# Moved: 07043SEME_seg3_112.png and 07043SEME_seg3_112.png
# Moved: 08002CHJE_seg3_049.png and 08002CHJE_seg3_049.png
# Moved: 08002CHJE_seg2_037.png and 08002CHJE_seg2_037.png
# Moved: 08002CHJE_seg1_078.png and 08002CHJE_seg1_078.png
# Moved: 08002CHJE_seg6_110.png and 08002CHJE_seg6_110.png
# Moved: 01016SACH_seg2_160.png and 01016SACH_seg2_160.png
# Moved: 01040VANE_seg4_181.png and 01040VANE_seg4_181.png
# Moved: 01016SACH_seg1_136.png and 01016SACH_seg1_136.png
# Moved: 07040DORE_seg7_176.png and 07040DORE_seg7_176.png
# Moved: 01016SACH_seg1_095.png and 01016SACH_seg1_095.png
# Moved: 08002CHJE_seg7_104.png and 08002CHJE_seg7_104.png
# Moved: 08002CHJE_seg5_201.png and 08002CHJE_seg5_201.png
# Moved: 07040DORE_seg4_101.png and 07040DORE_seg4_101.png
# Moved: 01016SACH_seg5_125.png and 01016SACH_seg5_125.png
# Moved: 07043SEME_seg1_168.png and 07043SEME_seg1_168.png
# Moved: 08002CHJE_seg1_116.png and 08002CHJE_seg1_116.png
# Moved: 08002CHJE_seg6_119.png and 08002CHJE_seg6_119.png
# Moved: 08002CHJE_seg4_156.png and 08002CHJE_seg4_156.png
# Moved: 08002CHJE_seg1_191.png and 08002CHJE_seg1_191.png
# Moved: 07040DORE_seg5_188.png and 07040DORE_seg5_188.png
# Moved: 08002CHJE_seg6_211.png and 08002CHJE_seg6_211.png
# Moved: 01016SACH_seg4_128.png and 01016SACH_seg4_128.png
# Moved: 08002CHJE_seg2_082.png and 08002CHJE_seg2_082.png
# Moved: 08002CHJE_seg3_073.png and 08002CHJE_seg3_073.png
# Moved: 08002CHJE_seg3_209.png and 08002CHJE_seg3_209.png
# Moved: 01016SACH_seg7_188.png and 01016SACH_seg7_188.png
# Moved: 07010NABO_seg6_081.png and 07010NABO_seg6_081.png
# Moved: 01016SACH_seg7_134.png and 01016SACH_seg7_134.png
# Moved: 07043SEME_seg3_107.png and 07043SEME_seg3_107.png
# Moved: 07010NABO_seg4_139.png and 07010NABO_seg4_139.png
# Moved: 08002CHJE_seg4_054.png and 08002CHJE_seg4_054.png
# Moved: 08002CHJE_seg2_161.png and 08002CHJE_seg2_161.png
# Moved: 01040VANE_seg3_096.png and 01040VANE_seg3_096.png
# Moved: 07010NABO_seg5_148.png and 07010NABO_seg5_148.png
# Moved: 01040VANE_seg7_147.png and 01040VANE_seg7_147.png
# Moved: 01016SACH_seg3_162.png and 01016SACH_seg3_162.png

# %%
def generate_consensus_labels():
    image_path = 'data/test/images'
    label_path = 'data/test/labels'
    
    caster = sitk.CastImageFilter()
    caster.SetOutputPixelType(sitk.sitkUInt8)

    # Iterate over all files in the folder
    for filename in os.listdir(image_path):
        file_path = os.path.join(image_path, filename)

        # Check if it's a file (not a subdirectory)
        if os.path.isfile(file_path):
            # Extract information using regex
            parts = filename.split('_')

            if len(parts) == 3:
                # Extract imageName and slice number
                imageName, fileType, slice_extension = parts
                sliceNumber, extension = slice_extension.split('.')
                sliceNumber = int(sliceNumber.lstrip('0'))
                
                print(f"Generating consensus for: {imageName}-{sliceNumber}...")
                
                ### LOAD SEGMENTATION FILES
                con_image = sitk.ReadImage(f'data/{imageName}/Consensus.nii.gz')
                
                sliced_image = con_image[sliceNumber, :, :]
                sliced_array = sitk.GetArrayFromImage(sliced_image)
                
                binary_mask = (sliced_array > 0).astype(np.uint8)
                output_image = sitk.GetImageFromArray(binary_mask)
                
                output_image.SetOrigin(sliced_image.GetOrigin())
                output_image.SetSpacing(sliced_image.GetSpacing())
                output_image.SetDirection(sliced_image.GetDirection())
                
                sliceNumber = str(sliceNumber).zfill(3)
                png_output_path = f'{label_path}/{imageName}_{sliceNumber}.png'
                sitk.WriteImage(output_image, png_output_path)
                
                file_path_to_delete = f'{label_path}/{imageName}_{fileType}_{sliceNumber}.{extension}'
                if os.path.exists(file_path_to_delete):
                    os.remove(file_path_to_delete)

                # Create the new file name without {type}
                new_filename = f'{imageName}_{sliceNumber}.{extension}'  # Adjust the file extension if needed
                if not os.path.exists(os.path.join(image_path, new_filename)):
                    os.rename(file_path, os.path.join(image_path, new_filename))
                    
                file_path_to_delete = f'{image_path}/{imageName}_{fileType}_{sliceNumber}.{extension}'
                if os.path.exists(file_path_to_delete):
                    os.remove(file_path_to_delete)

# %%
# generate consensus images for test set
generate_consensus_labels()
# Out:
# Generating consensus for: 01016SACH-54...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-76...
# Generating consensus for: 01016SACH-95...
# Generating consensus for: 01016SACH-97...
# Generating consensus for: 01016SACH-98...
# Generating consensus for: 01016SACH-106...
# Generating consensus for: 01016SACH-126...
# Generating consensus for: 01016SACH-127...
# Generating consensus for: 01016SACH-130...
# Generating consensus for: 01016SACH-132...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-136...
# Generating consensus for: 01016SACH-141...
# Generating consensus for: 01016SACH-144...
# Generating consensus for: 01016SACH-145...
# Generating consensus for: 01016SACH-150...
# Generating consensus for: 01016SACH-160...
# Generating consensus for: 01016SACH-161...
# Generating consensus for: 01016SACH-166...
# Generating consensus for: 01016SACH-174...
# Generating consensus for: 01016SACH-176...
# Generating consensus for: 01016SACH-178...
# Generating consensus for: 01016SACH-180...
# Generating consensus for: 01016SACH-189...
# Generating consensus for: 01016SACH-213...
# Generating consensus for: 01016SACH-215...
# Generating consensus for: 01016SACH-51...
# Generating consensus for: 01016SACH-57...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-70...
# Generating consensus for: 01016SACH-78...
# Generating consensus for: 01016SACH-87...
# Generating consensus for: 01016SACH-89...
# Generating consensus for: 01016SACH-102...
# Generating consensus for: 01016SACH-105...
# Generating consensus for: 01016SACH-106...
# Generating consensus for: 01016SACH-115...
# Generating consensus for: 01016SACH-120...
# Generating consensus for: 01016SACH-132...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-140...
# Generating consensus for: 01016SACH-145...
# Generating consensus for: 01016SACH-152...
# Generating consensus for: 01016SACH-159...
# Generating consensus for: 01016SACH-160...
# Generating consensus for: 01016SACH-162...
# Generating consensus for: 01016SACH-163...
# Generating consensus for: 01016SACH-169...
# Generating consensus for: 01016SACH-178...
# Generating consensus for: 01016SACH-179...
# Generating consensus for: 01016SACH-180...
# Generating consensus for: 01016SACH-181...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-194...
# Generating consensus for: 01016SACH-197...
# Generating consensus for: 01016SACH-207...
# Generating consensus for: 01016SACH-208...
# Generating consensus for: 01016SACH-211...
# Generating consensus for: 01016SACH-53...
# Generating consensus for: 01016SACH-60...
# Generating consensus for: 01016SACH-61...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-65...
# Generating consensus for: 01016SACH-67...
# Generating consensus for: 01016SACH-68...
# Generating consensus for: 01016SACH-70...
# Generating consensus for: 01016SACH-75...
# Generating consensus for: 01016SACH-77...
# Generating consensus for: 01016SACH-83...
# Generating consensus for: 01016SACH-88...
# Generating consensus for: 01016SACH-97...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-113...
# Generating consensus for: 01016SACH-114...
# Generating consensus for: 01016SACH-118...
# Generating consensus for: 01016SACH-143...
# Generating consensus for: 01016SACH-147...
# Generating consensus for: 01016SACH-149...
# Generating consensus for: 01016SACH-153...
# Generating consensus for: 01016SACH-156...
# Generating consensus for: 01016SACH-158...
# Generating consensus for: 01016SACH-162...
# Generating consensus for: 01016SACH-167...
# Generating consensus for: 01016SACH-173...
# Generating consensus for: 01016SACH-176...
# Generating consensus for: 01016SACH-188...
# Generating consensus for: 01016SACH-191...
# Generating consensus for: 01016SACH-192...
# Generating consensus for: 01016SACH-194...
# Generating consensus for: 01016SACH-196...
# Generating consensus for: 01016SACH-207...
# Generating consensus for: 01016SACH-209...
# Generating consensus for: 01016SACH-210...
# Generating consensus for: 01016SACH-52...
# Generating consensus for: 01016SACH-60...
# Generating consensus for: 01016SACH-61...
# Generating consensus for: 01016SACH-63...
# Generating consensus for: 01016SACH-74...
# Generating consensus for: 01016SACH-78...
# Generating consensus for: 01016SACH-79...
# Generating consensus for: 01016SACH-96...
# Generating consensus for: 01016SACH-97...
# Generating consensus for: 01016SACH-98...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-105...
# Generating consensus for: 01016SACH-111...
# Generating consensus for: 01016SACH-116...
# Generating consensus for: 01016SACH-121...
# Generating consensus for: 01016SACH-126...
# Generating consensus for: 01016SACH-128...
# Generating consensus for: 01016SACH-132...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-137...
# Generating consensus for: 01016SACH-139...
# Generating consensus for: 01016SACH-142...
# Generating consensus for: 01016SACH-147...
# Generating consensus for: 01016SACH-163...
# Generating consensus for: 01016SACH-164...
# Generating consensus for: 01016SACH-170...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-185...
# Generating consensus for: 01016SACH-186...
# Generating consensus for: 01016SACH-188...
# Generating consensus for: 01016SACH-190...
# Generating consensus for: 01016SACH-192...
# Generating consensus for: 01016SACH-55...
# Generating consensus for: 01016SACH-62...
# Generating consensus for: 01016SACH-67...
# Generating consensus for: 01016SACH-71...
# Generating consensus for: 01016SACH-72...
# Generating consensus for: 01016SACH-85...
# Generating consensus for: 01016SACH-93...
# Generating consensus for: 01016SACH-94...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-107...
# Generating consensus for: 01016SACH-108...
# Generating consensus for: 01016SACH-114...
# Generating consensus for: 01016SACH-117...
# Generating consensus for: 01016SACH-122...
# Generating consensus for: 01016SACH-124...
# Generating consensus for: 01016SACH-125...
# Generating consensus for: 01016SACH-135...
# Generating consensus for: 01016SACH-141...
# Generating consensus for: 01016SACH-151...
# Generating consensus for: 01016SACH-178...
# Generating consensus for: 01016SACH-179...
# Generating consensus for: 01016SACH-183...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-187...
# Generating consensus for: 01016SACH-191...
# Generating consensus for: 01016SACH-198...
# Generating consensus for: 01016SACH-208...
# Generating consensus for: 01016SACH-59...
# Generating consensus for: 01016SACH-62...
# Generating consensus for: 01016SACH-63...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-78...
# Generating consensus for: 01016SACH-94...
# Generating consensus for: 01016SACH-102...
# Generating consensus for: 01016SACH-107...
# Generating consensus for: 01016SACH-114...
# Generating consensus for: 01016SACH-121...
# Generating consensus for: 01016SACH-126...
# Generating consensus for: 01016SACH-127...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-138...
# Generating consensus for: 01016SACH-142...
# Generating consensus for: 01016SACH-147...
# Generating consensus for: 01016SACH-149...
# Generating consensus for: 01016SACH-150...
# Generating consensus for: 01016SACH-152...
# Generating consensus for: 01016SACH-155...
# Generating consensus for: 01016SACH-159...
# Generating consensus for: 01016SACH-164...
# Generating consensus for: 01016SACH-172...
# Generating consensus for: 01016SACH-174...
# Generating consensus for: 01016SACH-179...
# Generating consensus for: 01016SACH-181...
# Generating consensus for: 01016SACH-185...
# Generating consensus for: 01016SACH-192...
# Generating consensus for: 01016SACH-194...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-67...
# Generating consensus for: 01016SACH-73...
# Generating consensus for: 01016SACH-74...
# Generating consensus for: 01016SACH-81...
# Generating consensus for: 01016SACH-84...
# Generating consensus for: 01016SACH-99...
# Generating consensus for: 01016SACH-100...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-114...
# Generating consensus for: 01016SACH-117...
# Generating consensus for: 01016SACH-118...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-138...
# Generating consensus for: 01016SACH-139...
# Generating consensus for: 01016SACH-146...
# Generating consensus for: 01016SACH-151...
# Generating consensus for: 01016SACH-158...
# Generating consensus for: 01016SACH-164...
# Generating consensus for: 01016SACH-168...
# Generating consensus for: 01016SACH-170...
# Generating consensus for: 01016SACH-181...
# Generating consensus for: 01016SACH-183...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-188...
# Generating consensus for: 01040VANE-80...
# Generating consensus for: 01040VANE-82...
# Generating consensus for: 01040VANE-85...
# Generating consensus for: 01040VANE-88...
# Generating consensus for: 01040VANE-90...
# Generating consensus for: 01040VANE-91...
# Generating consensus for: 01040VANE-142...
# Generating consensus for: 01040VANE-144...
# Generating consensus for: 01040VANE-152...
# Generating consensus for: 01040VANE-172...
# Generating consensus for: 01040VANE-84...
# Generating consensus for: 01040VANE-93...
# Generating consensus for: 01040VANE-97...
# Generating consensus for: 01040VANE-99...
# Generating consensus for: 01040VANE-101...
# Generating consensus for: 01040VANE-102...
# Generating consensus for: 01040VANE-112...
# Generating consensus for: 01040VANE-116...
# Generating consensus for: 01040VANE-141...
# Generating consensus for: 01040VANE-142...
# Generating consensus for: 01040VANE-143...
# Generating consensus for: 01040VANE-144...
# Generating consensus for: 01040VANE-145...
# Generating consensus for: 01040VANE-146...
# Generating consensus for: 01040VANE-153...
# Generating consensus for: 01040VANE-155...
# Generating consensus for: 01040VANE-161...
# Generating consensus for: 01040VANE-162...
# Generating consensus for: 01040VANE-167...
# Generating consensus for: 01040VANE-177...
# Generating consensus for: 01040VANE-96...
# Generating consensus for: 01040VANE-112...
# Generating consensus for: 01040VANE-115...
# Generating consensus for: 01040VANE-119...
# Generating consensus for: 01040VANE-121...
# Generating consensus for: 01040VANE-123...
# Generating consensus for: 01040VANE-127...
# Generating consensus for: 01040VANE-148...
# Generating consensus for: 01040VANE-150...
# Generating consensus for: 01040VANE-151...
# Generating consensus for: 01040VANE-155...
# Generating consensus for: 01040VANE-162...
# Generating consensus for: 01040VANE-173...
# Generating consensus for: 01040VANE-87...
# Generating consensus for: 01040VANE-100...
# Generating consensus for: 01040VANE-108...
# Generating consensus for: 01040VANE-109...
# Generating consensus for: 01040VANE-115...
# Generating consensus for: 01040VANE-143...
# Generating consensus for: 01040VANE-145...
# Generating consensus for: 01040VANE-148...
# Generating consensus for: 01040VANE-150...
# Generating consensus for: 01040VANE-155...
# Generating consensus for: 01040VANE-156...
# Generating consensus for: 01040VANE-166...
# Generating consensus for: 01040VANE-170...
# Generating consensus for: 01040VANE-180...
# Generating consensus for: 01040VANE-181...
# Generating consensus for: 01040VANE-80...
# Generating consensus for: 01040VANE-82...
# Generating consensus for: 01040VANE-84...
# Generating consensus for: 01040VANE-85...
# Generating consensus for: 01040VANE-92...
# Generating consensus for: 01040VANE-93...
# Generating consensus for: 01040VANE-104...
# Generating consensus for: 01040VANE-105...
# Generating consensus for: 01040VANE-110...
# Generating consensus for: 01040VANE-145...
# Generating consensus for: 01040VANE-174...
# Generating consensus for: 01040VANE-53...
# Generating consensus for: 01040VANE-83...
# Generating consensus for: 01040VANE-93...
# Generating consensus for: 01040VANE-97...
# Generating consensus for: 01040VANE-104...
# Generating consensus for: 01040VANE-160...
# Generating consensus for: 01040VANE-165...
# Generating consensus for: 01040VANE-82...
# Generating consensus for: 01040VANE-83...
# Generating consensus for: 01040VANE-84...
# Generating consensus for: 01040VANE-92...
# Generating consensus for: 01040VANE-95...
# Generating consensus for: 01040VANE-102...
# Generating consensus for: 01040VANE-146...
# Generating consensus for: 01040VANE-147...
# Generating consensus for: 01040VANE-164...
# Generating consensus for: 07010NABO-73...
# Generating consensus for: 07010NABO-78...
# Generating consensus for: 07010NABO-83...
# Generating consensus for: 07010NABO-87...
# Generating consensus for: 07010NABO-94...
# Generating consensus for: 07010NABO-133...
# Generating consensus for: 07010NABO-147...
# Generating consensus for: 07010NABO-152...
# Generating consensus for: 07010NABO-159...
# Generating consensus for: 07010NABO-179...
# Generating consensus for: 07010NABO-185...
# Generating consensus for: 07010NABO-186...
# Generating consensus for: 07010NABO-190...
# Generating consensus for: 07010NABO-194...
# Generating consensus for: 07010NABO-195...
# Generating consensus for: 07010NABO-76...
# Generating consensus for: 07010NABO-78...
# Generating consensus for: 07010NABO-80...
# Generating consensus for: 07010NABO-85...
# Generating consensus for: 07010NABO-93...
# Generating consensus for: 07010NABO-131...
# Generating consensus for: 07010NABO-141...
# Generating consensus for: 07010NABO-142...
# Generating consensus for: 07010NABO-150...
# Generating consensus for: 07010NABO-165...
# Generating consensus for: 07010NABO-167...
# Generating consensus for: 07010NABO-169...
# Generating consensus for: 07010NABO-178...
# Generating consensus for: 07010NABO-181...
# Generating consensus for: 07010NABO-74...
# Generating consensus for: 07010NABO-75...
# Generating consensus for: 07010NABO-81...
# Generating consensus for: 07010NABO-89...
# Generating consensus for: 07010NABO-92...
# Generating consensus for: 07010NABO-101...
# Generating consensus for: 07010NABO-102...
# Generating consensus for: 07010NABO-107...
# Generating consensus for: 07010NABO-108...
# Generating consensus for: 07010NABO-135...
# Generating consensus for: 07010NABO-139...
# Generating consensus for: 07010NABO-141...
# Generating consensus for: 07010NABO-144...
# Generating consensus for: 07010NABO-146...
# Generating consensus for: 07010NABO-149...
# Generating consensus for: 07010NABO-165...
# Generating consensus for: 07010NABO-167...
# Generating consensus for: 07010NABO-172...
# Generating consensus for: 07010NABO-186...
# Generating consensus for: 07010NABO-192...
# Generating consensus for: 07010NABO-199...
# Generating consensus for: 07010NABO-137...
# Generating consensus for: 07010NABO-143...
# Generating consensus for: 07010NABO-145...
# Generating consensus for: 07010NABO-154...
# Generating consensus for: 07010NABO-157...
# Generating consensus for: 07010NABO-165...
# Generating consensus for: 07010NABO-168...
# Generating consensus for: 07010NABO-169...
# Generating consensus for: 07040DORE-70...
# Generating consensus for: 07040DORE-72...
# Generating consensus for: 07040DORE-73...
# Generating consensus for: 07040DORE-77...
# Generating consensus for: 07040DORE-87...
# Generating consensus for: 07040DORE-88...
# Generating consensus for: 07040DORE-95...
# Generating consensus for: 07040DORE-104...
# Generating consensus for: 07040DORE-105...
# Generating consensus for: 07040DORE-114...
# Generating consensus for: 07040DORE-116...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-153...
# Generating consensus for: 07040DORE-165...
# Generating consensus for: 07040DORE-173...
# Generating consensus for: 07040DORE-175...
# Generating consensus for: 07040DORE-180...
# Generating consensus for: 07040DORE-61...
# Generating consensus for: 07040DORE-62...
# Generating consensus for: 07040DORE-74...
# Generating consensus for: 07040DORE-77...
# Generating consensus for: 07040DORE-83...
# Generating consensus for: 07040DORE-87...
# Generating consensus for: 07040DORE-92...
# Generating consensus for: 07040DORE-99...
# Generating consensus for: 07040DORE-112...
# Generating consensus for: 07040DORE-117...
# Generating consensus for: 07040DORE-144...
# Generating consensus for: 07040DORE-147...
# Generating consensus for: 07040DORE-148...
# Generating consensus for: 07040DORE-157...
# Generating consensus for: 07040DORE-161...
# Generating consensus for: 07040DORE-163...
# Generating consensus for: 07040DORE-164...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-175...
# Generating consensus for: 07040DORE-179...
# Generating consensus for: 07040DORE-184...
# Generating consensus for: 07040DORE-189...
# Generating consensus for: 07040DORE-73...
# Generating consensus for: 07040DORE-77...
# Generating consensus for: 07040DORE-82...
# Generating consensus for: 07040DORE-85...
# Generating consensus for: 07040DORE-95...
# Generating consensus for: 07040DORE-105...
# Generating consensus for: 07040DORE-108...
# Generating consensus for: 07040DORE-110...
# Generating consensus for: 07040DORE-116...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-135...
# Generating consensus for: 07040DORE-138...
# Generating consensus for: 07040DORE-139...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-142...
# Generating consensus for: 07040DORE-168...
# Generating consensus for: 07040DORE-176...
# Generating consensus for: 07040DORE-69...
# Generating consensus for: 07040DORE-75...
# Generating consensus for: 07040DORE-78...
# Generating consensus for: 07040DORE-83...
# Generating consensus for: 07040DORE-91...
# Generating consensus for: 07040DORE-94...
# Generating consensus for: 07040DORE-96...
# Generating consensus for: 07040DORE-101...
# Generating consensus for: 07040DORE-110...
# Generating consensus for: 07040DORE-116...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-156...
# Generating consensus for: 07040DORE-157...
# Generating consensus for: 07040DORE-167...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-177...
# Generating consensus for: 07040DORE-179...
# Generating consensus for: 07040DORE-186...
# Generating consensus for: 07040DORE-62...
# Generating consensus for: 07040DORE-66...
# Generating consensus for: 07040DORE-67...
# Generating consensus for: 07040DORE-71...
# Generating consensus for: 07040DORE-88...
# Generating consensus for: 07040DORE-90...
# Generating consensus for: 07040DORE-91...
# Generating consensus for: 07040DORE-92...
# Generating consensus for: 07040DORE-95...
# Generating consensus for: 07040DORE-98...
# Generating consensus for: 07040DORE-105...
# Generating consensus for: 07040DORE-109...
# Generating consensus for: 07040DORE-115...
# Generating consensus for: 07040DORE-119...
# Generating consensus for: 07040DORE-120...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-145...
# Generating consensus for: 07040DORE-147...
# Generating consensus for: 07040DORE-151...
# Generating consensus for: 07040DORE-152...
# Generating consensus for: 07040DORE-159...
# Generating consensus for: 07040DORE-161...
# Generating consensus for: 07040DORE-162...
# Generating consensus for: 07040DORE-172...
# Generating consensus for: 07040DORE-178...
# Generating consensus for: 07040DORE-183...
# Generating consensus for: 07040DORE-185...
# Generating consensus for: 07040DORE-187...
# Generating consensus for: 07040DORE-188...
# Generating consensus for: 07040DORE-194...
# Generating consensus for: 07040DORE-65...
# Generating consensus for: 07040DORE-68...
# Generating consensus for: 07040DORE-88...
# Generating consensus for: 07040DORE-92...
# Generating consensus for: 07040DORE-104...
# Generating consensus for: 07040DORE-110...
# Generating consensus for: 07040DORE-118...
# Generating consensus for: 07040DORE-135...
# Generating consensus for: 07040DORE-136...
# Generating consensus for: 07040DORE-138...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-152...
# Generating consensus for: 07040DORE-162...
# Generating consensus for: 07040DORE-164...
# Generating consensus for: 07040DORE-165...
# Generating consensus for: 07040DORE-168...
# Generating consensus for: 07040DORE-169...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-177...
# Generating consensus for: 07040DORE-184...
# Generating consensus for: 07040DORE-185...
# Generating consensus for: 07040DORE-186...
# Generating consensus for: 07040DORE-187...
# Generating consensus for: 07040DORE-71...
# Generating consensus for: 07040DORE-76...
# Generating consensus for: 07040DORE-87...
# Generating consensus for: 07040DORE-90...
# Generating consensus for: 07040DORE-92...
# Generating consensus for: 07040DORE-97...
# Generating consensus for: 07040DORE-101...
# Generating consensus for: 07040DORE-103...
# Generating consensus for: 07040DORE-107...
# Generating consensus for: 07040DORE-110...
# Generating consensus for: 07040DORE-115...
# Generating consensus for: 07040DORE-148...
# Generating consensus for: 07040DORE-156...
# Generating consensus for: 07040DORE-157...
# Generating consensus for: 07040DORE-167...
# Generating consensus for: 07040DORE-169...
# Generating consensus for: 07040DORE-171...
# Generating consensus for: 07040DORE-176...
# Generating consensus for: 07040DORE-180...
# Generating consensus for: 07040DORE-181...
# Generating consensus for: 07040DORE-184...
# Generating consensus for: 07043SEME-87...
# Generating consensus for: 07043SEME-107...
# Generating consensus for: 07043SEME-109...
# Generating consensus for: 07043SEME-113...
# Generating consensus for: 08002CHJE-181...
# Generating consensus for: 08002CHJE-185...
# Generating consensus for: 08002CHJE-191...
# Generating consensus for: 08002CHJE-192...
# Generating consensus for: 08002CHJE-204...
# Generating consensus for: 08002CHJE-209...
# Generating consensus for: 08002CHJE-37...
# Generating consensus for: 08002CHJE-40...
# Generating consensus for: 08002CHJE-58...
# Generating consensus for: 08002CHJE-63...
# Generating consensus for: 08002CHJE-68...
# Generating consensus for: 08002CHJE-75...
# Generating consensus for: 08002CHJE-80...
# Generating consensus for: 08002CHJE-82...
# Generating consensus for: 08002CHJE-85...
# Generating consensus for: 08002CHJE-87...
# Generating consensus for: 08002CHJE-88...
# Generating consensus for: 08002CHJE-97...
# Generating consensus for: 08002CHJE-100...
# Generating consensus for: 08002CHJE-104...
# Generating consensus for: 08002CHJE-106...
# Generating consensus for: 08002CHJE-115...
# Generating consensus for: 08002CHJE-116...
# Generating consensus for: 08002CHJE-125...
# Generating consensus for: 08002CHJE-134...
# Generating consensus for: 08002CHJE-138...
# Generating consensus for: 08002CHJE-142...
# Generating consensus for: 08002CHJE-144...
# Generating consensus for: 08002CHJE-161...
# Generating consensus for: 08002CHJE-164...
# Generating consensus for: 08002CHJE-165...
# Generating consensus for: 08002CHJE-171...
# Generating consensus for: 08002CHJE-178...
# Generating consensus for: 08002CHJE-188...
# Generating consensus for: 08002CHJE-192...
# Generating consensus for: 08002CHJE-195...
# Generating consensus for: 08002CHJE-199...
# Generating consensus for: 08002CHJE-205...
# Generating consensus for: 08002CHJE-206...
# Generating consensus for: 08002CHJE-213...
# Generating consensus for: 08002CHJE-215...
# Generating consensus for: 08002CHJE-217...
# Generating consensus for: 08002CHJE-41...
# Generating consensus for: 08002CHJE-42...
# Generating consensus for: 08002CHJE-49...
# Generating consensus for: 08002CHJE-50...
# Generating consensus for: 08002CHJE-64...
# Generating consensus for: 08002CHJE-66...
# Generating consensus for: 08002CHJE-68...
# Generating consensus for: 08002CHJE-69...
# Generating consensus for: 08002CHJE-71...
# Generating consensus for: 08002CHJE-73...
# Generating consensus for: 08002CHJE-75...
# Generating consensus for: 08002CHJE-81...
# Generating consensus for: 08002CHJE-83...
# Generating consensus for: 08002CHJE-103...
# Generating consensus for: 08002CHJE-105...
# Generating consensus for: 08002CHJE-114...
# Generating consensus for: 08002CHJE-117...
# Generating consensus for: 08002CHJE-132...
# Generating consensus for: 08002CHJE-138...
# Generating consensus for: 08002CHJE-141...
# Generating consensus for: 08002CHJE-142...
# Generating consensus for: 08002CHJE-143...
# Generating consensus for: 08002CHJE-150...
# Generating consensus for: 08002CHJE-154...
# Generating consensus for: 08002CHJE-156...
# Generating consensus for: 08002CHJE-158...
# Generating consensus for: 08002CHJE-163...
# Generating consensus for: 08002CHJE-167...
# Generating consensus for: 08002CHJE-170...
# Generating consensus for: 08002CHJE-171...
# Generating consensus for: 08002CHJE-172...
# Generating consensus for: 08002CHJE-179...
# Generating consensus for: 08002CHJE-180...
# Generating consensus for: 08002CHJE-191...
# Generating consensus for: 08002CHJE-197...
# Generating consensus for: 08002CHJE-201...
# Generating consensus for: 08002CHJE-202...
# Generating consensus for: 08002CHJE-207...
# Generating consensus for: 08002CHJE-209...
# Generating consensus for: 08002CHJE-210...
# Generating consensus for: 08002CHJE-41...
# Generating consensus for: 08002CHJE-48...
# Generating consensus for: 08002CHJE-54...
# Generating consensus for: 08002CHJE-61...
# Generating consensus for: 08002CHJE-65...
# Generating consensus for: 08002CHJE-75...
# Generating consensus for: 08002CHJE-82...
# Generating consensus for: 08002CHJE-85...
# Generating consensus for: 08002CHJE-86...
# Generating consensus for: 08002CHJE-98...
# Generating consensus for: 08002CHJE-104...
# Generating consensus for: 08002CHJE-107...
# Generating consensus for: 08002CHJE-110...
# Generating consensus for: 08002CHJE-112...
# Generating consensus for: 08002CHJE-116...
# Generating consensus for: 08002CHJE-117...
# Generating consensus for: 08002CHJE-135...
# Generating consensus for: 08002CHJE-140...
# Generating consensus for: 08002CHJE-144...
# Generating consensus for: 08002CHJE-150...
# Generating consensus for: 08002CHJE-156...
# Generating consensus for: 08002CHJE-158...
# Generating consensus for: 08002CHJE-160...
# Generating consensus for: 08002CHJE-163...
# Generating consensus for: 08002CHJE-167...
# Generating consensus for: 08002CHJE-169...
# Generating consensus for: 08002CHJE-171...
# Generating consensus for: 08002CHJE-176...
# Generating consensus for: 08002CHJE-177...
# Generating consensus for: 08002CHJE-182...
# Generating consensus for: 08002CHJE-183...
# Generating consensus for: 08002CHJE-184...
# Generating consensus for: 08002CHJE-186...
# Generating consensus for: 08002CHJE-190...
# Generating consensus for: 08002CHJE-197...
# Generating consensus for: 08002CHJE-201...
# Generating consensus for: 08002CHJE-206...
# Generating consensus for: 08002CHJE-216...
# Generating consensus for: 08002CHJE-218...
# Generating consensus for: 08002CHJE-219...
# Generating consensus for: 08002CHJE-39...
# Generating consensus for: 08002CHJE-51...
# Generating consensus for: 08002CHJE-52...
# Generating consensus for: 08002CHJE-53...
# Generating consensus for: 08002CHJE-65...
# Generating consensus for: 08002CHJE-70...
# Generating consensus for: 08002CHJE-72...
# Generating consensus for: 08002CHJE-75...
# Generating consensus for: 08002CHJE-80...
# Generating consensus for: 08002CHJE-84...
# Generating consensus for: 08002CHJE-86...
# Generating consensus for: 08002CHJE-95...
# Generating consensus for: 08002CHJE-97...
# Generating consensus for: 08002CHJE-98...
# Generating consensus for: 08002CHJE-102...
# Generating consensus for: 08002CHJE-104...
# Generating consensus for: 08002CHJE-107...
# Generating consensus for: 08002CHJE-111...
# Generating consensus for: 08002CHJE-147...
# Generating consensus for: 08002CHJE-148...
# Generating consensus for: 08002CHJE-152...
# Generating consensus for: 08002CHJE-153...
# Generating consensus for: 08002CHJE-159...
# Generating consensus for: 08002CHJE-162...
# Generating consensus for: 08002CHJE-163...
# Generating consensus for: 08002CHJE-166...
# Generating consensus for: 08002CHJE-172...
# Generating consensus for: 08002CHJE-176...
# Generating consensus for: 08002CHJE-177...
# Generating consensus for: 08002CHJE-178...
# Generating consensus for: 08002CHJE-181...
# Generating consensus for: 08002CHJE-188...
# Generating consensus for: 08002CHJE-192...
# Generating consensus for: 08002CHJE-193...
# Generating consensus for: 08002CHJE-196...
# Generating consensus for: 08002CHJE-201...
# Generating consensus for: 08002CHJE-204...
# Generating consensus for: 08002CHJE-211...
# Generating consensus for: 08002CHJE-215...
# Generating consensus for: 08002CHJE-219...
# Generating consensus for: 08002CHJE-40...
# Generating consensus for: 08002CHJE-41...
# Generating consensus for: 08002CHJE-59...
# Generating consensus for: 08002CHJE-67...
# Generating consensus for: 08002CHJE-68...
# Generating consensus for: 08002CHJE-71...
# Generating consensus for: 08002CHJE-80...
# Generating consensus for: 08002CHJE-86...
# Generating consensus for: 08002CHJE-87...
# Generating consensus for: 08002CHJE-98...
# Generating consensus for: 08002CHJE-99...
# Generating consensus for: 08002CHJE-105...
# Generating consensus for: 08002CHJE-108...
# Generating consensus for: 08002CHJE-110...
# Generating consensus for: 08002CHJE-113...
# Generating consensus for: 08002CHJE-115...
# Generating consensus for: 08002CHJE-119...
# Generating consensus for: 08002CHJE-120...
# Generating consensus for: 08002CHJE-136...
# Generating consensus for: 08002CHJE-139...
# Generating consensus for: 08002CHJE-145...
# Generating consensus for: 08002CHJE-146...
# Generating consensus for: 08002CHJE-151...
# Generating consensus for: 08002CHJE-154...
# Generating consensus for: 08002CHJE-157...
# Generating consensus for: 08002CHJE-166...
# Generating consensus for: 08002CHJE-171...
# Generating consensus for: 08002CHJE-195...
# Generating consensus for: 08002CHJE-199...
# Generating consensus for: 08002CHJE-200...
# Generating consensus for: 08002CHJE-201...
# Generating consensus for: 08002CHJE-206...
# Generating consensus for: 08002CHJE-207...
# Generating consensus for: 08002CHJE-211...
# Generating consensus for: 08002CHJE-38...
# Generating consensus for: 08002CHJE-40...
# Generating consensus for: 08002CHJE-46...
# Generating consensus for: 08002CHJE-50...
# Generating consensus for: 08002CHJE-64...
# Generating consensus for: 08002CHJE-66...
# Generating consensus for: 08002CHJE-70...
# Generating consensus for: 08002CHJE-76...
# Generating consensus for: 08002CHJE-82...
# Generating consensus for: 08002CHJE-93...
# Generating consensus for: 08002CHJE-95...
# Generating consensus for: 08002CHJE-97...
# Generating consensus for: 08002CHJE-99...
# Generating consensus for: 08002CHJE-104...
# Generating consensus for: 08002CHJE-113...
# Generating consensus for: 08002CHJE-116...
# Generating consensus for: 08002CHJE-122...
# Generating consensus for: 08002CHJE-132...
# Generating consensus for: 08002CHJE-135...
# Generating consensus for: 08002CHJE-137...
# Generating consensus for: 08002CHJE-138...
# Generating consensus for: 08002CHJE-139...
# Generating consensus for: 08002CHJE-145...
# Generating consensus for: 08002CHJE-147...
# Generating consensus for: 08002CHJE-148...
# Generating consensus for: 08002CHJE-159...
# Generating consensus for: 08002CHJE-161...
# Generating consensus for: 08002CHJE-169...
# Generating consensus for: 08002CHJE-184...
# Generating consensus for: 08002CHJE-185...
# Generating consensus for: 08002CHJE-186...
# Generating consensus for: 08002CHJE-188...
# Generating consensus for: 08002CHJE-191...
# Generating consensus for: 08002CHJE-193...
# Generating consensus for: 08002CHJE-200...
# Generating consensus for: 08002CHJE-208...
