# %%
# !pip install SimpleITK

import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import re
import shutil
import random
# Out:
# Requirement already satisfied: SimpleITK in c:\users\f_alf\anaconda3\lib\site-packages (2.3.1)

# %%
def load_all_images(file):
    print(f'loading the {file} file...')
    
    ### LOAD SEGMENTATION FILES
    seg1_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_1.nii.gz')  
    seg2_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_2.nii.gz')  
    seg3_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_3.nii.gz')  
    seg4_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_4.nii.gz')  
    seg5_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_5.nii.gz') 
    seg6_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_6.nii.gz') 
    seg7_image = sitk.ReadImage(f'data/{file}/ManualSegmentation_7.nii.gz')

    ### LOAD 3D SCAN FILE
    flair_image = sitk.ReadImage(f'data/{file}/3DFLAIR.nii.gz')

    size = seg1_image.GetSize()

    caster = sitk.CastImageFilter()
    caster.SetOutputPixelType(sitk.sitkUInt8)

    ### FIND THE SLICES IN Z AXIS
    for z_slice in range(size[0]):
        # iterated slice of 3d image
        sliced_images = [
            seg1_image[z_slice, :, :],
            seg2_image[z_slice, :, :],
            seg3_image[z_slice, :, :],
            seg4_image[z_slice, :, :],
            seg5_image[z_slice, :, :],
            seg6_image[z_slice, :, :],
            seg7_image[z_slice, :, :]
        ]

        # get array from image slice
        sliced_arrays = [
            sitk.GetArrayFromImage(sliced_images[0]),
            sitk.GetArrayFromImage(sliced_images[1]),
            sitk.GetArrayFromImage(sliced_images[2]),
            sitk.GetArrayFromImage(sliced_images[3]),
            sitk.GetArrayFromImage(sliced_images[4]),
            sitk.GetArrayFromImage(sliced_images[5]),
            sitk.GetArrayFromImage(sliced_images[6])
        ]

        # same for the 3d image
        flair_slice_image = flair_image[z_slice, :, :]
        #flair_slice_array = sitk.GetArrayFromImage(flair_slice_image)

        for count, slice_array in enumerate(sliced_arrays):
            # if there are only zero values, skip
            non_zero_values = slice_array[slice_array != 0]
            if non_zero_values.size == 0:
                continue

            binary_mask = (slice_array > 0).astype(np.uint8)
            output_image = sitk.GetImageFromArray(binary_mask)

            # add origin, spacing, direction from original image
            output_image.SetOrigin(sliced_images[count].GetOrigin())
            output_image.SetSpacing(sliced_images[count].GetSpacing())
            output_image.SetDirection(sliced_images[count].GetDirection())

            # output image
            png_output_path = f'data/train/labels/{file}_seg{count+1}_{z_slice:03}.png'
            sitk.WriteImage(output_image, png_output_path)

            #output for the 3d image
            flair_slice_image = sitk.RescaleIntensity(flair_slice_image, 0, 255)
            flair_slice_image = caster.Execute(flair_slice_image)
            #output_image = sitk.GetImageFromArray(flair_slice_array.astype(np.uint8))
            #output_image.SetOrigin(flair_slice_image.GetOrigin())
            #output_image.SetSpacing(flair_slice_image.GetSpacing())
            #output_image.SetDirection(flair_slice_image.GetDirection())
            #png_output_path = f'data/train/images/{file}_{z_slice:03}.png'
            #sitk.WriteImage(flair_slice_image, png_output_path)
            #png_output_path = f'data/train/images_all/{file}_seg{count+1}_{z_slice:03}.png'
            #sitk.WriteImage(flair_slice_image, png_output_path)
            png_output_path = f'data/train/images/{file}_seg{count+1}_{z_slice:03}.png'
            sitk.WriteImage(flair_slice_image, png_output_path)

    print(f'...finished reading outputing the {file} file')

# %%
# loading images onto drive
load_all_images('01016SACH')
load_all_images('01040VANE')
load_all_images('07010NABO')
load_all_images('07040DORE')
# Out:
# loading the 01016SACH file...
# ...finished reading outputing the 01016SACH file
# loading the 01040VANE file...
# ...finished reading outputing the 01040VANE file
# loading the 07010NABO file...
# ...finished reading outputing the 07010NABO file
# loading the 07040DORE file...
# ...finished reading outputing the 07040DORE file

# %%
def move_related_files(source_dir1, source_dir2, dest_dir1, dest_dir2, percentage):
    files1 = os.listdir(source_dir1)
    files2 = os.listdir(source_dir2)

    os.makedirs(dest_dir1, exist_ok=True)
    os.makedirs(dest_dir2, exist_ok=True)

    num_files_to_move = int(min(len(files1), len(files2)) * (percentage / 100.0))

    files_to_move = random.sample(list(zip(files1, files2)), num_files_to_move)
    #print(files_to_move)

    for file_pair in files_to_move:
        file1, file2 = file_pair
        #print(f"Moving: {file1} and {file2}")
        source_path1 = os.path.join(source_dir1, file1)
        source_path2 = os.path.join(source_dir2, file2)
        dest_path1 = os.path.join(dest_dir1, file1)
        dest_path2 = os.path.join(dest_dir2, file2)

        try:
            shutil.move(source_path1, dest_path1)
            shutil.move(source_path2, dest_path2)
        except Exception as e:
            print(e)

        print(f"Moved: {file1} and {file2}")

# %%
# move some images and labels to test set
source_directory1 = "data/train/images"
source_directory2 = "data/train/labels"
destination_directory1 = "data/test/images"
destination_directory2 = "data/test/labels"
percentage_to_move = 20  # Adjust this percentage as needed
move_related_files(source_directory1, source_directory2, destination_directory1, destination_directory2, percentage_to_move)
# Out:
# Moved: 01040VANE_seg4_117.png and 01040VANE_seg4_117.png
# Moved: 01016SACH_seg2_208.png and 01016SACH_seg2_208.png
# Moved: 01016SACH_seg6_078.png and 01016SACH_seg6_078.png
# Moved: 07040DORE_seg1_152.png and 07040DORE_seg1_152.png
# Moved: 07010NABO_seg2_086.png and 07010NABO_seg2_086.png
# Moved: 01040VANE_seg4_180.png and 01040VANE_seg4_180.png
# Moved: 01040VANE_seg2_083.png and 01040VANE_seg2_083.png
# Moved: 01016SACH_seg7_186.png and 01016SACH_seg7_186.png
# Moved: 01016SACH_seg2_174.png and 01016SACH_seg2_174.png
# Moved: 07040DORE_seg5_083.png and 07040DORE_seg5_083.png
# Moved: 07010NABO_seg4_143.png and 07010NABO_seg4_143.png
# Moved: 07040DORE_seg1_084.png and 07040DORE_seg1_084.png
# Moved: 01016SACH_seg2_135.png and 01016SACH_seg2_135.png
# Moved: 07040DORE_seg1_063.png and 07040DORE_seg1_063.png
# Moved: 01040VANE_seg2_176.png and 01040VANE_seg2_176.png
# Moved: 01016SACH_seg7_174.png and 01016SACH_seg7_174.png
# Moved: 07010NABO_seg4_094.png and 07010NABO_seg4_094.png
# Moved: 01016SACH_seg5_079.png and 01016SACH_seg5_079.png
# Moved: 07010NABO_seg5_183.png and 07010NABO_seg5_183.png
# Moved: 07010NABO_seg3_159.png and 07010NABO_seg3_159.png
# Moved: 07040DORE_seg6_167.png and 07040DORE_seg6_167.png
# Moved: 07040DORE_seg4_075.png and 07040DORE_seg4_075.png
# Moved: 01016SACH_seg6_116.png and 01016SACH_seg6_116.png
# Moved: 01016SACH_seg6_166.png and 01016SACH_seg6_166.png
# Moved: 01040VANE_seg3_112.png and 01040VANE_seg3_112.png
# Moved: 01016SACH_seg7_115.png and 01016SACH_seg7_115.png
# Moved: 07010NABO_seg3_075.png and 07010NABO_seg3_075.png
# Moved: 01016SACH_seg2_083.png and 01016SACH_seg2_083.png
# Moved: 07010NABO_seg1_164.png and 07010NABO_seg1_164.png
# Moved: 07010NABO_seg2_097.png and 07010NABO_seg2_097.png
# Moved: 07040DORE_seg2_070.png and 07040DORE_seg2_070.png
# Moved: 07010NABO_seg6_150.png and 07010NABO_seg6_150.png
# Moved: 01016SACH_seg7_168.png and 01016SACH_seg7_168.png
# Moved: 01016SACH_seg6_072.png and 01016SACH_seg6_072.png
# Moved: 01016SACH_seg2_102.png and 01016SACH_seg2_102.png
# Moved: 01016SACH_seg4_057.png and 01016SACH_seg4_057.png
# Moved: 07040DORE_seg6_177.png and 07040DORE_seg6_177.png
# Moved: 07010NABO_seg7_088.png and 07010NABO_seg7_088.png
# Moved: 07040DORE_seg2_180.png and 07040DORE_seg2_180.png
# Moved: 01016SACH_seg3_053.png and 01016SACH_seg3_053.png
# Moved: 01016SACH_seg7_138.png and 01016SACH_seg7_138.png
# Moved: 07040DORE_seg4_105.png and 07040DORE_seg4_105.png
# Moved: 01016SACH_seg6_172.png and 01016SACH_seg6_172.png
# Moved: 01016SACH_seg7_060.png and 01016SACH_seg7_060.png
# Moved: 01016SACH_seg7_106.png and 01016SACH_seg7_106.png
# Moved: 07040DORE_seg7_159.png and 07040DORE_seg7_159.png
# Moved: 07040DORE_seg3_084.png and 07040DORE_seg3_084.png
# Moved: 01016SACH_seg3_088.png and 01016SACH_seg3_088.png
# Moved: 01040VANE_seg3_145.png and 01040VANE_seg3_145.png
# Moved: 07010NABO_seg3_152.png and 07010NABO_seg3_152.png
# Moved: 07010NABO_seg3_097.png and 07010NABO_seg3_097.png
# Moved: 07040DORE_seg6_086.png and 07040DORE_seg6_086.png
# Moved: 01016SACH_seg3_175.png and 01016SACH_seg3_175.png
# Moved: 07040DORE_seg1_145.png and 07040DORE_seg1_145.png
# Moved: 01016SACH_seg3_127.png and 01016SACH_seg3_127.png
# Moved: 07040DORE_seg4_155.png and 07040DORE_seg4_155.png
# Moved: 01016SACH_seg1_181.png and 01016SACH_seg1_181.png
# Moved: 01040VANE_seg4_103.png and 01040VANE_seg4_103.png
# Moved: 07040DORE_seg1_075.png and 07040DORE_seg1_075.png
# Moved: 01016SACH_seg7_167.png and 01016SACH_seg7_167.png
# Moved: 07040DORE_seg6_100.png and 07040DORE_seg6_100.png
# Moved: 01016SACH_seg2_170.png and 01016SACH_seg2_170.png
# Moved: 01040VANE_seg3_139.png and 01040VANE_seg3_139.png
# Moved: 01016SACH_seg6_064.png and 01016SACH_seg6_064.png
# Moved: 07010NABO_seg1_093.png and 07010NABO_seg1_093.png
# Moved: 07010NABO_seg4_140.png and 07010NABO_seg4_140.png
# Moved: 07010NABO_seg5_172.png and 07010NABO_seg5_172.png
# Moved: 01016SACH_seg3_142.png and 01016SACH_seg3_142.png
# Moved: 07010NABO_seg1_154.png and 07010NABO_seg1_154.png
# Moved: 01016SACH_seg5_154.png and 01016SACH_seg5_154.png
# Moved: 07010NABO_seg1_171.png and 07010NABO_seg1_171.png
# Moved: 01016SACH_seg1_124.png and 01016SACH_seg1_124.png
# Moved: 07010NABO_seg7_099.png and 07010NABO_seg7_099.png
# Moved: 01016SACH_seg4_093.png and 01016SACH_seg4_093.png
# Moved: 07040DORE_seg1_110.png and 07040DORE_seg1_110.png
# Moved: 07010NABO_seg3_103.png and 07010NABO_seg3_103.png
# Moved: 07040DORE_seg7_089.png and 07040DORE_seg7_089.png
# Moved: 01016SACH_seg1_156.png and 01016SACH_seg1_156.png
# Moved: 07010NABO_seg6_078.png and 07010NABO_seg6_078.png
# Moved: 01016SACH_seg2_052.png and 01016SACH_seg2_052.png
# Moved: 01040VANE_seg4_161.png and 01040VANE_seg4_161.png
# Moved: 07040DORE_seg2_170.png and 07040DORE_seg2_170.png
# Moved: 07040DORE_seg3_114.png and 07040DORE_seg3_114.png
# Moved: 07010NABO_seg3_136.png and 07010NABO_seg3_136.png
# Moved: 07010NABO_seg7_111.png and 07010NABO_seg7_111.png
# Moved: 07010NABO_seg3_165.png and 07010NABO_seg3_165.png
# Moved: 07040DORE_seg3_150.png and 07040DORE_seg3_150.png
# Moved: 01040VANE_seg3_097.png and 01040VANE_seg3_097.png
# Moved: 07010NABO_seg4_079.png and 07010NABO_seg4_079.png
# Moved: 01016SACH_seg7_188.png and 01016SACH_seg7_188.png
# Moved: 01016SACH_seg5_176.png and 01016SACH_seg5_176.png
# Moved: 01040VANE_seg6_054.png and 01040VANE_seg6_054.png
# Moved: 01040VANE_seg7_142.png and 01040VANE_seg7_142.png
# Moved: 01016SACH_seg6_153.png and 01016SACH_seg6_153.png
# Moved: 07010NABO_seg6_146.png and 07010NABO_seg6_146.png
# Moved: 07040DORE_seg6_118.png and 07040DORE_seg6_118.png
# Moved: 07040DORE_seg2_190.png and 07040DORE_seg2_190.png
# Moved: 07010NABO_seg6_148.png and 07010NABO_seg6_148.png
# Moved: 07010NABO_seg3_141.png and 07010NABO_seg3_141.png
# Moved: 01016SACH_seg1_211.png and 01016SACH_seg1_211.png
# Moved: 07040DORE_seg6_170.png and 07040DORE_seg6_170.png
# Moved: 07010NABO_seg1_172.png and 07010NABO_seg1_172.png
# Moved: 01016SACH_seg6_055.png and 01016SACH_seg6_055.png
# Moved: 07010NABO_seg5_174.png and 07010NABO_seg5_174.png
# Moved: 01016SACH_seg1_096.png and 01016SACH_seg1_096.png
# Moved: 01016SACH_seg7_140.png and 01016SACH_seg7_140.png
# Moved: 01040VANE_seg1_159.png and 01040VANE_seg1_159.png
# Moved: 01040VANE_seg7_164.png and 01040VANE_seg7_164.png
# Moved: 07040DORE_seg6_097.png and 07040DORE_seg6_097.png
# Moved: 01040VANE_seg6_050.png and 01040VANE_seg6_050.png
# Moved: 01016SACH_seg6_103.png and 01016SACH_seg6_103.png
# Moved: 07040DORE_seg6_085.png and 07040DORE_seg6_085.png
# Moved: 07010NABO_seg6_080.png and 07010NABO_seg6_080.png
# Moved: 07010NABO_seg1_087.png and 07010NABO_seg1_087.png
# Moved: 07040DORE_seg5_187.png and 07040DORE_seg5_187.png
# Moved: 01040VANE_seg7_108.png and 01040VANE_seg7_108.png
# Moved: 07010NABO_seg1_200.png and 07010NABO_seg1_200.png
# Moved: 07040DORE_seg7_176.png and 07040DORE_seg7_176.png
# Moved: 07040DORE_seg1_157.png and 07040DORE_seg1_157.png
# Moved: 01016SACH_seg3_109.png and 01016SACH_seg3_109.png
# Moved: 01016SACH_seg1_084.png and 01016SACH_seg1_084.png
# Moved: 07010NABO_seg6_102.png and 07010NABO_seg6_102.png
# Moved: 01040VANE_seg1_146.png and 01040VANE_seg1_146.png
# Moved: 07010NABO_seg5_086.png and 07010NABO_seg5_086.png
# Moved: 07040DORE_seg2_113.png and 07040DORE_seg2_113.png
# Moved: 01016SACH_seg6_149.png and 01016SACH_seg6_149.png
# Moved: 07040DORE_seg3_147.png and 07040DORE_seg3_147.png
# Moved: 01016SACH_seg7_184.png and 01016SACH_seg7_184.png
# Moved: 07040DORE_seg4_074.png and 07040DORE_seg4_074.png
# Moved: 01016SACH_seg2_105.png and 01016SACH_seg2_105.png
# Moved: 01016SACH_seg2_054.png and 01016SACH_seg2_054.png
# Moved: 07010NABO_seg4_076.png and 07010NABO_seg4_076.png
# Moved: 07010NABO_seg3_188.png and 07010NABO_seg3_188.png
# Moved: 07040DORE_seg5_074.png and 07040DORE_seg5_074.png
# Moved: 07040DORE_seg2_146.png and 07040DORE_seg2_146.png
# Moved: 07040DORE_seg7_151.png and 07040DORE_seg7_151.png
# Moved: 07010NABO_seg7_161.png and 07010NABO_seg7_161.png
# Moved: 07010NABO_seg7_154.png and 07010NABO_seg7_154.png
# Moved: 07040DORE_seg3_086.png and 07040DORE_seg3_086.png
# Moved: 01016SACH_seg7_072.png and 01016SACH_seg7_072.png
# Moved: 01016SACH_seg4_175.png and 01016SACH_seg4_175.png
# Moved: 01016SACH_seg5_111.png and 01016SACH_seg5_111.png
# Moved: 01016SACH_seg1_208.png and 01016SACH_seg1_208.png
# Moved: 01016SACH_seg6_058.png and 01016SACH_seg6_058.png
# Moved: 07040DORE_seg4_097.png and 07040DORE_seg4_097.png
# Moved: 01040VANE_seg1_105.png and 01040VANE_seg1_105.png
# Moved: 07040DORE_seg3_118.png and 07040DORE_seg3_118.png
# Moved: 01016SACH_seg4_096.png and 01016SACH_seg4_096.png
# Moved: 01040VANE_seg1_162.png and 01040VANE_seg1_162.png
# Moved: 01040VANE_seg1_147.png and 01040VANE_seg1_147.png
# Moved: 07010NABO_seg5_136.png and 07010NABO_seg5_136.png
# Moved: 07040DORE_seg2_083.png and 07040DORE_seg2_083.png
# Moved: 07010NABO_seg6_085.png and 07010NABO_seg6_085.png
# Moved: 01016SACH_seg1_121.png and 01016SACH_seg1_121.png
# Moved: 07040DORE_seg7_067.png and 07040DORE_seg7_067.png
# Moved: 07010NABO_seg2_083.png and 07010NABO_seg2_083.png
# Moved: 07040DORE_seg2_081.png and 07040DORE_seg2_081.png
# Moved: 07010NABO_seg3_102.png and 07010NABO_seg3_102.png
# Moved: 07010NABO_seg7_100.png and 07010NABO_seg7_100.png
# Moved: 01016SACH_seg7_068.png and 01016SACH_seg7_068.png
# Moved: 01016SACH_seg7_156.png and 01016SACH_seg7_156.png
# Moved: 01016SACH_seg4_078.png and 01016SACH_seg4_078.png
# Moved: 01016SACH_seg6_054.png and 01016SACH_seg6_054.png
# Moved: 01016SACH_seg1_134.png and 01016SACH_seg1_134.png
# Moved: 01016SACH_seg7_191.png and 01016SACH_seg7_191.png
# Moved: 07040DORE_seg3_096.png and 07040DORE_seg3_096.png
# Moved: 01016SACH_seg4_116.png and 01016SACH_seg4_116.png
# Moved: 01016SACH_seg3_212.png and 01016SACH_seg3_212.png
# Moved: 07010NABO_seg3_108.png and 07010NABO_seg3_108.png
# Moved: 01016SACH_seg6_191.png and 01016SACH_seg6_191.png
# Moved: 01016SACH_seg4_183.png and 01016SACH_seg4_183.png
# Moved: 01016SACH_seg7_145.png and 01016SACH_seg7_145.png
# Moved: 07040DORE_seg6_082.png and 07040DORE_seg6_082.png
# Moved: 07040DORE_seg1_143.png and 07040DORE_seg1_143.png
# Moved: 01016SACH_seg3_197.png and 01016SACH_seg3_197.png
# Moved: 07040DORE_seg6_076.png and 07040DORE_seg6_076.png
# Moved: 07040DORE_seg2_142.png and 07040DORE_seg2_142.png
# Moved: 07010NABO_seg3_182.png and 07010NABO_seg3_182.png
# Moved: 07040DORE_seg7_073.png and 07040DORE_seg7_073.png
# Moved: 07040DORE_seg6_157.png and 07040DORE_seg6_157.png
# Moved: 01016SACH_seg4_105.png and 01016SACH_seg4_105.png
# Moved: 01016SACH_seg5_090.png and 01016SACH_seg5_090.png
# Moved: 01016SACH_seg2_182.png and 01016SACH_seg2_182.png
# Moved: 07040DORE_seg3_145.png and 07040DORE_seg3_145.png
# Moved: 07040DORE_seg6_075.png and 07040DORE_seg6_075.png
# Moved: 01016SACH_seg3_133.png and 01016SACH_seg3_133.png
# Moved: 07040DORE_seg2_173.png and 07040DORE_seg2_173.png
# Moved: 01040VANE_seg5_083.png and 01040VANE_seg5_083.png
# Moved: 01016SACH_seg2_207.png and 01016SACH_seg2_207.png
# Moved: 01016SACH_seg6_119.png and 01016SACH_seg6_119.png
# Moved: 07010NABO_seg7_107.png and 07010NABO_seg7_107.png
# Moved: 07040DORE_seg4_099.png and 07040DORE_seg4_099.png
# Moved: 01016SACH_seg1_210.png and 01016SACH_seg1_210.png
# Moved: 07010NABO_seg2_089.png and 07010NABO_seg2_089.png
# Moved: 01016SACH_seg5_064.png and 01016SACH_seg5_064.png
# Moved: 07010NABO_seg4_073.png and 07010NABO_seg4_073.png
# Moved: 01016SACH_seg1_117.png and 01016SACH_seg1_117.png
# Moved: 07010NABO_seg1_147.png and 07010NABO_seg1_147.png
# Moved: 07040DORE_seg1_163.png and 07040DORE_seg1_163.png
# Moved: 01016SACH_seg2_073.png and 01016SACH_seg2_073.png
# Moved: 07010NABO_seg3_099.png and 07010NABO_seg3_099.png
# Moved: 07010NABO_seg2_106.png and 07010NABO_seg2_106.png
# Moved: 07010NABO_seg5_097.png and 07010NABO_seg5_097.png
# Moved: 07010NABO_seg5_098.png and 07010NABO_seg5_098.png
# Moved: 07010NABO_seg1_183.png and 07010NABO_seg1_183.png
# Moved: 01016SACH_seg1_133.png and 01016SACH_seg1_133.png
# Moved: 01040VANE_seg2_141.png and 01040VANE_seg2_141.png
# Moved: 01016SACH_seg4_066.png and 01016SACH_seg4_066.png
# Moved: 01040VANE_seg7_097.png and 01040VANE_seg7_097.png
# Moved: 07040DORE_seg5_179.png and 07040DORE_seg5_179.png
# Moved: 01040VANE_seg2_113.png and 01040VANE_seg2_113.png
# Moved: 01016SACH_seg4_174.png and 01016SACH_seg4_174.png
# Moved: 07010NABO_seg3_202.png and 07010NABO_seg3_202.png
# Moved: 01040VANE_seg7_094.png and 01040VANE_seg7_094.png
# Moved: 07040DORE_seg5_140.png and 07040DORE_seg5_140.png
# Moved: 07040DORE_seg2_108.png and 07040DORE_seg2_108.png
# Moved: 01040VANE_seg5_094.png and 01040VANE_seg5_094.png
# Moved: 01016SACH_seg5_186.png and 01016SACH_seg5_186.png
# Moved: 01016SACH_seg2_143.png and 01016SACH_seg2_143.png
# Moved: 07040DORE_seg2_158.png and 07040DORE_seg2_158.png
# Moved: 01016SACH_seg5_058.png and 01016SACH_seg5_058.png
# Moved: 01016SACH_seg5_215.png and 01016SACH_seg5_215.png
# Moved: 01040VANE_seg1_173.png and 01040VANE_seg1_173.png
# Moved: 07010NABO_seg6_149.png and 07010NABO_seg6_149.png
# Moved: 01016SACH_seg2_186.png and 01016SACH_seg2_186.png
# Moved: 01016SACH_seg4_121.png and 01016SACH_seg4_121.png
# Moved: 07040DORE_seg4_170.png and 07040DORE_seg4_170.png
# Moved: 01016SACH_seg2_117.png and 01016SACH_seg2_117.png
# Moved: 01016SACH_seg6_187.png and 01016SACH_seg6_187.png
# Moved: 01016SACH_seg6_190.png and 01016SACH_seg6_190.png
# Moved: 01016SACH_seg2_209.png and 01016SACH_seg2_209.png
# Moved: 07010NABO_seg1_142.png and 07010NABO_seg1_142.png
# Moved: 07010NABO_seg3_153.png and 07010NABO_seg3_153.png
# Moved: 07040DORE_seg5_121.png and 07040DORE_seg5_121.png
# Moved: 01040VANE_seg7_173.png and 01040VANE_seg7_173.png
# Moved: 07040DORE_seg2_152.png and 07040DORE_seg2_152.png
# Moved: 07040DORE_seg2_121.png and 07040DORE_seg2_121.png
# Moved: 07010NABO_seg1_178.png and 07010NABO_seg1_178.png
# Moved: 01016SACH_seg2_065.png and 01016SACH_seg2_065.png
# Moved: 07040DORE_seg4_072.png and 07040DORE_seg4_072.png
# Moved: 01016SACH_seg7_195.png and 01016SACH_seg7_195.png
# Moved: 01016SACH_seg7_139.png and 01016SACH_seg7_139.png
# Moved: 01016SACH_seg6_170.png and 01016SACH_seg6_170.png
# Moved: 01040VANE_seg5_109.png and 01040VANE_seg5_109.png
# Moved: 01040VANE_seg3_118.png and 01040VANE_seg3_118.png
# Moved: 07040DORE_seg1_165.png and 07040DORE_seg1_165.png
# Moved: 07010NABO_seg5_190.png and 07010NABO_seg5_190.png
# Moved: 01016SACH_seg4_101.png and 01016SACH_seg4_101.png
# Moved: 07040DORE_seg4_166.png and 07040DORE_seg4_166.png
# Moved: 01016SACH_seg6_096.png and 01016SACH_seg6_096.png
# Moved: 07010NABO_seg5_094.png and 07010NABO_seg5_094.png
# Moved: 07040DORE_seg5_065.png and 07040DORE_seg5_065.png
# Moved: 01016SACH_seg3_161.png and 01016SACH_seg3_161.png
# Moved: 07010NABO_seg1_184.png and 07010NABO_seg1_184.png
# Moved: 07010NABO_seg2_185.png and 07010NABO_seg2_185.png
# Moved: 07010NABO_seg6_099.png and 07010NABO_seg6_099.png
# Moved: 01016SACH_seg7_105.png and 01016SACH_seg7_105.png
# Moved: 01016SACH_seg4_095.png and 01016SACH_seg4_095.png
# Moved: 01016SACH_seg7_121.png and 01016SACH_seg7_121.png
# Moved: 07040DORE_seg5_095.png and 07040DORE_seg5_095.png
# Moved: 01016SACH_seg6_085.png and 01016SACH_seg6_085.png
# Moved: 01016SACH_seg6_134.png and 01016SACH_seg6_134.png
# Moved: 07040DORE_seg3_081.png and 07040DORE_seg3_081.png
# Moved: 07010NABO_seg5_080.png and 07010NABO_seg5_080.png
# Moved: 07010NABO_seg4_156.png and 07010NABO_seg4_156.png
# Moved: 07010NABO_seg4_170.png and 07010NABO_seg4_170.png
# Moved: 07010NABO_seg1_149.png and 07010NABO_seg1_149.png
# Moved: 01040VANE_seg7_118.png and 01040VANE_seg7_118.png
# Moved: 07040DORE_seg4_173.png and 07040DORE_seg4_173.png
# Moved: 07010NABO_seg2_168.png and 07010NABO_seg2_168.png
# Moved: 01040VANE_seg4_082.png and 01040VANE_seg4_082.png
# Moved: 07040DORE_seg6_144.png and 07040DORE_seg6_144.png
# Moved: 07040DORE_seg3_157.png and 07040DORE_seg3_157.png
# Moved: 07040DORE_seg1_172.png and 07040DORE_seg1_172.png
# Moved: 07040DORE_seg1_175.png and 07040DORE_seg1_175.png
# Moved: 01016SACH_seg7_124.png and 01016SACH_seg7_124.png
# Moved: 07040DORE_seg3_163.png and 07040DORE_seg3_163.png
# Moved: 07010NABO_seg5_075.png and 07010NABO_seg5_075.png
# Moved: 01016SACH_seg2_084.png and 01016SACH_seg2_084.png
# Moved: 07010NABO_seg7_132.png and 07010NABO_seg7_132.png
# Moved: 01016SACH_seg6_143.png and 01016SACH_seg6_143.png
# Moved: 01040VANE_seg1_106.png and 01040VANE_seg1_106.png
# Moved: 01016SACH_seg5_194.png and 01016SACH_seg5_194.png
# Moved: 01016SACH_seg4_197.png and 01016SACH_seg4_197.png
# Moved: 01016SACH_seg2_195.png and 01016SACH_seg2_195.png
# Moved: 01016SACH_seg6_140.png and 01016SACH_seg6_140.png
# Moved: 07040DORE_seg3_102.png and 07040DORE_seg3_102.png
# Moved: 01016SACH_seg6_101.png and 01016SACH_seg6_101.png
# Moved: 01016SACH_seg5_140.png and 01016SACH_seg5_140.png
# Moved: 07040DORE_seg2_182.png and 07040DORE_seg2_182.png
# Moved: 07040DORE_seg6_178.png and 07040DORE_seg6_178.png
# Moved: 01016SACH_seg5_156.png and 01016SACH_seg5_156.png
# Moved: 01016SACH_seg4_179.png and 01016SACH_seg4_179.png
# Moved: 07010NABO_seg5_198.png and 07010NABO_seg5_198.png
# Moved: 01016SACH_seg2_197.png and 01016SACH_seg2_197.png
# Moved: 07040DORE_seg1_144.png and 07040DORE_seg1_144.png
# Moved: 01016SACH_seg5_076.png and 01016SACH_seg5_076.png
# Moved: 01040VANE_seg4_145.png and 01040VANE_seg4_145.png
# Moved: 01016SACH_seg2_088.png and 01016SACH_seg2_088.png
# Moved: 07040DORE_seg7_150.png and 07040DORE_seg7_150.png
# Moved: 01016SACH_seg6_142.png and 01016SACH_seg6_142.png
# Moved: 01040VANE_seg5_159.png and 01040VANE_seg5_159.png
# Moved: 01016SACH_seg6_076.png and 01016SACH_seg6_076.png
# Moved: 01040VANE_seg2_156.png and 01040VANE_seg2_156.png
# Moved: 01016SACH_seg7_113.png and 01016SACH_seg7_113.png
# Moved: 01040VANE_seg2_166.png and 01040VANE_seg2_166.png
# Moved: 01016SACH_seg3_072.png and 01016SACH_seg3_072.png
# Moved: 01016SACH_seg5_152.png and 01016SACH_seg5_152.png
# Moved: 01016SACH_seg4_089.png and 01016SACH_seg4_089.png
# Moved: 07040DORE_seg7_083.png and 07040DORE_seg7_083.png
# Moved: 01016SACH_seg7_092.png and 01016SACH_seg7_092.png
# Moved: 01016SACH_seg6_183.png and 01016SACH_seg6_183.png
# Moved: 01016SACH_seg4_146.png and 01016SACH_seg4_146.png
# Moved: 01016SACH_seg1_195.png and 01016SACH_seg1_195.png
# Moved: 07010NABO_seg2_111.png and 07010NABO_seg2_111.png
# Moved: 01040VANE_seg5_107.png and 01040VANE_seg5_107.png
# Moved: 07040DORE_seg2_179.png and 07040DORE_seg2_179.png
# Moved: 07010NABO_seg5_186.png and 07010NABO_seg5_186.png
# Moved: 01016SACH_seg6_150.png and 01016SACH_seg6_150.png
# Moved: 01016SACH_seg2_178.png and 01016SACH_seg2_178.png
# Moved: 01016SACH_seg4_122.png and 01016SACH_seg4_122.png
# Moved: 07010NABO_seg4_160.png and 07010NABO_seg4_160.png
# Moved: 07040DORE_seg6_169.png and 07040DORE_seg6_169.png
# Moved: 01016SACH_seg5_193.png and 01016SACH_seg5_193.png
# Moved: 01040VANE_seg4_104.png and 01040VANE_seg4_104.png
# Moved: 01040VANE_seg5_162.png and 01040VANE_seg5_162.png
# Moved: 07010NABO_seg5_189.png and 07010NABO_seg5_189.png
# Moved: 07010NABO_seg2_154.png and 07010NABO_seg2_154.png
# Moved: 07010NABO_seg6_082.png and 07010NABO_seg6_082.png
# Moved: 01016SACH_seg1_101.png and 01016SACH_seg1_101.png
# Moved: 01016SACH_seg4_102.png and 01016SACH_seg4_102.png
# Moved: 07010NABO_seg4_183.png and 07010NABO_seg4_183.png
# Moved: 07010NABO_seg3_105.png and 07010NABO_seg3_105.png
# Moved: 07040DORE_seg5_153.png and 07040DORE_seg5_153.png
# Moved: 07040DORE_seg5_088.png and 07040DORE_seg5_088.png
# Moved: 07010NABO_seg7_148.png and 07010NABO_seg7_148.png
# Moved: 01040VANE_seg6_056.png and 01040VANE_seg6_056.png
# Moved: 07040DORE_seg5_077.png and 07040DORE_seg5_077.png
# Moved: 07040DORE_seg1_115.png and 07040DORE_seg1_115.png
# Moved: 07040DORE_seg6_164.png and 07040DORE_seg6_164.png
# Moved: 07040DORE_seg3_108.png and 07040DORE_seg3_108.png
# Moved: 07040DORE_seg4_062.png and 07040DORE_seg4_062.png
# Moved: 01016SACH_seg4_110.png and 01016SACH_seg4_110.png
# Moved: 07010NABO_seg3_082.png and 07010NABO_seg3_082.png
# Moved: 01040VANE_seg3_177.png and 01040VANE_seg3_177.png
# Moved: 01040VANE_seg4_168.png and 01040VANE_seg4_168.png
# Moved: 01016SACH_seg4_133.png and 01016SACH_seg4_133.png
# Moved: 01016SACH_seg1_063.png and 01016SACH_seg1_063.png
# Moved: 01016SACH_seg3_125.png and 01016SACH_seg3_125.png
# Moved: 01040VANE_seg1_093.png and 01040VANE_seg1_093.png
# Moved: 07040DORE_seg4_109.png and 07040DORE_seg4_109.png
# Moved: 07010NABO_seg3_154.png and 07010NABO_seg3_154.png
# Moved: 07040DORE_seg7_100.png and 07040DORE_seg7_100.png
# Moved: 01016SACH_seg3_134.png and 01016SACH_seg3_134.png
# Moved: 07040DORE_seg6_155.png and 07040DORE_seg6_155.png
# Moved: 01016SACH_seg7_053.png and 01016SACH_seg7_053.png
# Moved: 07040DORE_seg6_152.png and 07040DORE_seg6_152.png
# Moved: 07040DORE_seg3_167.png and 07040DORE_seg3_167.png
# Moved: 07010NABO_seg1_076.png and 07010NABO_seg1_076.png
# Moved: 01040VANE_seg4_115.png and 01040VANE_seg4_115.png
# Moved: 07010NABO_seg2_076.png and 07010NABO_seg2_076.png
# Moved: 01040VANE_seg2_157.png and 01040VANE_seg2_157.png
# Moved: 01016SACH_seg1_114.png and 01016SACH_seg1_114.png
# Moved: 07010NABO_seg4_150.png and 07010NABO_seg4_150.png
# Moved: 07010NABO_seg4_092.png and 07010NABO_seg4_092.png
# Moved: 01016SACH_seg4_157.png and 01016SACH_seg4_157.png
# Moved: 01016SACH_seg6_198.png and 01016SACH_seg6_198.png
# Moved: 07040DORE_seg1_170.png and 07040DORE_seg1_170.png
# Moved: 01016SACH_seg3_103.png and 01016SACH_seg3_103.png
# Moved: 01016SACH_seg1_132.png and 01016SACH_seg1_132.png
# Moved: 07040DORE_seg6_074.png and 07040DORE_seg6_074.png
# Moved: 07010NABO_seg2_092.png and 07010NABO_seg2_092.png
# Moved: 07010NABO_seg2_081.png and 07010NABO_seg2_081.png
# Moved: 01016SACH_seg6_059.png and 01016SACH_seg6_059.png
# Moved: 01040VANE_seg7_090.png and 01040VANE_seg7_090.png
# Moved: 07040DORE_seg1_112.png and 07040DORE_seg1_112.png
# Moved: 01016SACH_seg5_166.png and 01016SACH_seg5_166.png
# Moved: 07040DORE_seg7_186.png and 07040DORE_seg7_186.png
# Moved: 01016SACH_seg1_142.png and 01016SACH_seg1_142.png
# Moved: 01040VANE_seg6_103.png and 01040VANE_seg6_103.png
# Moved: 07040DORE_seg3_143.png and 07040DORE_seg3_143.png
# Moved: 07040DORE_seg7_080.png and 07040DORE_seg7_080.png
# Moved: 07010NABO_seg7_135.png and 07010NABO_seg7_135.png
# Moved: 01016SACH_seg1_178.png and 01016SACH_seg1_178.png
# Moved: 07040DORE_seg6_090.png and 07040DORE_seg6_090.png
# Moved: 07040DORE_seg3_165.png and 07040DORE_seg3_165.png
# Moved: 07040DORE_seg1_159.png and 07040DORE_seg1_159.png
# Moved: 01040VANE_seg7_162.png and 01040VANE_seg7_162.png
# Moved: 07040DORE_seg5_141.png and 07040DORE_seg5_141.png
# Moved: 07010NABO_seg2_085.png and 07010NABO_seg2_085.png
# Moved: 07040DORE_seg7_106.png and 07040DORE_seg7_106.png
# Moved: 07010NABO_seg3_166.png and 07010NABO_seg3_166.png
# Moved: 07040DORE_seg5_192.png and 07040DORE_seg5_192.png
# Moved: 01016SACH_seg1_086.png and 01016SACH_seg1_086.png
# Moved: 01016SACH_seg4_074.png and 01016SACH_seg4_074.png
# Moved: 01016SACH_seg4_166.png and 01016SACH_seg4_166.png
# Moved: 07010NABO_seg2_096.png and 07010NABO_seg2_096.png
# Moved: 07040DORE_seg6_102.png and 07040DORE_seg6_102.png
# Moved: 07010NABO_seg6_104.png and 07010NABO_seg6_104.png
# Moved: 07040DORE_seg3_083.png and 07040DORE_seg3_083.png
# Moved: 07040DORE_seg1_141.png and 07040DORE_seg1_141.png
# Moved: 01016SACH_seg7_088.png and 01016SACH_seg7_088.png
# Moved: 07010NABO_seg3_200.png and 07010NABO_seg3_200.png
# Moved: 01040VANE_seg3_104.png and 01040VANE_seg3_104.png
# Moved: 01016SACH_seg5_078.png and 01016SACH_seg5_078.png
# Moved: 07040DORE_seg2_189.png and 07040DORE_seg2_189.png
# Moved: 01016SACH_seg1_184.png and 01016SACH_seg1_184.png
# Moved: 01016SACH_seg5_112.png and 01016SACH_seg5_112.png
# Moved: 01016SACH_seg1_176.png and 01016SACH_seg1_176.png
# Moved: 01040VANE_seg4_136.png and 01040VANE_seg4_136.png
# Moved: 01016SACH_seg6_062.png and 01016SACH_seg6_062.png
# Moved: 07040DORE_seg2_080.png and 07040DORE_seg2_080.png
# Moved: 01040VANE_seg7_163.png and 01040VANE_seg7_163.png
# Moved: 01016SACH_seg2_162.png and 01016SACH_seg2_162.png
# Moved: 07040DORE_seg4_141.png and 07040DORE_seg4_141.png
# Moved: 01016SACH_seg2_119.png and 01016SACH_seg2_119.png
# Moved: 07010NABO_seg4_134.png and 07010NABO_seg4_134.png
# Moved: 07040DORE_seg6_184.png and 07040DORE_seg6_184.png
# Moved: 01016SACH_seg5_085.png and 01016SACH_seg5_085.png
# Moved: 07010NABO_seg7_091.png and 07010NABO_seg7_091.png
# Moved: 07040DORE_seg2_066.png and 07040DORE_seg2_066.png
# Moved: 01016SACH_seg7_196.png and 01016SACH_seg7_196.png
# Moved: 07010NABO_seg6_142.png and 07010NABO_seg6_142.png
# Moved: 07040DORE_seg1_070.png and 07040DORE_seg1_070.png
# Moved: 07010NABO_seg7_147.png and 07010NABO_seg7_147.png
# Moved: 01040VANE_seg4_091.png and 01040VANE_seg4_091.png
# Moved: 01040VANE_seg2_152.png and 01040VANE_seg2_152.png
# Moved: 07010NABO_seg4_090.png and 07010NABO_seg4_090.png
# Moved: 07040DORE_seg5_110.png and 07040DORE_seg5_110.png
# Moved: 01016SACH_seg3_177.png and 01016SACH_seg3_177.png
# Moved: 07010NABO_seg2_098.png and 07010NABO_seg2_098.png
# Moved: 01016SACH_seg1_073.png and 01016SACH_seg1_073.png
# Moved: 01016SACH_seg4_143.png and 01016SACH_seg4_143.png
# Moved: 01016SACH_seg6_152.png and 01016SACH_seg6_152.png
# Moved: 01040VANE_seg4_137.png and 01040VANE_seg4_137.png
# Moved: 07040DORE_seg2_062.png and 07040DORE_seg2_062.png
# Moved: 07010NABO_seg1_202.png and 07010NABO_seg1_202.png
# Moved: 01040VANE_seg1_152.png and 01040VANE_seg1_152.png
# Moved: 01016SACH_seg3_059.png and 01016SACH_seg3_059.png
# Moved: 07040DORE_seg1_196.png and 07040DORE_seg1_196.png
# Moved: 07040DORE_seg4_121.png and 07040DORE_seg4_121.png
# Moved: 07010NABO_seg5_073.png and 07010NABO_seg5_073.png
# Moved: 01016SACH_seg2_159.png and 01016SACH_seg2_159.png
# Moved: 01040VANE_seg1_172.png and 01040VANE_seg1_172.png
# Moved: 07010NABO_seg4_093.png and 07010NABO_seg4_093.png
# Moved: 07040DORE_seg6_070.png and 07040DORE_seg6_070.png
# Moved: 01016SACH_seg2_156.png and 01016SACH_seg2_156.png
# Moved: 01016SACH_seg4_170.png and 01016SACH_seg4_170.png
# Moved: 01040VANE_seg3_173.png and 01040VANE_seg3_173.png
# Moved: 07010NABO_seg4_155.png and 07010NABO_seg4_155.png
# Moved: 01016SACH_seg3_208.png and 01016SACH_seg3_208.png
# Moved: 01040VANE_seg6_161.png and 01040VANE_seg6_161.png
# Moved: 01016SACH_seg5_144.png and 01016SACH_seg5_144.png
# Moved: 01016SACH_seg5_192.png and 01016SACH_seg5_192.png
# Moved: 07010NABO_seg2_181.png and 07010NABO_seg2_181.png
# Moved: 07040DORE_seg2_147.png and 07040DORE_seg2_147.png
# Moved: 01016SACH_seg7_112.png and 01016SACH_seg7_112.png
# Moved: 01016SACH_seg3_079.png and 01016SACH_seg3_079.png
# Moved: 07010NABO_seg7_086.png and 07010NABO_seg7_086.png
# Moved: 01016SACH_seg7_082.png and 01016SACH_seg7_082.png
# Moved: 01016SACH_seg2_072.png and 01016SACH_seg2_072.png
# Moved: 07040DORE_seg4_091.png and 07040DORE_seg4_091.png
# Moved: 01016SACH_seg5_145.png and 01016SACH_seg5_145.png
# Moved: 01016SACH_seg5_099.png and 01016SACH_seg5_099.png
# Moved: 07040DORE_seg2_063.png and 07040DORE_seg2_063.png
# Moved: 07040DORE_seg5_112.png and 07040DORE_seg5_112.png
# Moved: 01016SACH_seg4_053.png and 01016SACH_seg4_053.png
# Moved: 07040DORE_seg2_073.png and 07040DORE_seg2_073.png
# Moved: 07040DORE_seg2_143.png and 07040DORE_seg2_143.png
# Moved: 07010NABO_seg3_199.png and 07010NABO_seg3_199.png
# Moved: 01040VANE_seg6_052.png and 01040VANE_seg6_052.png
# Moved: 07040DORE_seg4_172.png and 07040DORE_seg4_172.png
# Moved: 07040DORE_seg2_166.png and 07040DORE_seg2_166.png
# Moved: 01016SACH_seg3_174.png and 01016SACH_seg3_174.png
# Moved: 01016SACH_seg6_182.png and 01016SACH_seg6_182.png
# Moved: 01016SACH_seg3_064.png and 01016SACH_seg3_064.png
# Moved: 01040VANE_seg5_175.png and 01040VANE_seg5_175.png
# Moved: 01016SACH_seg1_087.png and 01016SACH_seg1_087.png
# Moved: 01016SACH_seg1_103.png and 01016SACH_seg1_103.png
# Moved: 01040VANE_seg7_112.png and 01040VANE_seg7_112.png
# Moved: 01016SACH_seg6_127.png and 01016SACH_seg6_127.png
# Moved: 01040VANE_seg7_105.png and 01040VANE_seg7_105.png
# Moved: 01040VANE_seg6_202.png and 01040VANE_seg6_202.png
# Moved: 01040VANE_seg5_172.png and 01040VANE_seg5_172.png
# Moved: 01016SACH_seg2_157.png and 01016SACH_seg2_157.png
# Moved: 07040DORE_seg2_163.png and 07040DORE_seg2_163.png
# Moved: 01016SACH_seg4_117.png and 01016SACH_seg4_117.png
# Moved: 07040DORE_seg3_154.png and 07040DORE_seg3_154.png
# Moved: 07040DORE_seg4_149.png and 07040DORE_seg4_149.png
# Moved: 01040VANE_seg7_104.png and 01040VANE_seg7_104.png
# Moved: 01016SACH_seg3_192.png and 01016SACH_seg3_192.png
# Moved: 01016SACH_seg3_209.png and 01016SACH_seg3_209.png
# Moved: 01016SACH_seg3_111.png and 01016SACH_seg3_111.png
# Moved: 01016SACH_seg2_196.png and 01016SACH_seg2_196.png
# Moved: 07040DORE_seg1_068.png and 07040DORE_seg1_068.png
# Moved: 01040VANE_seg3_142.png and 01040VANE_seg3_142.png
# Moved: 01040VANE_seg2_177.png and 01040VANE_seg2_177.png
# Moved: 07040DORE_seg1_155.png and 07040DORE_seg1_155.png
# Moved: 01040VANE_seg5_090.png and 01040VANE_seg5_090.png
# Moved: 01040VANE_seg7_161.png and 01040VANE_seg7_161.png
# Moved: 07040DORE_seg6_160.png and 07040DORE_seg6_160.png
# Moved: 07010NABO_seg5_156.png and 07010NABO_seg5_156.png
# Moved: 01040VANE_seg1_092.png and 01040VANE_seg1_092.png
# Moved: 01040VANE_seg4_089.png and 01040VANE_seg4_089.png
# Moved: 01016SACH_seg6_184.png and 01016SACH_seg6_184.png
# Moved: 07010NABO_seg4_153.png and 07010NABO_seg4_153.png
# Moved: 01040VANE_seg2_080.png and 01040VANE_seg2_080.png
# Moved: 01016SACH_seg2_193.png and 01016SACH_seg2_193.png
# Moved: 07010NABO_seg6_158.png and 07010NABO_seg6_158.png
# Moved: 07040DORE_seg6_087.png and 07040DORE_seg6_087.png
# Moved: 01016SACH_seg7_175.png and 01016SACH_seg7_175.png
# Moved: 07010NABO_seg3_193.png and 07010NABO_seg3_193.png
# Moved: 01016SACH_seg7_077.png and 01016SACH_seg7_077.png
# Moved: 01016SACH_seg4_152.png and 01016SACH_seg4_152.png
# Moved: 01040VANE_seg6_105.png and 01040VANE_seg6_105.png
# Moved: 01016SACH_seg4_064.png and 01016SACH_seg4_064.png
# Moved: 01016SACH_seg6_176.png and 01016SACH_seg6_176.png
# Moved: 01040VANE_seg6_164.png and 01040VANE_seg6_164.png
# Moved: 01016SACH_seg3_108.png and 01016SACH_seg3_108.png
# Moved: 07040DORE_seg6_141.png and 07040DORE_seg6_141.png
# Moved: 07010NABO_seg2_073.png and 07010NABO_seg2_073.png
# Moved: 01040VANE_seg5_106.png and 01040VANE_seg5_106.png
# Moved: 07010NABO_seg3_134.png and 07010NABO_seg3_134.png
# Moved: 07040DORE_seg6_172.png and 07040DORE_seg6_172.png
# Moved: 07010NABO_seg5_082.png and 07010NABO_seg5_082.png
# Moved: 07010NABO_seg6_089.png and 07010NABO_seg6_089.png
# Moved: 01040VANE_seg5_085.png and 01040VANE_seg5_085.png
# Moved: 01016SACH_seg7_061.png and 01016SACH_seg7_061.png
# Moved: 07040DORE_seg5_107.png and 07040DORE_seg5_107.png
# Moved: 01016SACH_seg3_082.png and 01016SACH_seg3_082.png
# Moved: 01016SACH_seg2_177.png and 01016SACH_seg2_177.png
# Moved: 07010NABO_seg5_163.png and 07010NABO_seg5_163.png
# Moved: 07040DORE_seg5_161.png and 07040DORE_seg5_161.png
# Moved: 07010NABO_seg4_167.png and 07010NABO_seg4_167.png
# Moved: 01016SACH_seg5_062.png and 01016SACH_seg5_062.png
# Moved: 01016SACH_seg6_083.png and 01016SACH_seg6_083.png
# Moved: 07010NABO_seg7_146.png and 07010NABO_seg7_146.png
# Moved: 07040DORE_seg5_173.png and 07040DORE_seg5_173.png
# Moved: 01016SACH_seg1_145.png and 01016SACH_seg1_145.png
# Moved: 07040DORE_seg3_161.png and 07040DORE_seg3_161.png
# Moved: 01040VANE_seg4_140.png and 01040VANE_seg4_140.png
# Moved: 01016SACH_seg6_165.png and 01016SACH_seg6_165.png
# Moved: 01016SACH_seg2_063.png and 01016SACH_seg2_063.png
# Moved: 07010NABO_seg3_078.png and 07010NABO_seg3_078.png
# Moved: 07040DORE_seg1_191.png and 07040DORE_seg1_191.png
# Moved: 07010NABO_seg6_095.png and 07010NABO_seg6_095.png
# Moved: 01016SACH_seg6_144.png and 01016SACH_seg6_144.png
# Moved: 01040VANE_seg6_201.png and 01040VANE_seg6_201.png
# Moved: 01040VANE_seg6_091.png and 01040VANE_seg6_091.png
# Moved: 07040DORE_seg3_101.png and 07040DORE_seg3_101.png
# Moved: 07010NABO_seg6_076.png and 07010NABO_seg6_076.png
# Moved: 07010NABO_seg5_180.png and 07010NABO_seg5_180.png
# Moved: 01016SACH_seg5_118.png and 01016SACH_seg5_118.png
# Moved: 07010NABO_seg5_196.png and 07010NABO_seg5_196.png
# Moved: 07010NABO_seg3_083.png and 07010NABO_seg3_083.png
# Moved: 07010NABO_seg7_077.png and 07010NABO_seg7_077.png
# Moved: 07010NABO_seg5_144.png and 07010NABO_seg5_144.png
# Moved: 07040DORE_seg5_160.png and 07040DORE_seg5_160.png
# Moved: 07040DORE_seg4_120.png and 07040DORE_seg4_120.png
# Moved: 07040DORE_seg6_187.png and 07040DORE_seg6_187.png
# Moved: 07010NABO_seg1_160.png and 07010NABO_seg1_160.png
# Moved: 01016SACH_seg6_128.png and 01016SACH_seg6_128.png
# Moved: 01016SACH_seg4_103.png and 01016SACH_seg4_103.png
# Moved: 01016SACH_seg4_171.png and 01016SACH_seg4_171.png
# Moved: 07040DORE_seg7_146.png and 07040DORE_seg7_146.png
# Moved: 01040VANE_seg3_150.png and 01040VANE_seg3_150.png
# Moved: 07040DORE_seg4_118.png and 07040DORE_seg4_118.png
# Moved: 07040DORE_seg4_073.png and 07040DORE_seg4_073.png
# Moved: 01040VANE_seg7_095.png and 01040VANE_seg7_095.png
# Moved: 01016SACH_seg2_172.png and 01016SACH_seg2_172.png
# Moved: 07040DORE_seg4_084.png and 07040DORE_seg4_084.png
# Moved: 07040DORE_seg7_117.png and 07040DORE_seg7_117.png
# Moved: 01040VANE_seg4_102.png and 01040VANE_seg4_102.png
# Moved: 01040VANE_seg2_109.png and 01040VANE_seg2_109.png
# Moved: 01016SACH_seg2_175.png and 01016SACH_seg2_175.png
# Moved: 01016SACH_seg1_151.png and 01016SACH_seg1_151.png
# Moved: 07040DORE_seg1_177.png and 07040DORE_seg1_177.png
# Moved: 07040DORE_seg1_100.png and 07040DORE_seg1_100.png
# Moved: 01016SACH_seg5_210.png and 01016SACH_seg5_210.png
# Moved: 07010NABO_seg4_135.png and 07010NABO_seg4_135.png
# Moved: 07010NABO_seg6_154.png and 07010NABO_seg6_154.png
# Moved: 01040VANE_seg7_113.png and 01040VANE_seg7_113.png
# Moved: 01040VANE_seg3_175.png and 01040VANE_seg3_175.png
# Moved: 07040DORE_seg6_140.png and 07040DORE_seg6_140.png
# Moved: 01016SACH_seg2_216.png and 01016SACH_seg2_216.png
# Moved: 01016SACH_seg6_139.png and 01016SACH_seg6_139.png
# Moved: 01016SACH_seg6_121.png and 01016SACH_seg6_121.png
# Moved: 07040DORE_seg7_092.png and 07040DORE_seg7_092.png
# Moved: 01016SACH_seg1_189.png and 01016SACH_seg1_189.png
# Moved: 07040DORE_seg4_185.png and 07040DORE_seg4_185.png
# Moved: 01016SACH_seg1_060.png and 01016SACH_seg1_060.png

# %%
def generate_consensus_labels():
    image_path = 'data/test/images'
    label_path = 'data/test/labels'
    
    caster = sitk.CastImageFilter()
    caster.SetOutputPixelType(sitk.sitkUInt8)

    # Iterate over all files in the folder
    for filename in os.listdir(image_path):
        file_path = os.path.join(image_path, filename)

        # Check if it's a file (not a subdirectory)
        if os.path.isfile(file_path):
            # Extract information using regex
            parts = filename.split('_')

            if len(parts) == 3:
                # Extract imageName and slice number
                imageName, fileType, slice_extension = parts
                sliceNumber, extension = slice_extension.split('.')
                sliceNumber = int(sliceNumber.lstrip('0'))
                
                print(f"Generating consensus for: {imageName}-{sliceNumber}...")
                
                ### LOAD SEGMENTATION FILES
                con_image = sitk.ReadImage(f'data/{imageName}/Consensus.nii.gz')
                
                sliced_image = con_image[sliceNumber, :, :]
                sliced_array = sitk.GetArrayFromImage(sliced_image)
                
                binary_mask = (sliced_array > 0).astype(np.uint8)
                output_image = sitk.GetImageFromArray(binary_mask)
                
                output_image.SetOrigin(sliced_image.GetOrigin())
                output_image.SetSpacing(sliced_image.GetSpacing())
                output_image.SetDirection(sliced_image.GetDirection())
                
                sliceNumber = str(sliceNumber).zfill(3)
                png_output_path = f'{label_path}/{imageName}_{sliceNumber}.png'
                sitk.WriteImage(output_image, png_output_path)
                
                file_path_to_delete = f'{label_path}/{imageName}_{fileType}_{sliceNumber}.{extension}'
                if os.path.exists(file_path_to_delete):
                    os.remove(file_path_to_delete)

                # Create the new file name without {type}
                new_filename = f'{imageName}_{sliceNumber}.{extension}'  # Adjust the file extension if needed
                if not os.path.exists(os.path.join(image_path, new_filename)):
                    os.rename(file_path, os.path.join(image_path, new_filename))
                    
                file_path_to_delete = f'{image_path}/{imageName}_{fileType}_{sliceNumber}.{extension}'
                if os.path.exists(file_path_to_delete):
                    os.remove(file_path_to_delete)

# %%
# generate consensus images for test set
generate_consensus_labels()
# Out:
# Generating consensus for: 01016SACH-63...
# Generating consensus for: 01016SACH-73...
# Generating consensus for: 01016SACH-84...
# Generating consensus for: 01016SACH-117...
# Generating consensus for: 01016SACH-156...
# Generating consensus for: 01016SACH-178...
# Generating consensus for: 01016SACH-195...
# Generating consensus for: 01016SACH-208...
# Generating consensus for: 01016SACH-72...
# Generating consensus for: 01016SACH-88...
# Generating consensus for: 01016SACH-103...
# Generating consensus for: 01016SACH-133...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-142...
# Generating consensus for: 01016SACH-174...
# Generating consensus for: 01016SACH-175...
# Generating consensus for: 01016SACH-177...
# Generating consensus for: 01016SACH-197...
# Generating consensus for: 01016SACH-208...
# Generating consensus for: 01016SACH-209...
# Generating consensus for: 01016SACH-53...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-96...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-102...
# Generating consensus for: 01016SACH-103...
# Generating consensus for: 01016SACH-105...
# Generating consensus for: 01016SACH-117...
# Generating consensus for: 01016SACH-121...
# Generating consensus for: 01016SACH-133...
# Generating consensus for: 01016SACH-143...
# Generating consensus for: 01016SACH-157...
# Generating consensus for: 01016SACH-170...
# Generating consensus for: 01016SACH-174...
# Generating consensus for: 01016SACH-175...
# Generating consensus for: 01016SACH-197...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-78...
# Generating consensus for: 01016SACH-79...
# Generating consensus for: 01016SACH-111...
# Generating consensus for: 01016SACH-145...
# Generating consensus for: 01016SACH-152...
# Generating consensus for: 01016SACH-156...
# Generating consensus for: 01016SACH-166...
# Generating consensus for: 01016SACH-176...
# Generating consensus for: 01016SACH-186...
# Generating consensus for: 01016SACH-192...
# Generating consensus for: 01016SACH-193...
# Generating consensus for: 01016SACH-210...
# Generating consensus for: 01016SACH-54...
# Generating consensus for: 01016SACH-58...
# Generating consensus for: 01016SACH-59...
# Generating consensus for: 01016SACH-62...
# Generating consensus for: 01016SACH-64...
# Generating consensus for: 01016SACH-72...
# Generating consensus for: 01016SACH-76...
# Generating consensus for: 01016SACH-78...
# Generating consensus for: 01016SACH-83...
# Generating consensus for: 01016SACH-85...
# Generating consensus for: 01016SACH-96...
# Generating consensus for: 01016SACH-101...
# Generating consensus for: 01016SACH-103...
# Generating consensus for: 01016SACH-116...
# Generating consensus for: 01016SACH-119...
# Generating consensus for: 01016SACH-121...
# Generating consensus for: 01016SACH-127...
# Generating consensus for: 01016SACH-134...
# Generating consensus for: 01016SACH-140...
# Generating consensus for: 01016SACH-142...
# Generating consensus for: 01016SACH-143...
# Generating consensus for: 01016SACH-144...
# Generating consensus for: 01016SACH-152...
# Generating consensus for: 01016SACH-166...
# Generating consensus for: 01016SACH-170...
# Generating consensus for: 01016SACH-172...
# Generating consensus for: 01016SACH-176...
# Generating consensus for: 01016SACH-182...
# Generating consensus for: 01016SACH-183...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-53...
# Generating consensus for: 01016SACH-60...
# Generating consensus for: 01016SACH-72...
# Generating consensus for: 01016SACH-82...
# Generating consensus for: 01016SACH-88...
# Generating consensus for: 01016SACH-105...
# Generating consensus for: 01016SACH-112...
# Generating consensus for: 01016SACH-121...
# Generating consensus for: 01016SACH-124...
# Generating consensus for: 01016SACH-139...
# Generating consensus for: 01016SACH-140...
# Generating consensus for: 01016SACH-145...
# Generating consensus for: 01016SACH-156...
# Generating consensus for: 01016SACH-174...
# Generating consensus for: 01016SACH-175...
# Generating consensus for: 01016SACH-184...
# Generating consensus for: 01016SACH-186...
# Generating consensus for: 01016SACH-191...
# Generating consensus for: 01016SACH-195...
# Generating consensus for: 01016SACH-196...
# Generating consensus for: 01040VANE-152...
# Generating consensus for: 01040VANE-173...
# Generating consensus for: 01040VANE-177...
# Generating consensus for: 01040VANE-104...
# Generating consensus for: 01040VANE-145...
# Generating consensus for: 01040VANE-83...
# Generating consensus for: 01040VANE-106...
# Generating consensus for: 01040VANE-109...
# Generating consensus for: 01040VANE-159...
# Generating consensus for: 01040VANE-162...
# Generating consensus for: 01040VANE-172...
# Generating consensus for: 01040VANE-175...
# Generating consensus for: 01040VANE-91...
# Generating consensus for: 01040VANE-103...
# Generating consensus for: 01040VANE-105...
# Generating consensus for: 01040VANE-161...
# Generating consensus for: 01040VANE-90...
# Generating consensus for: 01040VANE-94...
# Generating consensus for: 01040VANE-97...
# Generating consensus for: 01040VANE-104...
# Generating consensus for: 01040VANE-105...
# Generating consensus for: 01040VANE-112...
# Generating consensus for: 01040VANE-113...
# Generating consensus for: 01040VANE-118...
# Generating consensus for: 01040VANE-142...
# Generating consensus for: 01040VANE-161...
# Generating consensus for: 01040VANE-162...
# Generating consensus for: 01040VANE-164...
# Generating consensus for: 01040VANE-173...
# Generating consensus for: 07010NABO-76...
# Generating consensus for: 07010NABO-154...
# Generating consensus for: 07010NABO-83...
# Generating consensus for: 07010NABO-97...
# Generating consensus for: 07010NABO-154...
# Generating consensus for: 07010NABO-200...
# Generating consensus for: 07010NABO-202...
# Generating consensus for: 07010NABO-73...
# Generating consensus for: 07010NABO-76...
# Generating consensus for: 07010NABO-92...
# Generating consensus for: 07010NABO-93...
# Generating consensus for: 07010NABO-134...
# Generating consensus for: 07010NABO-153...
# Generating consensus for: 07010NABO-160...
# Generating consensus for: 07010NABO-183...
# Generating consensus for: 07010NABO-73...
# Generating consensus for: 07010NABO-75...
# Generating consensus for: 07010NABO-82...
# Generating consensus for: 07010NABO-86...
# Generating consensus for: 07010NABO-94...
# Generating consensus for: 07010NABO-97...
# Generating consensus for: 07010NABO-98...
# Generating consensus for: 07010NABO-136...
# Generating consensus for: 07010NABO-156...
# Generating consensus for: 07010NABO-172...
# Generating consensus for: 07010NABO-183...
# Generating consensus for: 07010NABO-76...
# Generating consensus for: 07010NABO-78...
# Generating consensus for: 07010NABO-80...
# Generating consensus for: 07010NABO-82...
# Generating consensus for: 07010NABO-85...
# Generating consensus for: 07010NABO-89...
# Generating consensus for: 07010NABO-99...
# Generating consensus for: 07010NABO-102...
# Generating consensus for: 07010NABO-142...
# Generating consensus for: 07010NABO-149...
# Generating consensus for: 07010NABO-150...
# Generating consensus for: 07010NABO-154...
# Generating consensus for: 07010NABO-86...
# Generating consensus for: 07010NABO-99...
# Generating consensus for: 07010NABO-111...
# Generating consensus for: 07010NABO-135...
# Generating consensus for: 07010NABO-146...
# Generating consensus for: 07010NABO-147...
# Generating consensus for: 07010NABO-148...
# Generating consensus for: 07010NABO-154...
# Generating consensus for: 07040DORE-63...
# Generating consensus for: 07040DORE-70...
# Generating consensus for: 07040DORE-143...
# Generating consensus for: 07040DORE-152...
# Generating consensus for: 07040DORE-163...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-81...
# Generating consensus for: 07040DORE-83...
# Generating consensus for: 07040DORE-84...
# Generating consensus for: 07040DORE-108...
# Generating consensus for: 07040DORE-143...
# Generating consensus for: 07040DORE-145...
# Generating consensus for: 07040DORE-147...
# Generating consensus for: 07040DORE-157...
# Generating consensus for: 07040DORE-163...
# Generating consensus for: 07040DORE-165...
# Generating consensus for: 07040DORE-62...
# Generating consensus for: 07040DORE-73...
# Generating consensus for: 07040DORE-75...
# Generating consensus for: 07040DORE-84...
# Generating consensus for: 07040DORE-118...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-155...
# Generating consensus for: 07040DORE-166...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-172...
# Generating consensus for: 07040DORE-173...
# Generating consensus for: 07040DORE-74...
# Generating consensus for: 07040DORE-83...
# Generating consensus for: 07040DORE-110...
# Generating consensus for: 07040DORE-112...
# Generating consensus for: 07040DORE-121...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-161...
# Generating consensus for: 07040DORE-173...
# Generating consensus for: 07040DORE-179...
# Generating consensus for: 07040DORE-70...
# Generating consensus for: 07040DORE-74...
# Generating consensus for: 07040DORE-75...
# Generating consensus for: 07040DORE-86...
# Generating consensus for: 07040DORE-97...
# Generating consensus for: 07040DORE-100...
# Generating consensus for: 07040DORE-102...
# Generating consensus for: 07040DORE-118...
# Generating consensus for: 07040DORE-140...
# Generating consensus for: 07040DORE-141...
# Generating consensus for: 07040DORE-144...
# Generating consensus for: 07040DORE-152...
# Generating consensus for: 07040DORE-155...
# Generating consensus for: 07040DORE-157...
# Generating consensus for: 07040DORE-160...
# Generating consensus for: 07040DORE-167...
# Generating consensus for: 07040DORE-170...
# Generating consensus for: 07040DORE-172...
# Generating consensus for: 07040DORE-177...
# Generating consensus for: 07040DORE-187...
# Generating consensus for: 07040DORE-73...
# Generating consensus for: 07040DORE-80...
# Generating consensus for: 07040DORE-83...
# Generating consensus for: 07040DORE-100...
# Generating consensus for: 07040DORE-146...
# Generating consensus for: 07040DORE-150...
# Generating consensus for: 07040DORE-159...
