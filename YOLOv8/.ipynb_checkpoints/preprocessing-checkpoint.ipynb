# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\f_alf\anaconda3\lib\site-packages (10.0.1)

# %%
from PIL import Image
import os
import cv2
import glob
import numpy as np
import shutil
import random

# %%
def resize_images(input_output_folder, target_size=(640, 640)):
    # Ensure the folder exists
    os.makedirs(input_output_folder, exist_ok=True)

    # List all files in the folder
    input_files = os.listdir(input_output_folder)

    for filename in input_files:
        input_path = os.path.join(input_output_folder, filename)
        output_path = os.path.join(input_output_folder, filename)

        # Open the image
        with Image.open(input_path) as img:
            # Resize the image
            resized_img = img.resize(target_size, resample=Image.LANCZOS)

            # Save the resized image
            resized_img.save(output_path)

    print(f'...finished resizing {len(input_files)} images')

# %%
print(f'resizing train images...')
folder = 'datasets/data/train/images'
resize_images(folder)
print(f'resizing train labels...')
folder = 'datasets/data/train/labels'
resize_images(folder)
print(f'resizing test images...')
folder = 'datasets/data/test/images'
resize_images(folder)
print(f'resizing test labels...')
folder = 'datasets/data/test/labels'
resize_images(folder)
# Out:
# resizing train images...
# ...finished resizing 3916 images
# resizing train labels...
# ...finished resizing 3916 images
# resizing test images...
# ...finished resizing 599 images
# resizing test labels...
# ...finished resizing 599 images

# %%
def bounding_box_extraction(image_folder):
    # Iterate over all images in the folder
    for image_path in glob.glob(os.path.join(image_folder, '*.png')):
        # Load the grayscale mask image
        mask_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Check the loaded image
        if mask_image is None:
            print(f"Error: Unable to load the image {image_path}")
            continue

        # Threshold the image: Values greater than or equal to 1 become 255
        _, binary_mask = cv2.threshold(mask_image, 0.5, 255, cv2.THRESH_BINARY)

        # Find contours in the binary mask
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Output file details
        output_file_path = os.path.splitext(image_path)[0] + '.txt'

        # Write bounding box coordinates to the text file
        with open(output_file_path, 'w') as f:
            for contour in contours:
                flattened_contour = contour.reshape(-1, 2)  # Flatten the nested structure
                
                if len(flattened_contour) >= 2:
                    normalized_contour = (flattened_contour.astype(float) / np.array([mask_image.shape[1], mask_image.shape[0]])).tolist()

                    # Write to the text file
                    f.write("1")
                    for point in normalized_contour:
                        f.write(" {} {}".format(point[0], point[1]))
                    f.write("\n")

        # Deleting the image file
        os.remove(image_path)
    print("...finished")

# %%
print("extracting bounding boxes for train...")
bounding_box_extraction('./datasets/data/train/labels')
print("extracting bounding boxes for test...")
bounding_box_extraction('./datasets/data/test/labels')
print("...finished extracting")
# Out:
# extracting bounding boxes for train...
# extracting bounding boxes for test...
# ...finished extracting

# %%
def move_related_files(source_dir1, source_dir2, dest_dir1, dest_dir2, percentage):
    files1 = os.listdir(source_dir1)
    files2 = os.listdir(source_dir2)

    os.makedirs(dest_dir1, exist_ok=True)
    os.makedirs(dest_dir2, exist_ok=True)

    num_files_to_move = int(min(len(files1), len(files2)) * (percentage / 100.0))

    files_to_move = random.sample(list(zip(files1, files2)), num_files_to_move)
    #print(files_to_move)

    for file_pair in files_to_move:
        file1, file2 = file_pair
        #print(f"Moving: {file1} and {file2}")
        source_path1 = os.path.join(source_dir1, file1)
        source_path2 = os.path.join(source_dir2, file2)
        dest_path1 = os.path.join(dest_dir1, file1)
        dest_path2 = os.path.join(dest_dir2, file2)

        try:
            shutil.move(source_path1, dest_path1)
            shutil.move(source_path2, dest_path2)
        except Exception as e:
            print(e)

        print(f"Moved: {file1} and {file2}")

# %%
source_directory1 = "./datasets/data/train/images"
source_directory2 = "./datasets/data/train/labels"
destination_directory1 = "./datasets/data/val/images"
destination_directory2 = "./datasets/data/val/labels"
percentage_to_move = 20  # Adjust this percentage as needed

move_related_files(source_directory1, source_directory2, destination_directory1, destination_directory2, percentage_to_move)
# Out:
# Moved: 01040VANE_seg6_110.png and 01040VANE_seg6_110.txt
# Moved: 01016SACH_seg4_076.png and 01016SACH_seg4_076.txt
# Moved: 08002CHJE_seg1_088.png and 08002CHJE_seg1_088.txt
# Moved: 07043SEME_seg3_150.png and 07043SEME_seg3_150.txt
# Moved: 07040DORE_seg1_089.png and 07040DORE_seg1_089.txt
# Moved: 08002CHJE_seg2_065.png and 08002CHJE_seg2_065.txt
# Moved: 07040DORE_seg1_185.png and 07040DORE_seg1_185.txt
# Moved: 07043SEME_seg6_181.png and 07043SEME_seg6_181.txt
# Moved: 07040DORE_seg6_167.png and 07040DORE_seg6_167.txt
# Moved: 07043SEME_seg1_116.png and 07043SEME_seg1_116.txt
# Moved: 08002CHJE_seg3_152.png and 08002CHJE_seg3_152.txt
# Moved: 07040DORE_seg6_106.png and 07040DORE_seg6_106.txt
# Moved: 01040VANE_seg3_098.png and 01040VANE_seg3_098.txt
# Moved: 08002CHJE_seg6_194.png and 08002CHJE_seg6_194.txt
# Moved: 08002CHJE_seg5_040.png and 08002CHJE_seg5_040.txt
# Moved: 01040VANE_seg1_097.png and 01040VANE_seg1_097.txt
# Moved: 08002CHJE_seg1_042.png and 08002CHJE_seg1_042.txt
# Moved: 07040DORE_seg2_155.png and 07040DORE_seg2_155.txt
# Moved: 07043SEME_seg6_175.png and 07043SEME_seg6_175.txt
# Moved: 07043SEME_seg5_191.png and 07043SEME_seg5_191.txt
# Moved: 01040VANE_seg3_116.png and 01040VANE_seg3_116.txt
# Moved: 07043SEME_seg6_086.png and 07043SEME_seg6_086.txt
# Moved: 01016SACH_seg2_144.png and 01016SACH_seg2_144.txt
# Moved: 07043SEME_seg7_145.png and 07043SEME_seg7_145.txt
# Moved: 01016SACH_seg2_122.png and 01016SACH_seg2_122.txt
# Moved: 01016SACH_seg7_155.png and 01016SACH_seg7_155.txt
# Moved: 01016SACH_seg6_119.png and 01016SACH_seg6_119.txt
# Moved: 01040VANE_seg3_125.png and 01040VANE_seg3_125.txt
# Moved: 07043SEME_seg5_157.png and 07043SEME_seg5_157.txt
# Moved: 07040DORE_seg2_183.png and 07040DORE_seg2_183.txt
# Moved: 07040DORE_seg5_100.png and 07040DORE_seg5_100.txt
# Moved: 08002CHJE_seg5_143.png and 08002CHJE_seg5_143.txt
# Moved: 08002CHJE_seg4_180.png and 08002CHJE_seg4_180.txt
# Moved: 01040VANE_seg4_167.png and 01040VANE_seg4_167.txt
# Moved: 07040DORE_seg2_152.png and 07040DORE_seg2_152.txt
# Moved: 07010NABO_seg4_179.png and 07010NABO_seg4_179.txt
# Moved: 01016SACH_seg5_164.png and 01016SACH_seg5_164.txt
# Moved: 01016SACH_seg5_171.png and 01016SACH_seg5_171.txt
# Moved: 01016SACH_seg4_165.png and 01016SACH_seg4_165.txt
# Moved: 01016SACH_seg6_060.png and 01016SACH_seg6_060.txt
# Moved: 01040VANE_seg3_176.png and 01040VANE_seg3_176.txt
# Moved: 07040DORE_seg6_070.png and 07040DORE_seg6_070.txt
# Moved: 08002CHJE_seg5_089.png and 08002CHJE_seg5_089.txt
# Moved: 01016SACH_seg6_125.png and 01016SACH_seg6_125.txt
# Moved: 08002CHJE_seg4_069.png and 08002CHJE_seg4_069.txt
# Moved: 07043SEME_seg5_190.png and 07043SEME_seg5_190.txt
# Moved: 07010NABO_seg7_135.png and 07010NABO_seg7_135.txt
# Moved: 08002CHJE_seg1_200.png and 08002CHJE_seg1_200.txt
# Moved: 01016SACH_seg7_079.png and 01016SACH_seg7_079.txt
# Moved: 07010NABO_seg3_168.png and 07010NABO_seg3_168.txt
# Moved: 07040DORE_seg7_079.png and 07040DORE_seg7_079.txt
# Moved: 01016SACH_seg1_088.png and 01016SACH_seg1_088.txt
# Moved: 07040DORE_seg1_111.png and 07040DORE_seg1_111.txt
# Moved: 08002CHJE_seg1_090.png and 08002CHJE_seg1_090.txt
# Moved: 01016SACH_seg1_167.png and 01016SACH_seg1_167.txt
# Moved: 01016SACH_seg4_145.png and 01016SACH_seg4_145.txt
# Moved: 08002CHJE_seg6_208.png and 08002CHJE_seg6_208.txt
# Moved: 07010NABO_seg5_150.png and 07010NABO_seg5_150.txt
# Moved: 08002CHJE_seg5_151.png and 08002CHJE_seg5_151.txt
# Moved: 08002CHJE_seg1_121.png and 08002CHJE_seg1_121.txt
# Moved: 08002CHJE_seg5_048.png and 08002CHJE_seg5_048.txt
# Moved: 07040DORE_seg1_074.png and 07040DORE_seg1_074.txt
# Moved: 07010NABO_seg6_146.png and 07010NABO_seg6_146.txt
# Moved: 07043SEME_seg3_130.png and 07043SEME_seg3_130.txt
# Moved: 01040VANE_seg5_164.png and 01040VANE_seg5_164.txt
# Moved: 07040DORE_seg1_155.png and 07040DORE_seg1_155.txt
# Moved: 07010NABO_seg6_157.png and 07010NABO_seg6_157.txt
# Moved: 07040DORE_seg2_150.png and 07040DORE_seg2_150.txt
# Moved: 01016SACH_seg7_154.png and 01016SACH_seg7_154.txt
# Moved: 08002CHJE_seg2_084.png and 08002CHJE_seg2_084.txt
# Moved: 07010NABO_seg3_194.png and 07010NABO_seg3_194.txt
# Moved: 08002CHJE_seg2_093.png and 08002CHJE_seg2_093.txt
# Moved: 08002CHJE_seg6_148.png and 08002CHJE_seg6_148.txt
# Moved: 01016SACH_seg7_131.png and 01016SACH_seg7_131.txt
# Moved: 07043SEME_seg5_105.png and 07043SEME_seg5_105.txt
# Moved: 01016SACH_seg1_152.png and 01016SACH_seg1_152.txt
# Moved: 08002CHJE_seg4_137.png and 08002CHJE_seg4_137.txt
# Moved: 01016SACH_seg3_199.png and 01016SACH_seg3_199.txt
# Moved: 01016SACH_seg2_066.png and 01016SACH_seg2_066.txt
# Moved: 07010NABO_seg3_133.png and 07010NABO_seg3_133.txt
# Moved: 08002CHJE_seg4_213.png and 08002CHJE_seg4_213.txt
# Moved: 01016SACH_seg2_148.png and 01016SACH_seg2_148.txt
# Moved: 07010NABO_seg1_171.png and 07010NABO_seg1_171.txt
# Moved: 08002CHJE_seg4_060.png and 08002CHJE_seg4_060.txt
# Moved: 07040DORE_seg5_146.png and 07040DORE_seg5_146.txt
# Moved: 07040DORE_seg5_112.png and 07040DORE_seg5_112.txt
# Moved: 07043SEME_seg7_161.png and 07043SEME_seg7_161.txt
# Moved: 07043SEME_seg4_172.png and 07043SEME_seg4_172.txt
# Moved: 01040VANE_seg7_114.png and 01040VANE_seg7_114.txt
# Moved: 01016SACH_seg5_158.png and 01016SACH_seg5_158.txt
# Moved: 07040DORE_seg5_173.png and 07040DORE_seg5_173.txt
# Moved: 07010NABO_seg7_133.png and 07010NABO_seg7_133.txt
# Moved: 01016SACH_seg2_112.png and 01016SACH_seg2_112.txt
# Moved: 01040VANE_seg7_175.png and 01040VANE_seg7_175.txt
# Moved: 01016SACH_seg5_176.png and 01016SACH_seg5_176.txt
# Moved: 07010NABO_seg1_088.png and 07010NABO_seg1_088.txt
# Moved: 07043SEME_seg1_119.png and 07043SEME_seg1_119.txt
# Moved: 07043SEME_seg3_098.png and 07043SEME_seg3_098.txt
# Moved: 07043SEME_seg1_162.png and 07043SEME_seg1_162.txt
# Moved: 08002CHJE_seg6_141.png and 08002CHJE_seg6_141.txt
# Moved: 07043SEME_seg2_145.png and 07043SEME_seg2_145.txt
# Moved: 01016SACH_seg5_214.png and 01016SACH_seg5_214.txt
# Moved: 01016SACH_seg2_214.png and 01016SACH_seg2_214.txt
# Moved: 01016SACH_seg6_165.png and 01016SACH_seg6_165.txt
# Moved: 07043SEME_seg4_103.png and 07043SEME_seg4_103.txt
# Moved: 07010NABO_seg2_161.png and 07010NABO_seg2_161.txt
# Moved: 01016SACH_seg2_146.png and 01016SACH_seg2_146.txt
# Moved: 01016SACH_seg2_167.png and 01016SACH_seg2_167.txt
# Moved: 01016SACH_seg3_096.png and 01016SACH_seg3_096.txt
# Moved: 07010NABO_seg6_133.png and 07010NABO_seg6_133.txt
# Moved: 01040VANE_seg4_097.png and 01040VANE_seg4_097.txt
# Moved: 08002CHJE_seg5_101.png and 08002CHJE_seg5_101.txt
# Moved: 07040DORE_seg7_173.png and 07040DORE_seg7_173.txt
# Moved: 08002CHJE_seg5_100.png and 08002CHJE_seg5_100.txt
# Moved: 07040DORE_seg6_113.png and 07040DORE_seg6_113.txt
# Moved: 07040DORE_seg2_145.png and 07040DORE_seg2_145.txt
# Moved: 01016SACH_seg4_086.png and 01016SACH_seg4_086.txt
# Moved: 01016SACH_seg7_189.png and 01016SACH_seg7_189.txt
# Moved: 07040DORE_seg1_084.png and 07040DORE_seg1_084.txt
# Moved: 01016SACH_seg1_056.png and 01016SACH_seg1_056.txt
# Moved: 01040VANE_seg4_171.png and 01040VANE_seg4_171.txt
# Moved: 07040DORE_seg4_062.png and 07040DORE_seg4_062.txt
# Moved: 01040VANE_seg7_162.png and 01040VANE_seg7_162.txt
# Moved: 07043SEME_seg6_157.png and 07043SEME_seg6_157.txt
# Moved: 08002CHJE_seg5_207.png and 08002CHJE_seg5_207.txt
# Moved: 08002CHJE_seg3_101.png and 08002CHJE_seg3_101.txt
# Moved: 01016SACH_seg1_211.png and 01016SACH_seg1_211.txt
# Moved: 07040DORE_seg1_092.png and 07040DORE_seg1_092.txt
# Moved: 07010NABO_seg4_147.png and 07010NABO_seg4_147.txt
# Moved: 07043SEME_seg6_139.png and 07043SEME_seg6_139.txt
# Moved: 01040VANE_seg4_154.png and 01040VANE_seg4_154.txt
# Moved: 07040DORE_seg1_194.png and 07040DORE_seg1_194.txt
# Moved: 07043SEME_seg5_159.png and 07043SEME_seg5_159.txt
# Moved: 07010NABO_seg6_195.png and 07010NABO_seg6_195.txt
# Moved: 07040DORE_seg2_113.png and 07040DORE_seg2_113.txt
# Moved: 07040DORE_seg5_104.png and 07040DORE_seg5_104.txt
# Moved: 08002CHJE_seg3_054.png and 08002CHJE_seg3_054.txt
# Moved: 01016SACH_seg2_116.png and 01016SACH_seg2_116.txt
# Moved: 07010NABO_seg7_101.png and 07010NABO_seg7_101.txt
# Moved: 08002CHJE_seg3_203.png and 08002CHJE_seg3_203.txt
# Moved: 08002CHJE_seg5_087.png and 08002CHJE_seg5_087.txt
# Moved: 01040VANE_seg7_144.png and 01040VANE_seg7_144.txt
# Moved: 01040VANE_seg3_102.png and 01040VANE_seg3_102.txt
# Moved: 07010NABO_seg4_180.png and 07010NABO_seg4_180.txt
# Moved: 08002CHJE_seg6_180.png and 08002CHJE_seg6_180.txt
# Moved: 01016SACH_seg3_092.png and 01016SACH_seg3_092.txt
# Moved: 07043SEME_seg2_182.png and 07043SEME_seg2_182.txt
# Moved: 01016SACH_seg5_173.png and 01016SACH_seg5_173.txt
# Moved: 08002CHJE_seg7_134.png and 08002CHJE_seg7_134.txt
# Moved: 07043SEME_seg5_161.png and 07043SEME_seg5_161.txt
# Moved: 08002CHJE_seg3_119.png and 08002CHJE_seg3_119.txt
# Moved: 01016SACH_seg5_140.png and 01016SACH_seg5_140.txt
# Moved: 07043SEME_seg6_078.png and 07043SEME_seg6_078.txt
# Moved: 01016SACH_seg6_118.png and 01016SACH_seg6_118.txt
# Moved: 08002CHJE_seg4_049.png and 08002CHJE_seg4_049.txt
# Moved: 01040VANE_seg3_175.png and 01040VANE_seg3_175.txt
# Moved: 01040VANE_seg1_104.png and 01040VANE_seg1_104.txt
# Moved: 01016SACH_seg7_090.png and 01016SACH_seg7_090.txt
# Moved: 08002CHJE_seg5_085.png and 08002CHJE_seg5_085.txt
# Moved: 01016SACH_seg2_127.png and 01016SACH_seg2_127.txt
# Moved: 07010NABO_seg1_132.png and 07010NABO_seg1_132.txt
# Moved: 08002CHJE_seg7_195.png and 08002CHJE_seg7_195.txt
# Moved: 07043SEME_seg5_142.png and 07043SEME_seg5_142.txt
# Moved: 01016SACH_seg1_067.png and 01016SACH_seg1_067.txt
# Moved: 08002CHJE_seg4_212.png and 08002CHJE_seg4_212.txt
# Moved: 07010NABO_seg4_095.png and 07010NABO_seg4_095.txt
# Moved: 08002CHJE_seg1_142.png and 08002CHJE_seg1_142.txt
# Moved: 08002CHJE_seg1_040.png and 08002CHJE_seg1_040.txt
# Moved: 07043SEME_seg4_142.png and 07043SEME_seg4_142.txt
# Moved: 08002CHJE_seg6_095.png and 08002CHJE_seg6_095.txt
# Moved: 08002CHJE_seg3_115.png and 08002CHJE_seg3_115.txt
# Moved: 07040DORE_seg1_101.png and 07040DORE_seg1_101.txt
# Moved: 07010NABO_seg6_077.png and 07010NABO_seg6_077.txt
# Moved: 01040VANE_seg3_146.png and 01040VANE_seg3_146.txt
# Moved: 07040DORE_seg3_100.png and 07040DORE_seg3_100.txt
# Moved: 01016SACH_seg2_188.png and 01016SACH_seg2_188.txt
# Moved: 08002CHJE_seg6_103.png and 08002CHJE_seg6_103.txt
# Moved: 01016SACH_seg7_107.png and 01016SACH_seg7_107.txt
# Moved: 08002CHJE_seg7_109.png and 08002CHJE_seg7_109.txt
# Moved: 07010NABO_seg1_184.png and 07010NABO_seg1_184.txt
# Moved: 07043SEME_seg6_114.png and 07043SEME_seg6_114.txt
# Moved: 08002CHJE_seg4_215.png and 08002CHJE_seg4_215.txt
# Moved: 07010NABO_seg1_136.png and 07010NABO_seg1_136.txt
# Moved: 01016SACH_seg6_198.png and 01016SACH_seg6_198.txt
# Moved: 07043SEME_seg7_154.png and 07043SEME_seg7_154.txt
# Moved: 07043SEME_seg2_189.png and 07043SEME_seg2_189.txt
# Moved: 07040DORE_seg7_086.png and 07040DORE_seg7_086.txt
# Moved: 07040DORE_seg4_090.png and 07040DORE_seg4_090.txt
# Moved: 01016SACH_seg4_198.png and 01016SACH_seg4_198.txt
# Moved: 07043SEME_seg5_125.png and 07043SEME_seg5_125.txt
# Moved: 07043SEME_seg1_123.png and 07043SEME_seg1_123.txt
# Moved: 08002CHJE_seg2_042.png and 08002CHJE_seg2_042.txt
# Moved: 01040VANE_seg3_118.png and 01040VANE_seg3_118.txt
# Moved: 07010NABO_seg6_129.png and 07010NABO_seg6_129.txt
# Moved: 07010NABO_seg2_088.png and 07010NABO_seg2_088.txt
# Moved: 01016SACH_seg7_129.png and 01016SACH_seg7_129.txt
# Moved: 07043SEME_seg4_165.png and 07043SEME_seg4_165.txt
# Moved: 07043SEME_seg2_121.png and 07043SEME_seg2_121.txt
# Moved: 01040VANE_seg7_098.png and 01040VANE_seg7_098.txt
# Moved: 01016SACH_seg2_130.png and 01016SACH_seg2_130.txt
# Moved: 07040DORE_seg4_162.png and 07040DORE_seg4_162.txt
# Moved: 08002CHJE_seg4_115.png and 08002CHJE_seg4_115.txt
# Moved: 07040DORE_seg4_095.png and 07040DORE_seg4_095.txt
# Moved: 07010NABO_seg3_086.png and 07010NABO_seg3_086.txt
# Moved: 07043SEME_seg5_086.png and 07043SEME_seg5_086.txt
# Moved: 01016SACH_seg4_110.png and 01016SACH_seg4_110.txt
# Moved: 08002CHJE_seg1_155.png and 08002CHJE_seg1_155.txt
# Moved: 07043SEME_seg1_181.png and 07043SEME_seg1_181.txt
# Moved: 08002CHJE_seg5_183.png and 08002CHJE_seg5_183.txt
# Moved: 01040VANE_seg6_054.png and 01040VANE_seg6_054.txt
# Moved: 08002CHJE_seg5_210.png and 08002CHJE_seg5_210.txt
# Moved: 01016SACH_seg2_143.png and 01016SACH_seg2_143.txt
# Moved: 08002CHJE_seg7_045.png and 08002CHJE_seg7_045.txt
# Moved: 07040DORE_seg1_100.png and 07040DORE_seg1_100.txt
# Moved: 07040DORE_seg1_096.png and 07040DORE_seg1_096.txt
# Moved: 01040VANE_seg7_106.png and 01040VANE_seg7_106.txt
# Moved: 08002CHJE_seg2_148.png and 08002CHJE_seg2_148.txt
# Moved: 01016SACH_seg7_141.png and 01016SACH_seg7_141.txt
# Moved: 08002CHJE_seg5_074.png and 08002CHJE_seg5_074.txt
# Moved: 08002CHJE_seg5_096.png and 08002CHJE_seg5_096.txt
# Moved: 07043SEME_seg4_168.png and 07043SEME_seg4_168.txt
# Moved: 08002CHJE_seg3_108.png and 08002CHJE_seg3_108.txt
# Moved: 01016SACH_seg4_087.png and 01016SACH_seg4_087.txt
# Moved: 07043SEME_seg2_177.png and 07043SEME_seg2_177.txt
# Moved: 07040DORE_seg3_172.png and 07040DORE_seg3_172.txt
# Moved: 07043SEME_seg3_116.png and 07043SEME_seg3_116.txt
# Moved: 08002CHJE_seg2_078.png and 08002CHJE_seg2_078.txt
# Moved: 08002CHJE_seg2_107.png and 08002CHJE_seg2_107.txt
# Moved: 07010NABO_seg2_098.png and 07010NABO_seg2_098.txt
# Moved: 08002CHJE_seg4_119.png and 08002CHJE_seg4_119.txt
# Moved: 01016SACH_seg3_174.png and 01016SACH_seg3_174.txt
# Moved: 07010NABO_seg5_095.png and 07010NABO_seg5_095.txt
# Moved: 01016SACH_seg3_169.png and 01016SACH_seg3_169.txt
# Moved: 01040VANE_seg6_052.png and 01040VANE_seg6_052.txt
# Moved: 01016SACH_seg2_111.png and 01016SACH_seg2_111.txt
# Moved: 07040DORE_seg1_187.png and 07040DORE_seg1_187.txt
# Moved: 07043SEME_seg5_083.png and 07043SEME_seg5_083.txt
# Moved: 07010NABO_seg3_090.png and 07010NABO_seg3_090.txt
# Moved: 07040DORE_seg6_085.png and 07040DORE_seg6_085.txt
# Moved: 01016SACH_seg2_083.png and 01016SACH_seg2_083.txt
# Moved: 08002CHJE_seg2_168.png and 08002CHJE_seg2_168.txt
# Moved: 07043SEME_seg7_169.png and 07043SEME_seg7_169.txt
# Moved: 07010NABO_seg4_087.png and 07010NABO_seg4_087.txt
# Moved: 08002CHJE_seg2_064.png and 08002CHJE_seg2_064.txt
# Moved: 07010NABO_seg5_169.png and 07010NABO_seg5_169.txt
# Moved: 08002CHJE_seg1_178.png and 08002CHJE_seg1_178.txt
# Moved: 01016SACH_seg1_199.png and 01016SACH_seg1_199.txt
# Moved: 01040VANE_seg6_084.png and 01040VANE_seg6_084.txt
# Moved: 08002CHJE_seg1_077.png and 08002CHJE_seg1_077.txt
# Moved: 01016SACH_seg2_054.png and 01016SACH_seg2_054.txt
# Moved: 07010NABO_seg6_128.png and 07010NABO_seg6_128.txt
# Moved: 01040VANE_seg6_055.png and 01040VANE_seg6_055.txt
# Moved: 07040DORE_seg4_106.png and 07040DORE_seg4_106.txt
# Moved: 01016SACH_seg1_128.png and 01016SACH_seg1_128.txt
# Moved: 01016SACH_seg4_181.png and 01016SACH_seg4_181.txt
# Moved: 07010NABO_seg3_161.png and 07010NABO_seg3_161.txt
# Moved: 07010NABO_seg1_169.png and 07010NABO_seg1_169.txt
# Moved: 08002CHJE_seg2_109.png and 08002CHJE_seg2_109.txt
# Moved: 07010NABO_seg2_084.png and 07010NABO_seg2_084.txt
# Moved: 07010NABO_seg1_145.png and 07010NABO_seg1_145.txt
# Moved: 07010NABO_seg6_139.png and 07010NABO_seg6_139.txt
# Moved: 07043SEME_seg7_140.png and 07043SEME_seg7_140.txt
# Moved: 07043SEME_seg3_151.png and 07043SEME_seg3_151.txt
# Moved: 07043SEME_seg7_081.png and 07043SEME_seg7_081.txt
# Moved: 07040DORE_seg3_093.png and 07040DORE_seg3_093.txt
# Moved: 07040DORE_seg7_143.png and 07040DORE_seg7_143.txt
# Moved: 07010NABO_seg7_134.png and 07010NABO_seg7_134.txt
# Moved: 08002CHJE_seg5_093.png and 08002CHJE_seg5_093.txt
# Moved: 08002CHJE_seg1_097.png and 08002CHJE_seg1_097.txt
# Moved: 07010NABO_seg1_161.png and 07010NABO_seg1_161.txt
# Moved: 08002CHJE_seg6_138.png and 08002CHJE_seg6_138.txt
# Moved: 07040DORE_seg3_162.png and 07040DORE_seg3_162.txt
# Moved: 08002CHJE_seg2_141.png and 08002CHJE_seg2_141.txt
# Moved: 07040DORE_seg6_082.png and 07040DORE_seg6_082.txt
# Moved: 07040DORE_seg4_155.png and 07040DORE_seg4_155.txt
# Moved: 07043SEME_seg2_098.png and 07043SEME_seg2_098.txt
# Moved: 01016SACH_seg1_125.png and 01016SACH_seg1_125.txt
# Moved: 07043SEME_seg4_137.png and 07043SEME_seg4_137.txt
# Moved: 08002CHJE_seg3_168.png and 08002CHJE_seg3_168.txt
# Moved: 07040DORE_seg5_114.png and 07040DORE_seg5_114.txt
# Moved: 07043SEME_seg7_166.png and 07043SEME_seg7_166.txt
# Moved: 07040DORE_seg5_184.png and 07040DORE_seg5_184.txt
# Moved: 07010NABO_seg5_185.png and 07010NABO_seg5_185.txt
# Moved: 08002CHJE_seg7_150.png and 08002CHJE_seg7_150.txt
# Moved: 07043SEME_seg7_083.png and 07043SEME_seg7_083.txt
# Moved: 01016SACH_seg7_124.png and 01016SACH_seg7_124.txt
# Moved: 01016SACH_seg1_073.png and 01016SACH_seg1_073.txt
# Moved: 07010NABO_seg6_110.png and 07010NABO_seg6_110.txt
# Moved: 01040VANE_seg5_102.png and 01040VANE_seg5_102.txt
# Moved: 07043SEME_seg4_136.png and 07043SEME_seg4_136.txt
# Moved: 08002CHJE_seg1_070.png and 08002CHJE_seg1_070.txt
# Moved: 01016SACH_seg1_210.png and 01016SACH_seg1_210.txt
# Moved: 07010NABO_seg7_102.png and 07010NABO_seg7_102.txt
# Moved: 01016SACH_seg3_100.png and 01016SACH_seg3_100.txt
# Moved: 08002CHJE_seg7_108.png and 08002CHJE_seg7_108.txt
# Moved: 07040DORE_seg5_166.png and 07040DORE_seg5_166.txt
# Moved: 01016SACH_seg3_151.png and 01016SACH_seg3_151.txt
# Moved: 07040DORE_seg1_191.png and 07040DORE_seg1_191.txt
# Moved: 01016SACH_seg5_146.png and 01016SACH_seg5_146.txt
# Moved: 01016SACH_seg7_059.png and 01016SACH_seg7_059.txt
# Moved: 01016SACH_seg2_108.png and 01016SACH_seg2_108.txt
# Moved: 01016SACH_seg1_209.png and 01016SACH_seg1_209.txt
# Moved: 08002CHJE_seg6_203.png and 08002CHJE_seg6_203.txt
# Moved: 01016SACH_seg4_136.png and 01016SACH_seg4_136.txt
# Moved: 07010NABO_seg6_078.png and 07010NABO_seg6_078.txt
# Moved: 01040VANE_seg1_145.png and 01040VANE_seg1_145.txt
# Moved: 01040VANE_seg4_158.png and 01040VANE_seg4_158.txt
# Moved: 01040VANE_seg6_201.png and 01040VANE_seg6_201.txt
# Moved: 07040DORE_seg5_157.png and 07040DORE_seg5_157.txt
# Moved: 07040DORE_seg5_097.png and 07040DORE_seg5_097.txt
# Moved: 01016SACH_seg4_062.png and 01016SACH_seg4_062.txt
# Moved: 01016SACH_seg7_145.png and 01016SACH_seg7_145.txt
# Moved: 08002CHJE_seg2_179.png and 08002CHJE_seg2_179.txt
# Moved: 07043SEME_seg1_112.png and 07043SEME_seg1_112.txt
# Moved: 07040DORE_seg2_190.png and 07040DORE_seg2_190.txt
# Moved: 08002CHJE_seg2_208.png and 08002CHJE_seg2_208.txt
# Moved: 01016SACH_seg1_070.png and 01016SACH_seg1_070.txt
# Moved: 01016SACH_seg7_123.png and 01016SACH_seg7_123.txt
# Moved: 01016SACH_seg2_092.png and 01016SACH_seg2_092.txt
# Moved: 01040VANE_seg3_128.png and 01040VANE_seg3_128.txt
# Moved: 01016SACH_seg3_168.png and 01016SACH_seg3_168.txt
# Moved: 08002CHJE_seg2_152.png and 08002CHJE_seg2_152.txt
# Moved: 07043SEME_seg5_180.png and 07043SEME_seg5_180.txt
# Moved: 07040DORE_seg6_077.png and 07040DORE_seg6_077.txt
# Moved: 07040DORE_seg6_150.png and 07040DORE_seg6_150.txt
# Moved: 07010NABO_seg6_135.png and 07010NABO_seg6_135.txt
# Moved: 07010NABO_seg3_128.png and 07010NABO_seg3_128.txt
# Moved: 08002CHJE_seg4_166.png and 08002CHJE_seg4_166.txt
# Moved: 07010NABO_seg1_191.png and 07010NABO_seg1_191.txt
# Moved: 07040DORE_seg2_103.png and 07040DORE_seg2_103.txt
# Moved: 01016SACH_seg1_129.png and 01016SACH_seg1_129.txt
# Moved: 08002CHJE_seg7_114.png and 08002CHJE_seg7_114.txt
# Moved: 01016SACH_seg5_106.png and 01016SACH_seg5_106.txt
# Moved: 07043SEME_seg7_078.png and 07043SEME_seg7_078.txt
# Moved: 07010NABO_seg4_082.png and 07010NABO_seg4_082.txt
# Moved: 08002CHJE_seg4_189.png and 08002CHJE_seg4_189.txt
# Moved: 07010NABO_seg3_200.png and 07010NABO_seg3_200.txt
# Moved: 08002CHJE_seg5_063.png and 08002CHJE_seg5_063.txt
# Moved: 07040DORE_seg7_146.png and 07040DORE_seg7_146.txt
# Moved: 07043SEME_seg7_088.png and 07043SEME_seg7_088.txt
# Moved: 08002CHJE_seg1_103.png and 08002CHJE_seg1_103.txt
# Moved: 01016SACH_seg5_145.png and 01016SACH_seg5_145.txt
# Moved: 07043SEME_seg2_142.png and 07043SEME_seg2_142.txt
# Moved: 01016SACH_seg3_200.png and 01016SACH_seg3_200.txt
# Moved: 08002CHJE_seg5_108.png and 08002CHJE_seg5_108.txt
# Moved: 07010NABO_seg5_194.png and 07010NABO_seg5_194.txt
# Moved: 08002CHJE_seg4_068.png and 08002CHJE_seg4_068.txt
# Moved: 07040DORE_seg4_150.png and 07040DORE_seg4_150.txt
# Moved: 07040DORE_seg7_077.png and 07040DORE_seg7_077.txt
# Moved: 07040DORE_seg3_165.png and 07040DORE_seg3_165.txt
# Moved: 07010NABO_seg4_188.png and 07010NABO_seg4_188.txt
# Moved: 01040VANE_seg1_111.png and 01040VANE_seg1_111.txt
# Moved: 07040DORE_seg7_070.png and 07040DORE_seg7_070.txt
# Moved: 07043SEME_seg1_092.png and 07043SEME_seg1_092.txt
# Moved: 08002CHJE_seg5_164.png and 08002CHJE_seg5_164.txt
# Moved: 07040DORE_seg5_155.png and 07040DORE_seg5_155.txt
# Moved: 07010NABO_seg3_201.png and 07010NABO_seg3_201.txt
# Moved: 07043SEME_seg2_171.png and 07043SEME_seg2_171.txt
# Moved: 07040DORE_seg3_155.png and 07040DORE_seg3_155.txt
# Moved: 01016SACH_seg1_143.png and 01016SACH_seg1_143.txt
# Moved: 07010NABO_seg5_079.png and 07010NABO_seg5_079.txt
# Moved: 07043SEME_seg5_090.png and 07043SEME_seg5_090.txt
# Moved: 01040VANE_seg4_146.png and 01040VANE_seg4_146.txt
# Moved: 01040VANE_seg3_099.png and 01040VANE_seg3_099.txt
# Moved: 08002CHJE_seg1_143.png and 08002CHJE_seg1_143.txt
# Moved: 07010NABO_seg3_143.png and 07010NABO_seg3_143.txt
# Moved: 01016SACH_seg3_062.png and 01016SACH_seg3_062.txt
# Moved: 07043SEME_seg1_102.png and 07043SEME_seg1_102.txt
# Moved: 01016SACH_seg3_071.png and 01016SACH_seg3_071.txt
# Moved: 07040DORE_seg2_066.png and 07040DORE_seg2_066.txt
# Moved: 01016SACH_seg3_076.png and 01016SACH_seg3_076.txt
# Moved: 01016SACH_seg2_177.png and 01016SACH_seg2_177.txt
# Moved: 08002CHJE_seg6_173.png and 08002CHJE_seg6_173.txt
# Moved: 01016SACH_seg7_193.png and 01016SACH_seg7_193.txt
# Moved: 07040DORE_seg4_178.png and 07040DORE_seg4_178.txt
# Moved: 07040DORE_seg5_168.png and 07040DORE_seg5_168.txt
# Moved: 08002CHJE_seg2_184.png and 08002CHJE_seg2_184.txt
# Moved: 08002CHJE_seg7_053.png and 08002CHJE_seg7_053.txt
# Moved: 01016SACH_seg3_102.png and 01016SACH_seg3_102.txt
# Moved: 07040DORE_seg4_108.png and 07040DORE_seg4_108.txt
# Moved: 01040VANE_seg4_169.png and 01040VANE_seg4_169.txt
# Moved: 08002CHJE_seg2_108.png and 08002CHJE_seg2_108.txt
# Moved: 01016SACH_seg6_131.png and 01016SACH_seg6_131.txt
# Moved: 01016SACH_seg2_096.png and 01016SACH_seg2_096.txt
# Moved: 01016SACH_seg1_181.png and 01016SACH_seg1_181.txt
# Moved: 01016SACH_seg3_135.png and 01016SACH_seg3_135.txt
# Moved: 08002CHJE_seg7_083.png and 08002CHJE_seg7_083.txt
# Moved: 08002CHJE_seg2_174.png and 08002CHJE_seg2_174.txt
# Moved: 07040DORE_seg6_137.png and 07040DORE_seg6_137.txt
# Moved: 07010NABO_seg3_155.png and 07010NABO_seg3_155.txt
# Moved: 07040DORE_seg1_168.png and 07040DORE_seg1_168.txt
# Moved: 08002CHJE_seg3_190.png and 08002CHJE_seg3_190.txt
# Moved: 07010NABO_seg1_196.png and 07010NABO_seg1_196.txt
# Moved: 01040VANE_seg4_162.png and 01040VANE_seg4_162.txt
# Moved: 01040VANE_seg1_081.png and 01040VANE_seg1_081.txt
# Moved: 07010NABO_seg3_148.png and 07010NABO_seg3_148.txt
# Moved: 01016SACH_seg2_189.png and 01016SACH_seg2_189.txt
# Moved: 08002CHJE_seg5_061.png and 08002CHJE_seg5_061.txt
# Moved: 01016SACH_seg6_153.png and 01016SACH_seg6_153.txt
# Moved: 08002CHJE_seg3_063.png and 08002CHJE_seg3_063.txt
# Moved: 07043SEME_seg2_124.png and 07043SEME_seg2_124.txt
# Moved: 07040DORE_seg7_168.png and 07040DORE_seg7_168.txt
# Moved: 01040VANE_seg5_162.png and 01040VANE_seg5_162.txt
# Moved: 07043SEME_seg3_157.png and 07043SEME_seg3_157.txt
# Moved: 01016SACH_seg7_093.png and 01016SACH_seg7_093.txt
# Moved: 01040VANE_seg5_175.png and 01040VANE_seg5_175.txt
# Moved: 01040VANE_seg4_137.png and 01040VANE_seg4_137.txt
# Moved: 01016SACH_seg1_185.png and 01016SACH_seg1_185.txt
# Moved: 08002CHJE_seg3_109.png and 08002CHJE_seg3_109.txt
# Moved: 08002CHJE_seg5_149.png and 08002CHJE_seg5_149.txt
# Moved: 08002CHJE_seg4_076.png and 08002CHJE_seg4_076.txt
# Moved: 01016SACH_seg1_058.png and 01016SACH_seg1_058.txt
# Moved: 01016SACH_seg6_055.png and 01016SACH_seg6_055.txt
# Moved: 07043SEME_seg7_114.png and 07043SEME_seg7_114.txt
# Moved: 01016SACH_seg7_169.png and 01016SACH_seg7_169.txt
# Moved: 08002CHJE_seg4_080.png and 08002CHJE_seg4_080.txt
# Moved: 01016SACH_seg3_115.png and 01016SACH_seg3_115.txt
# Moved: 08002CHJE_seg4_136.png and 08002CHJE_seg4_136.txt
# Moved: 07040DORE_seg3_160.png and 07040DORE_seg3_160.txt
# Moved: 07010NABO_seg5_088.png and 07010NABO_seg5_088.txt
# Moved: 07010NABO_seg2_086.png and 07010NABO_seg2_086.txt
# Moved: 07043SEME_seg3_174.png and 07043SEME_seg3_174.txt
# Moved: 07043SEME_seg4_187.png and 07043SEME_seg4_187.txt
# Moved: 07010NABO_seg4_182.png and 07010NABO_seg4_182.txt
# Moved: 07010NABO_seg3_171.png and 07010NABO_seg3_171.txt
# Moved: 08002CHJE_seg4_062.png and 08002CHJE_seg4_062.txt
# Moved: 01016SACH_seg7_082.png and 01016SACH_seg7_082.txt
# Moved: 01016SACH_seg4_167.png and 01016SACH_seg4_167.txt
# Moved: 07043SEME_seg6_164.png and 07043SEME_seg6_164.txt
# Moved: 08002CHJE_seg3_194.png and 08002CHJE_seg3_194.txt
# Moved: 07043SEME_seg7_129.png and 07043SEME_seg7_129.txt
# Moved: 07040DORE_seg1_151.png and 07040DORE_seg1_151.txt
# Moved: 07010NABO_seg3_098.png and 07010NABO_seg3_098.txt
# Moved: 07040DORE_seg2_188.png and 07040DORE_seg2_188.txt
# Moved: 01016SACH_seg3_172.png and 01016SACH_seg3_172.txt
# Moved: 07010NABO_seg2_180.png and 07010NABO_seg2_180.txt
# Moved: 07043SEME_seg1_125.png and 07043SEME_seg1_125.txt
# Moved: 07010NABO_seg6_136.png and 07010NABO_seg6_136.txt
# Moved: 08002CHJE_seg4_159.png and 08002CHJE_seg4_159.txt
# Moved: 07040DORE_seg1_098.png and 07040DORE_seg1_098.txt
# Moved: 07043SEME_seg7_084.png and 07043SEME_seg7_084.txt
# Moved: 08002CHJE_seg1_133.png and 08002CHJE_seg1_133.txt
# Moved: 01016SACH_seg4_150.png and 01016SACH_seg4_150.txt
# Moved: 07040DORE_seg6_145.png and 07040DORE_seg6_145.txt
# Moved: 07040DORE_seg4_087.png and 07040DORE_seg4_087.txt
# Moved: 07040DORE_seg4_195.png and 07040DORE_seg4_195.txt
# Moved: 01040VANE_seg1_160.png and 01040VANE_seg1_160.txt
# Moved: 01016SACH_seg3_078.png and 01016SACH_seg3_078.txt
# Moved: 07040DORE_seg5_116.png and 07040DORE_seg5_116.txt
# Moved: 07040DORE_seg2_143.png and 07040DORE_seg2_143.txt
# Moved: 07040DORE_seg4_193.png and 07040DORE_seg4_193.txt
# Moved: 01016SACH_seg7_089.png and 01016SACH_seg7_089.txt
# Moved: 07043SEME_seg4_121.png and 07043SEME_seg4_121.txt
# Moved: 08002CHJE_seg1_062.png and 08002CHJE_seg1_062.txt
# Moved: 07010NABO_seg5_172.png and 07010NABO_seg5_172.txt
# Moved: 07040DORE_seg4_097.png and 07040DORE_seg4_097.txt
# Moved: 07010NABO_seg2_151.png and 07010NABO_seg2_151.txt
# Moved: 01040VANE_seg2_158.png and 01040VANE_seg2_158.txt
# Moved: 07010NABO_seg1_142.png and 07010NABO_seg1_142.txt
# Moved: 07010NABO_seg4_134.png and 07010NABO_seg4_134.txt
# Moved: 01016SACH_seg1_147.png and 01016SACH_seg1_147.txt
# Moved: 08002CHJE_seg4_102.png and 08002CHJE_seg4_102.txt
# Moved: 01040VANE_seg2_085.png and 01040VANE_seg2_085.txt
# Moved: 08002CHJE_seg2_149.png and 08002CHJE_seg2_149.txt
# Moved: 01040VANE_seg7_112.png and 01040VANE_seg7_112.txt
# Moved: 07040DORE_seg7_117.png and 07040DORE_seg7_117.txt
# Moved: 07040DORE_seg2_192.png and 07040DORE_seg2_192.txt
# Moved: 07040DORE_seg2_120.png and 07040DORE_seg2_120.txt
# Moved: 07043SEME_seg2_175.png and 07043SEME_seg2_175.txt
# Moved: 07040DORE_seg6_069.png and 07040DORE_seg6_069.txt
# Moved: 08002CHJE_seg5_125.png and 08002CHJE_seg5_125.txt
# Moved: 08002CHJE_seg7_117.png and 08002CHJE_seg7_117.txt
# Moved: 01016SACH_seg7_150.png and 01016SACH_seg7_150.txt
# Moved: 07040DORE_seg6_074.png and 07040DORE_seg6_074.txt
# Moved: 07040DORE_seg2_178.png and 07040DORE_seg2_178.txt
# Moved: 07040DORE_seg2_182.png and 07040DORE_seg2_182.txt
# Moved: 08002CHJE_seg4_124.png and 08002CHJE_seg4_124.txt
# Moved: 08002CHJE_seg2_189.png and 08002CHJE_seg2_189.txt
# Moved: 08002CHJE_seg3_174.png and 08002CHJE_seg3_174.txt
# Moved: 07040DORE_seg2_101.png and 07040DORE_seg2_101.txt
# Moved: 08002CHJE_seg7_079.png and 08002CHJE_seg7_079.txt
# Moved: 07010NABO_seg5_078.png and 07010NABO_seg5_078.txt
# Moved: 01040VANE_seg4_104.png and 01040VANE_seg4_104.txt
# Moved: 08002CHJE_seg4_092.png and 08002CHJE_seg4_092.txt
# Moved: 07010NABO_seg6_191.png and 07010NABO_seg6_191.txt
# Moved: 01016SACH_seg2_216.png and 01016SACH_seg2_216.txt
# Moved: 08002CHJE_seg1_102.png and 08002CHJE_seg1_102.txt
# Moved: 01040VANE_seg3_134.png and 01040VANE_seg3_134.txt
# Moved: 07043SEME_seg7_080.png and 07043SEME_seg7_080.txt
# Moved: 07043SEME_seg2_159.png and 07043SEME_seg2_159.txt
# Moved: 08002CHJE_seg2_190.png and 08002CHJE_seg2_190.txt
# Moved: 01040VANE_seg2_096.png and 01040VANE_seg2_096.txt
# Moved: 08002CHJE_seg1_092.png and 08002CHJE_seg1_092.txt
# Moved: 08002CHJE_seg5_121.png and 08002CHJE_seg5_121.txt
# Moved: 08002CHJE_seg5_083.png and 08002CHJE_seg5_083.txt
# Moved: 08002CHJE_seg3_039.png and 08002CHJE_seg3_039.txt
# Moved: 01016SACH_seg6_190.png and 01016SACH_seg6_190.txt
# Moved: 01040VANE_seg4_163.png and 01040VANE_seg4_163.txt
# Moved: 07010NABO_seg1_096.png and 07010NABO_seg1_096.txt
# Moved: 07010NABO_seg5_151.png and 07010NABO_seg5_151.txt
# Moved: 01016SACH_seg7_054.png and 01016SACH_seg7_054.txt
# Moved: 07040DORE_seg4_163.png and 07040DORE_seg4_163.txt
# Moved: 08002CHJE_seg7_154.png and 08002CHJE_seg7_154.txt
# Moved: 07040DORE_seg7_081.png and 07040DORE_seg7_081.txt
# Moved: 07043SEME_seg5_104.png and 07043SEME_seg5_104.txt
# Moved: 08002CHJE_seg2_143.png and 08002CHJE_seg2_143.txt
# Moved: 01016SACH_seg2_067.png and 01016SACH_seg2_067.txt
# Moved: 07010NABO_seg1_198.png and 07010NABO_seg1_198.txt
# Moved: 08002CHJE_seg6_084.png and 08002CHJE_seg6_084.txt
# Moved: 07043SEME_seg2_114.png and 07043SEME_seg2_114.txt
# Moved: 08002CHJE_seg4_111.png and 08002CHJE_seg4_111.txt
# Moved: 01016SACH_seg4_055.png and 01016SACH_seg4_055.txt
# Moved: 08002CHJE_seg3_128.png and 08002CHJE_seg3_128.txt
# Moved: 01040VANE_seg1_143.png and 01040VANE_seg1_143.txt
# Moved: 07010NABO_seg6_098.png and 07010NABO_seg6_098.txt
# Moved: 08002CHJE_seg3_046.png and 08002CHJE_seg3_046.txt
# Moved: 08002CHJE_seg4_122.png and 08002CHJE_seg4_122.txt
# Moved: 07010NABO_seg6_142.png and 07010NABO_seg6_142.txt
# Moved: 07040DORE_seg3_145.png and 07040DORE_seg3_145.txt
# Moved: 01016SACH_seg7_178.png and 01016SACH_seg7_178.txt
# Moved: 08002CHJE_seg2_202.png and 08002CHJE_seg2_202.txt
# Moved: 07043SEME_seg1_169.png and 07043SEME_seg1_169.txt
# Moved: 07043SEME_seg5_188.png and 07043SEME_seg5_188.txt
# Moved: 01016SACH_seg2_095.png and 01016SACH_seg2_095.txt
# Moved: 07040DORE_seg3_137.png and 07040DORE_seg3_137.txt
# Moved: 01016SACH_seg7_053.png and 01016SACH_seg7_053.txt
# Moved: 07010NABO_seg4_149.png and 07010NABO_seg4_149.txt
# Moved: 07040DORE_seg1_078.png and 07040DORE_seg1_078.txt
# Moved: 01016SACH_seg1_173.png and 01016SACH_seg1_173.txt
# Moved: 07040DORE_seg6_174.png and 07040DORE_seg6_174.txt
# Moved: 07040DORE_seg5_083.png and 07040DORE_seg5_083.txt
# Moved: 01016SACH_seg7_196.png and 01016SACH_seg7_196.txt
# Moved: 01016SACH_seg7_152.png and 01016SACH_seg7_152.txt
# Moved: 01016SACH_seg2_114.png and 01016SACH_seg2_114.txt
# Moved: 07010NABO_seg2_097.png and 07010NABO_seg2_097.txt
# Moved: 01016SACH_seg5_116.png and 01016SACH_seg5_116.txt
# Moved: 01040VANE_seg1_094.png and 01040VANE_seg1_094.txt
# Moved: 07010NABO_seg6_130.png and 07010NABO_seg6_130.txt
# Moved: 07040DORE_seg3_140.png and 07040DORE_seg3_140.txt
# Moved: 07043SEME_seg3_099.png and 07043SEME_seg3_099.txt
# Moved: 08002CHJE_seg6_096.png and 08002CHJE_seg6_096.txt
# Moved: 07010NABO_seg3_106.png and 07010NABO_seg3_106.txt
# Moved: 07043SEME_seg3_153.png and 07043SEME_seg3_153.txt
# Moved: 01040VANE_seg3_104.png and 01040VANE_seg3_104.txt
# Moved: 01016SACH_seg4_069.png and 01016SACH_seg4_069.txt
# Moved: 01040VANE_seg4_153.png and 01040VANE_seg4_153.txt
# Moved: 08002CHJE_seg1_176.png and 08002CHJE_seg1_176.txt
# Moved: 01016SACH_seg5_131.png and 01016SACH_seg5_131.txt
# Moved: 07043SEME_seg1_184.png and 07043SEME_seg1_184.txt
# Moved: 07040DORE_seg6_111.png and 07040DORE_seg6_111.txt
# Moved: 08002CHJE_seg6_060.png and 08002CHJE_seg6_060.txt
# Moved: 08002CHJE_seg1_166.png and 08002CHJE_seg1_166.txt
# Moved: 07010NABO_seg3_189.png and 07010NABO_seg3_189.txt
# Moved: 01040VANE_seg4_083.png and 01040VANE_seg4_083.txt
# Moved: 07010NABO_seg2_090.png and 07010NABO_seg2_090.txt
# Moved: 08002CHJE_seg6_043.png and 08002CHJE_seg6_043.txt
# Moved: 07040DORE_seg3_089.png and 07040DORE_seg3_089.txt
# Moved: 08002CHJE_seg3_133.png and 08002CHJE_seg3_133.txt
# Moved: 08002CHJE_seg7_143.png and 08002CHJE_seg7_143.txt
# Moved: 07040DORE_seg2_169.png and 07040DORE_seg2_169.txt
# Moved: 08002CHJE_seg1_065.png and 08002CHJE_seg1_065.txt
# Moved: 01016SACH_seg2_107.png and 01016SACH_seg2_107.txt
# Moved: 01016SACH_seg2_193.png and 01016SACH_seg2_193.txt
# Moved: 01016SACH_seg4_089.png and 01016SACH_seg4_089.txt
# Moved: 01016SACH_seg3_052.png and 01016SACH_seg3_052.txt
# Moved: 01016SACH_seg5_150.png and 01016SACH_seg5_150.txt
# Moved: 08002CHJE_seg2_090.png and 08002CHJE_seg2_090.txt
# Moved: 08002CHJE_seg5_044.png and 08002CHJE_seg5_044.txt
# Moved: 08002CHJE_seg5_138.png and 08002CHJE_seg5_138.txt
# Moved: 01016SACH_seg6_135.png and 01016SACH_seg6_135.txt
# Moved: 08002CHJE_seg2_203.png and 08002CHJE_seg2_203.txt
# Moved: 01016SACH_seg3_146.png and 01016SACH_seg3_146.txt
# Moved: 07043SEME_seg7_031.png and 07043SEME_seg7_031.txt
# Moved: 01016SACH_seg7_180.png and 01016SACH_seg7_180.txt
# Moved: 07040DORE_seg3_166.png and 07040DORE_seg3_166.txt
# Moved: 07043SEME_seg6_111.png and 07043SEME_seg6_111.txt
# Moved: 07010NABO_seg1_199.png and 07010NABO_seg1_199.txt
# Moved: 01016SACH_seg4_057.png and 01016SACH_seg4_057.txt
# Moved: 07010NABO_seg2_154.png and 07010NABO_seg2_154.txt
# Moved: 08002CHJE_seg4_059.png and 08002CHJE_seg4_059.txt
# Moved: 07040DORE_seg4_088.png and 07040DORE_seg4_088.txt
# Moved: 08002CHJE_seg4_188.png and 08002CHJE_seg4_188.txt
# Moved: 07043SEME_seg6_107.png and 07043SEME_seg6_107.txt
# Moved: 01016SACH_seg6_175.png and 01016SACH_seg6_175.txt
# Moved: 01016SACH_seg1_187.png and 01016SACH_seg1_187.txt
# Moved: 07043SEME_seg4_194.png and 07043SEME_seg4_194.txt
# Moved: 01016SACH_seg3_084.png and 01016SACH_seg3_084.txt
# Moved: 07010NABO_seg5_073.png and 07010NABO_seg5_073.txt
# Moved: 01040VANE_seg1_098.png and 01040VANE_seg1_098.txt
# Moved: 08002CHJE_seg4_199.png and 08002CHJE_seg4_199.txt
# Moved: 01016SACH_seg3_104.png and 01016SACH_seg3_104.txt
# Moved: 07010NABO_seg6_102.png and 07010NABO_seg6_102.txt
# Moved: 08002CHJE_seg3_080.png and 08002CHJE_seg3_080.txt
# Moved: 07040DORE_seg2_075.png and 07040DORE_seg2_075.txt
# Moved: 08002CHJE_seg6_174.png and 08002CHJE_seg6_174.txt
# Moved: 08002CHJE_seg4_173.png and 08002CHJE_seg4_173.txt
# Moved: 07010NABO_seg5_082.png and 07010NABO_seg5_082.txt
# Moved: 07010NABO_seg1_149.png and 07010NABO_seg1_149.txt
# Moved: 07040DORE_seg4_079.png and 07040DORE_seg4_079.txt
# Moved: 07043SEME_seg4_148.png and 07043SEME_seg4_148.txt
# Moved: 01016SACH_seg4_095.png and 01016SACH_seg4_095.txt
# Moved: 07043SEME_seg4_177.png and 07043SEME_seg4_177.txt
# Moved: 07040DORE_seg1_161.png and 07040DORE_seg1_161.txt
# Moved: 08002CHJE_seg2_067.png and 08002CHJE_seg2_067.txt
# Moved: 01016SACH_seg5_190.png and 01016SACH_seg5_190.txt
# Moved: 01016SACH_seg6_182.png and 01016SACH_seg6_182.txt
# Moved: 07040DORE_seg5_175.png and 07040DORE_seg5_175.txt
# Moved: 01016SACH_seg7_078.png and 01016SACH_seg7_078.txt
# Moved: 01016SACH_seg5_058.png and 01016SACH_seg5_058.txt
# Moved: 07010NABO_seg7_141.png and 07010NABO_seg7_141.txt
# Moved: 01016SACH_seg6_069.png and 01016SACH_seg6_069.txt
# Moved: 07040DORE_seg2_069.png and 07040DORE_seg2_069.txt
# Moved: 07010NABO_seg1_157.png and 07010NABO_seg1_157.txt
# Moved: 07040DORE_seg4_146.png and 07040DORE_seg4_146.txt
# Moved: 07010NABO_seg1_134.png and 07010NABO_seg1_134.txt
# Moved: 08002CHJE_seg2_137.png and 08002CHJE_seg2_137.txt
# Moved: 08002CHJE_seg1_043.png and 08002CHJE_seg1_043.txt
# Moved: 01016SACH_seg2_158.png and 01016SACH_seg2_158.txt
# Moved: 08002CHJE_seg7_081.png and 08002CHJE_seg7_081.txt
# Moved: 01016SACH_seg7_108.png and 01016SACH_seg7_108.txt
# Moved: 01040VANE_seg6_103.png and 01040VANE_seg6_103.txt
# Moved: 01016SACH_seg6_178.png and 01016SACH_seg6_178.txt
# Moved: 08002CHJE_seg7_136.png and 08002CHJE_seg7_136.txt
# Moved: 07043SEME_seg5_132.png and 07043SEME_seg5_132.txt
# Moved: 08002CHJE_seg2_175.png and 08002CHJE_seg2_175.txt
# Moved: 01040VANE_seg1_110.png and 01040VANE_seg1_110.txt
# Moved: 08002CHJE_seg2_194.png and 08002CHJE_seg2_194.txt
# Moved: 07043SEME_seg7_136.png and 07043SEME_seg7_136.txt
# Moved: 08002CHJE_seg3_129.png and 08002CHJE_seg3_129.txt
# Moved: 01016SACH_seg1_112.png and 01016SACH_seg1_112.txt
# Moved: 01016SACH_seg1_131.png and 01016SACH_seg1_131.txt
# Moved: 07040DORE_seg4_072.png and 07040DORE_seg4_072.txt
# Moved: 01016SACH_seg3_133.png and 01016SACH_seg3_133.txt
# Moved: 08002CHJE_seg4_204.png and 08002CHJE_seg4_204.txt
# Moved: 08002CHJE_seg5_165.png and 08002CHJE_seg5_165.txt
# Moved: 01016SACH_seg3_182.png and 01016SACH_seg3_182.txt
# Moved: 07040DORE_seg7_099.png and 07040DORE_seg7_099.txt
# Moved: 07040DORE_seg1_146.png and 07040DORE_seg1_146.txt
# Moved: 01016SACH_seg3_103.png and 01016SACH_seg3_103.txt
# Moved: 01040VANE_seg7_117.png and 01040VANE_seg7_117.txt
# Moved: 07040DORE_seg7_105.png and 07040DORE_seg7_105.txt
# Moved: 08002CHJE_seg2_076.png and 08002CHJE_seg2_076.txt
# Moved: 07043SEME_seg5_111.png and 07043SEME_seg5_111.txt
# Moved: 01016SACH_seg2_068.png and 01016SACH_seg2_068.txt
# Moved: 07010NABO_seg2_173.png and 07010NABO_seg2_173.txt
# Moved: 07043SEME_seg6_093.png and 07043SEME_seg6_093.txt
# Moved: 08002CHJE_seg7_174.png and 08002CHJE_seg7_174.txt
# Moved: 01016SACH_seg1_094.png and 01016SACH_seg1_094.txt
# Moved: 07040DORE_seg1_167.png and 07040DORE_seg1_167.txt
# Moved: 07043SEME_seg6_104.png and 07043SEME_seg6_104.txt
# Moved: 08002CHJE_seg7_141.png and 08002CHJE_seg7_141.txt
# Moved: 01016SACH_seg6_076.png and 01016SACH_seg6_076.txt
# Moved: 07040DORE_seg6_098.png and 07040DORE_seg6_098.txt
# Moved: 08002CHJE_seg7_171.png and 08002CHJE_seg7_171.txt
# Moved: 01016SACH_seg1_192.png and 01016SACH_seg1_192.txt
# Moved: 07043SEME_seg3_166.png and 07043SEME_seg3_166.txt
# Moved: 08002CHJE_seg6_073.png and 08002CHJE_seg6_073.txt
# Moved: 07043SEME_seg7_156.png and 07043SEME_seg7_156.txt
# Moved: 01016SACH_seg5_080.png and 01016SACH_seg5_080.txt
# Moved: 07043SEME_seg1_157.png and 07043SEME_seg1_157.txt
# Moved: 01016SACH_seg6_108.png and 01016SACH_seg6_108.txt
# Moved: 07010NABO_seg3_084.png and 07010NABO_seg3_084.txt
# Moved: 07040DORE_seg5_144.png and 07040DORE_seg5_144.txt
# Moved: 07010NABO_seg1_095.png and 07010NABO_seg1_095.txt
# Moved: 07010NABO_seg3_187.png and 07010NABO_seg3_187.txt
# Moved: 01016SACH_seg5_165.png and 01016SACH_seg5_165.txt
# Moved: 07040DORE_seg3_084.png and 07040DORE_seg3_084.txt
# Moved: 07043SEME_seg2_173.png and 07043SEME_seg2_173.txt
# Moved: 07043SEME_seg5_118.png and 07043SEME_seg5_118.txt
# Moved: 01016SACH_seg4_157.png and 01016SACH_seg4_157.txt
# Moved: 08002CHJE_seg2_126.png and 08002CHJE_seg2_126.txt
# Moved: 01040VANE_seg6_162.png and 01040VANE_seg6_162.txt
# Moved: 08002CHJE_seg6_142.png and 08002CHJE_seg6_142.txt
# Moved: 08002CHJE_seg4_079.png and 08002CHJE_seg4_079.txt
# Moved: 01016SACH_seg2_123.png and 01016SACH_seg2_123.txt
# Moved: 01016SACH_seg7_153.png and 01016SACH_seg7_153.txt
# Moved: 07010NABO_seg1_197.png and 07010NABO_seg1_197.txt
# Moved: 07040DORE_seg7_111.png and 07040DORE_seg7_111.txt
# Moved: 07010NABO_seg5_183.png and 07010NABO_seg5_183.txt
# Moved: 01016SACH_seg2_196.png and 01016SACH_seg2_196.txt
# Moved: 01016SACH_seg7_072.png and 01016SACH_seg7_072.txt
# Moved: 01016SACH_seg4_166.png and 01016SACH_seg4_166.txt
# Moved: 01016SACH_seg4_160.png and 01016SACH_seg4_160.txt
# Moved: 08002CHJE_seg7_212.png and 08002CHJE_seg7_212.txt
# Moved: 08002CHJE_seg5_135.png and 08002CHJE_seg5_135.txt
# Moved: 01040VANE_seg4_113.png and 01040VANE_seg4_113.txt
# Moved: 07040DORE_seg3_153.png and 07040DORE_seg3_153.txt
# Moved: 07040DORE_seg6_142.png and 07040DORE_seg6_142.txt
# Moved: 08002CHJE_seg2_086.png and 08002CHJE_seg2_086.txt
# Moved: 01016SACH_seg4_107.png and 01016SACH_seg4_107.txt
# Moved: 07043SEME_seg1_099.png and 07043SEME_seg1_099.txt
# Moved: 07043SEME_seg4_123.png and 07043SEME_seg4_123.txt
# Moved: 01016SACH_seg7_187.png and 01016SACH_seg7_187.txt
# Moved: 01040VANE_seg7_107.png and 01040VANE_seg7_107.txt
# Moved: 07040DORE_seg2_153.png and 07040DORE_seg2_153.txt
# Moved: 01040VANE_seg5_161.png and 01040VANE_seg5_161.txt
# Moved: 07010NABO_seg5_171.png and 07010NABO_seg5_171.txt
# Moved: 01016SACH_seg3_086.png and 01016SACH_seg3_086.txt
# Moved: 01040VANE_seg5_094.png and 01040VANE_seg5_094.txt
# Moved: 08002CHJE_seg3_159.png and 08002CHJE_seg3_159.txt
# Moved: 07040DORE_seg3_169.png and 07040DORE_seg3_169.txt
# Moved: 07043SEME_seg2_092.png and 07043SEME_seg2_092.txt
# Moved: 01040VANE_seg2_103.png and 01040VANE_seg2_103.txt
# Moved: 01040VANE_seg4_116.png and 01040VANE_seg4_116.txt
# Moved: 01016SACH_seg6_143.png and 01016SACH_seg6_143.txt
# Moved: 08002CHJE_seg1_186.png and 08002CHJE_seg1_186.txt
# Moved: 07043SEME_seg6_188.png and 07043SEME_seg6_188.txt
# Moved: 07040DORE_seg5_065.png and 07040DORE_seg5_065.txt
# Moved: 08002CHJE_seg1_193.png and 08002CHJE_seg1_193.txt
# Moved: 08002CHJE_seg6_116.png and 08002CHJE_seg6_116.txt
# Moved: 07043SEME_seg7_113.png and 07043SEME_seg7_113.txt
# Moved: 07043SEME_seg3_141.png and 07043SEME_seg3_141.txt
# Moved: 01016SACH_seg3_123.png and 01016SACH_seg3_123.txt
# Moved: 07040DORE_seg1_188.png and 07040DORE_seg1_188.txt
# Moved: 01016SACH_seg1_111.png and 01016SACH_seg1_111.txt
# Moved: 08002CHJE_seg2_110.png and 08002CHJE_seg2_110.txt
# Moved: 07040DORE_seg4_171.png and 07040DORE_seg4_171.txt
# Moved: 08002CHJE_seg4_174.png and 08002CHJE_seg4_174.txt
# Moved: 07010NABO_seg6_093.png and 07010NABO_seg6_093.txt
# Moved: 08002CHJE_seg2_207.png and 08002CHJE_seg2_207.txt
# Moved: 01016SACH_seg2_199.png and 01016SACH_seg2_199.txt
# Moved: 07040DORE_seg5_163.png and 07040DORE_seg5_163.txt
# Moved: 07010NABO_seg1_077.png and 07010NABO_seg1_077.txt
# Moved: 01040VANE_seg1_161.png and 01040VANE_seg1_161.txt
# Moved: 07043SEME_seg1_100.png and 07043SEME_seg1_100.txt
# Moved: 07040DORE_seg4_077.png and 07040DORE_seg4_077.txt
# Moved: 07040DORE_seg4_112.png and 07040DORE_seg4_112.txt
# Moved: 07040DORE_seg6_117.png and 07040DORE_seg6_117.txt
# Moved: 01016SACH_seg4_104.png and 01016SACH_seg4_104.txt
# Moved: 01016SACH_seg4_169.png and 01016SACH_seg4_169.txt
# Moved: 01016SACH_seg4_054.png and 01016SACH_seg4_054.txt
# Moved: 08002CHJE_seg3_196.png and 08002CHJE_seg3_196.txt
# Moved: 07043SEME_seg4_085.png and 07043SEME_seg4_085.txt
# Moved: 01040VANE_seg6_164.png and 01040VANE_seg6_164.txt
# Moved: 07040DORE_seg3_111.png and 07040DORE_seg3_111.txt
# Moved: 01016SACH_seg3_127.png and 01016SACH_seg3_127.txt
# Moved: 08002CHJE_seg3_107.png and 08002CHJE_seg3_107.txt
# Moved: 08002CHJE_seg4_095.png and 08002CHJE_seg4_095.txt
# Moved: 07010NABO_seg6_141.png and 07010NABO_seg6_141.txt
# Moved: 07043SEME_seg7_172.png and 07043SEME_seg7_172.txt
# Moved: 07043SEME_seg7_131.png and 07043SEME_seg7_131.txt
# Moved: 07040DORE_seg4_114.png and 07040DORE_seg4_114.txt
# Moved: 08002CHJE_seg4_208.png and 08002CHJE_seg4_208.txt
# Moved: 08002CHJE_seg3_195.png and 08002CHJE_seg3_195.txt
# Moved: 01016SACH_seg1_104.png and 01016SACH_seg1_104.txt
# Moved: 07040DORE_seg5_080.png and 07040DORE_seg5_080.txt
# Moved: 01016SACH_seg3_157.png and 01016SACH_seg3_157.txt
# Moved: 01016SACH_seg1_115.png and 01016SACH_seg1_115.txt
# Moved: 08002CHJE_seg2_187.png and 08002CHJE_seg2_187.txt
# Moved: 07040DORE_seg1_083.png and 07040DORE_seg1_083.txt
# Moved: 07010NABO_seg2_074.png and 07010NABO_seg2_074.txt
# Moved: 07043SEME_seg2_099.png and 07043SEME_seg2_099.txt
# Moved: 01016SACH_seg1_148.png and 01016SACH_seg1_148.txt
# Moved: 07040DORE_seg2_142.png and 07040DORE_seg2_142.txt
# Moved: 07010NABO_seg2_176.png and 07010NABO_seg2_176.txt
# Moved: 07043SEME_seg5_148.png and 07043SEME_seg5_148.txt
# Moved: 07043SEME_seg6_184.png and 07043SEME_seg6_184.txt
# Moved: 08002CHJE_seg2_139.png and 08002CHJE_seg2_139.txt
# Moved: 08002CHJE_seg4_202.png and 08002CHJE_seg4_202.txt
# Moved: 01016SACH_seg1_077.png and 01016SACH_seg1_077.txt
# Moved: 07010NABO_seg5_086.png and 07010NABO_seg5_086.txt
# Moved: 07043SEME_seg2_154.png and 07043SEME_seg2_154.txt
# Moved: 07043SEME_seg4_170.png and 07043SEME_seg4_170.txt
# Moved: 01016SACH_seg5_070.png and 01016SACH_seg5_070.txt
# Moved: 08002CHJE_seg6_045.png and 08002CHJE_seg6_045.txt
# Moved: 07010NABO_seg1_182.png and 07010NABO_seg1_182.txt
# Moved: 07040DORE_seg4_064.png and 07040DORE_seg4_064.txt
# Moved: 07043SEME_seg2_163.png and 07043SEME_seg2_163.txt
# Moved: 01016SACH_seg5_174.png and 01016SACH_seg5_174.txt
# Moved: 08002CHJE_seg7_189.png and 08002CHJE_seg7_189.txt
# Moved: 08002CHJE_seg3_178.png and 08002CHJE_seg3_178.txt
# Moved: 07010NABO_seg3_097.png and 07010NABO_seg3_097.txt
# Moved: 01016SACH_seg2_104.png and 01016SACH_seg2_104.txt
# Moved: 08002CHJE_seg2_211.png and 08002CHJE_seg2_211.txt
# Moved: 07010NABO_seg5_159.png and 07010NABO_seg5_159.txt
# Moved: 01016SACH_seg6_177.png and 01016SACH_seg6_177.txt
# Moved: 07010NABO_seg5_155.png and 07010NABO_seg5_155.txt
# Moved: 08002CHJE_seg4_089.png and 08002CHJE_seg4_089.txt
# Moved: 08002CHJE_seg1_211.png and 08002CHJE_seg1_211.txt
# Moved: 08002CHJE_seg5_189.png and 08002CHJE_seg5_189.txt
# Moved: 08002CHJE_seg7_204.png and 08002CHJE_seg7_204.txt
# Moved: 01016SACH_seg2_086.png and 01016SACH_seg2_086.txt
# Moved: 07043SEME_seg6_115.png and 07043SEME_seg6_115.txt
